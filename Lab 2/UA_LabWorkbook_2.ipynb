# %% [markdown]
# # GG4257 - Urban Analytics: A Toolkit for Sustainable Urban Development
# ## Lab Workbook No 2: Data Manipulation and Working with Web Services
# ---
# Dr Fernando Benitez -  University of St Andrews - School of Geography and Sustainable Development - Iteration 2024

# %% [markdown]
# # Objectives
#
# - Practice and get familiar with the urban data landscape
# - Understand the *messiness* of real world (urban) data
# - Create common objects used to store data
# - Read tabular and spatial data formats into Python
# - Subset and merge data
# - Manipulate data and calculate new values
# - Practice basic techiques of Data Manipulation and learn how to use Python to access programmatically urban data and understand the benefits of it

# %% [markdown]
# # Data Manipulation
#
# Access and manipulate data is very important when it comes to work with python or any kind of programming langague, you need to feel confortable by reading and manipulating data in this programatic way. Initially it will seems it is more complicated, but later with practice you will see the advangte of dealing with data in this way.

# %% [markdown]
# ## Arrays and Data Frames (Numpy and Pandas)
#
# As you recall from the previous modules ( GG3209), there are two packages that can help you to read data in your computer memory and then let you manipulate them in a more efficient way.
#
# Two main object types that can be used to store tabular data in Python include the data frame and array. Each column of a data frame must be a single type, but different columns can be different types (e.g. string, float, etc.); all the columns of an array must be the same type. You can create these within Python manually or by reading in other common formats such as spreadsheets or csv files.

# %%
import numpy as np
import pandas as pd

#Create two arrays
years = range(2010, 2018) #creates a list of consecutive integers from 2010 to 2017
a = np.repeat(years, 4) #this uses numpy's repeat() function to repeat values
b = np.random.randint(0, 40, 32) # the randint() function can be used to generate random integers - in this case 32 values between 0 and 40
#Create data frame
c = pd.DataFrame({'a':a,'b':b})  #the curly brackets indicate a dictionary

# %% [markdown]
# The last line says to make a two column data frame, where the first column is called `'a'` and has the values from the `a` array, and the second column is called `'b'` and contains the values from the `b` array.
#
# You can type `c` into the console to return the whole data frame, however, you might just want to look at the top few rows. This can be achieved with the `head()` method:

# %%
#head returns the top five rows
c.head()

# %% [markdown]
# In a similar way you can create arrays using the numpy package.

# %%
#Create a list of numbers
a = range(0, 25)#the range function generates a range of integers

b = np.array(a) #creates a one dimensional array
b = b.reshape(5,5) #create an array with 5 rows and 5 columns
b

# %% [markdown]
# It is possible to multiply a numeric array by a constant or another array

# %%
#Multiply b by 10
b * 10

# %%
#Multiply b * b
b * b

# %% [markdown]
# Extracting elements from a one dimensional array is the same as a list; for a two dimensional array the slicing is formatted as [row number, column number]. For example:

# %%
#Extract the 0 position row
b[0,:]  #the colon means give all elements along that dimension

#Extract 3 position column
b[:,3]

#Extract the 2 and 3 position columns
b[:,2:4] # The colon is used to define a numeric vector between the two numbers

#Extract 0 and 3 position rows
b[[0,3],:] # The list ([0,3]) is used to identify the indexes to be extracted

#Extract the value in the 2 position row and 3 position column
b[2,3]

# If you run this cell you will get the output only from the last part of the script,
# if you want to see the outcome of every part, just copy and paste the code in another code cell

# %%
b[2,3]

# %% [markdown]
# In the data frame that you created earlier, you can use a similar notation to extract values based on the row and column indexes. It is formatted as `.iloc[row index, column index]`.
#
# As you see in the previous practices, `iloc` and `loc` are key methods to explore, filter and manipulate data uisng pandas. So make sure you understand how that work.

# %%
c.iloc[23,1]

# %% [markdown]
# Data frames can have named rows and columns, which can be used for indexing. It is formatted as `loc[row name, column name]`

# %%
c.loc[23,'b']

# %% [markdown]
# You can also reference the column names themselves using dot notation, for example:

# %%
#Return all the values in the column called "a"
c.a

# %%
#A different way of returning the column called "a"
c["a"]

# %%
#Yet another way of returning the column called "a"
c.loc[:,"a"]

# %% [markdown]
# We can also find out what a data frame's column names are using the `columns` attribute:

# %%
c.columns

# %% [markdown]
# There are many ways you can rename the columns, here one of those:

# %%
c = c.rename(columns={'a': 'Year', 'b': 'Count'})
c.head()

# %% [markdown]
# # Challenge No 1:
#
# 1. Using a Dictionary, create a dataframe (table), with at least 4 columns and more than 100 rows. How come you can create this among data from scratch without defining every single row of data?
# 2. Using the appropriate method, create a new DataFrame containing only the first 30 rows and the first 3 columns of the original DataFrame. Name this new DataFrame subset_df.
# 3. Using the appropriate method, filter the rows from the original dataframe where a numerical attribute(column) is greater than a particular numerical value, and find another categorical attribute that is equal to a specific string or text. Name this new DataFrame filtered_df.
# 4. Check this website https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html and apply the methods, mean, standard deviation, group_by to run fundamental statistical analysis of your created data frame.
# 5. Make sure you comment on your code and describe how you are manipulating the data.

# %%
#1)create 4 arrays, 3 with random numbers and 1 with a random selection of A B or C
#randint is used to fill the arrays with random integers within the range
a = np.random.randint(0, 400, 100)
b = np.random.randint(0, 400, 100)
c = np.random.randint(0, 400, 100)
d = np.random.choice(['A', 'B', 'C'],100)

# %%
#turn arrays into dataframe
e = pd.DataFrame({'numbers a':a,'numbers b':b,'numbers c':c,'letters':d})
e.shape
# Out:
# (100, 4)

# %%
#2)Select the first 30 rows of the first 3 columns using iloc
subset_df = e.iloc[:30, :3]
subset_d

# %%
#3)select rows where numbers in collumn 1 > 200 and the letters in collumn 4 == C
filtered_df = e[(e['numbers a'] > 200) & (e['letters'] == 'C')]
print(filtered_df)

# %%
#4)find the mean for the numerical data
mean = e.mean(numeric_only=True) 
#find the standard deviation for the numerical data
std = e.std(numeric_only=True)
print(mean)
print(std)

# %%
#find the mean for each column grouped by the unique values in the letter column
grouped_mean = e.groupby('letters')[['numbers a', 'numbers b', 'numbers c']].mean()
#find the standard devieation for each column grouped by the unique values in the letter column
grouped_std = e.groupby('letters')[['numbers a', 'numbers b', 'numbers c']].std()
print(grouped_std)
print(grouped_mean)

# %% [markdown]
# ## Reading External Data
#
# For most urban analytics you are more likely to be reading external data into Python rather than creating data objects from scratch. Tabular data is commonly stored in text files such as CSV, or on spreadsheets; and explicitly spatial data will likely be stored in formats such as Shapefiles.
#
# A common way in which data can be stored externally are the use of `.csv` files. These are text files, and have a very simple format where columns of attributes are separated by a comma, and each row by a carriage return.
#
# **Note:** There are a range of different delimiters which can be used in addition to a comma, with the most common being tab; although sometimes characters not commonly used such as bar/pipe (`|`) will be used.
#
# In the following example you will read in some U.S. Census Bureau, 2010-2014 American Community Survey (ACS) 5-Year Estimate data. This was downloaded from the [American Fact Finder](https://factfinder.census.gov) website. The data are for census tracts in San Francisco and relate to median earnings in the past 12 months.
#
# Reading CSV files into Python uses pandas `read_csv` function:

# %%
#Read CSV file - creates a data frame called earnings
earnings = pd.read_csv("data/ACS_14_5YR_S2001_with_ann.csv")

#Show column headings
earnings.columns

#UID - Tract ID
#pop - estimated total population over 16 with income
#pop_m - estimated total population over 16 with income (margin of error)
#earnings - estimated median earnings
#earnings_m - estimated median earnings (margin of error)

# %% [markdown]
# It is possible to show the structure of the object using the `info()` method.

# %%
earnings.info()

# %% [markdown]
# This shows that the object is a Pandas data frame with 197 rows and 5 variables. For each of the attributes the class is shown (e.g. `int64` indicates integer). The `read_csv()` function guesses the column types when the data are read into Python.
#
# One issue you might notice is that the earnings and earnings_m variables have been read in as an `object`. The reason these columns were not read as integers (like the UID, pop, pop_m) is the presence of two non-numeric values which are shown as "*" and "-". In ACS data these two symbols indicate that the sample sizes were either no sample observations or too few sample observations to make a calculation.
#
# Issues such as these are quite common when reading in external data; and we will look at how this can be corrected later.

# %% [markdown]
# **However!**: Not all tabular data are distributed as textfiles, and another very common format is Microsoft Excel format - .xls or xlsx.
#
# The following code downloads an Excel File from the [London Data Store](https://data.london.gov.uk/) and then reads this into Python.
#
# >Note: In the following code you will fetch data from a URL, something that is new at this point, I will describe better the importance of working with web services later in the next seccion of this workbook.

# %%
import urllib.request
url = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xlsx"
urllib.request.urlretrieve(url, "data/UK_House_price_index.xlsx")

# %%
#Read workbook
house_price = pd.read_excel("data/UK_House_price_index.xlsx", sheet_name='Average price')
house_price

# %% [markdown]
# ## Reading Spatial Data
#
# Spatial data are distributed in a variety of formats, but Shapefiles. are maybe the most common format. These can be read into Python using a number of packages, however, is illustrated here with "geopandas". You have experienced GeoPandas already in the previous module, but here you can practice once again.
#
# The following code loads the house composition from the latest Census in the UK downloaded from the [NOMIS Data](https://www.nomisweb.co.uk/datasets/c2021ts003).

# %%
# Loading house data 
import pandas as pd
house_data = pd.read_excel("data/householdcomposition.xlsx")
pd.options.display.max_columns = None
house_data.head()

# %% [markdown]
# You have notice by using the `.info()` and .columns methods that our dataset have some issues than need to resolve before we movee fowards. The initial issue is the name of the columns, and the `Dytpe`
# of the columns, instead of having a string and numerical or float/intenger values, we have object, which tells us that there is something on those columns that might need to get removed.

# %%
#Let's start by renaming some of the most important columns names.
house_data.rename(columns={'2021 super output area - middle layer':'2021_MSOA_name','Unnamed: 1': 'MSOA21CD', 'Total: All households': 'All_households', 'One-person household':'1Person_household'}, inplace=True)
house_data.head()

# %%
house_data['2021_MSOA_name'] = house_data['2021_MSOA_name'].astype(str)
house_data['MSOA21CD'] = house_data['MSOA21CD'].astype(str)

# %% [markdown]
# Here we are loading a shapefile from the latest version of census boundaries included in the The Open Geography portal from the Office for National Statistics (ONS) https://geoportal.statistics.gov.uk/

# %%
#Loading geopandas
import geopandas as gpd

# Read Shapefile
shapefile_path = "data/MSOA_2021_BGC/MSOA_2021_EW_BGC_V2.shp"
gdf_shapefile = gpd.read_file(shapefile_path)

# %%
gdf_shapefile.crs

# %%
gdf_shapefile.explore()

# %%
gdf_wgs84 = gdf_shapefile.to_crs(epsg=4326)

# %%
gdf_wgs84.crs

# %% [markdown]
# Now, we can also create a Dictionary to define which columns we would like to keep in a more curated dataframe

# %%
keep_cols = [
    "MSOA21CD",
    "MSOA21NM",
    "geometry",
]
msoa_shp = gdf_wgs84[keep_cols]
msoa_shp.head()

# %%
msoa_shp.explore()

# %%
merged_gdf = msoa_shp.merge(house_data, on='MSOA21CD')

# %%
#This is a "magic", which allows figures to be rendered inside the notebook (it only needs to be run once in Notebook)
# %matplotlib inline

merged_gdf.explore(column='All_households', cmap='Blues')

# %% [markdown]
# As you already know, a geo data frame is structured like a regular data frame, with rows being observations and columns being attributes on those observations. The key difference is that a geo data frame has a `geometry` column that contains the spatial coordinates on each record. You can access the `geometry` like you would any column:

# %%
#Show the top rows of the geometry column
merged_gdf.geometry.head()

# %%
pip install leafmap

# %% [markdown]
# Leafmap is a popular new Python package for interactive mapping and geospatial analysis with minimal coding in a Jupyter environment.  Get more information in its documentation web site: https://leafmap.org/

# %%
import leafmap

m = leafmap.Map()
m

# %%
# You can use this handy web map to get the centre of the map, zoom level, and other great resources for web map development 
m = leafmap.Map(center=[54, -1], zoom=6)
m.add_gdf(merged_gdf, layer_name="Housing")
m

# %% [markdown]
# ## Creating Spatial Data
#
# Sometimes it is necessary to create a spatial object from scratch, which is most common for point data given that only a single co-ordinate is required for each feature. This can be achieved by building a `GeoDataFrame()` object and is used within this example to create a 311 point dataset. 311 data record non emergency calls within the US, and in this case are those which occurred within San Francisco between January and December 2016. The 311 data used here have been simplified from the [original](https://data.sfgov.org/City-Infrastructure/Case-Data-from-San-Francisco-311-SF311-/vw6y-z8j6/data) data to only a few variables, and those calls without spatial references have been removed.

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
# Read csv into Python
data_311 = pd.read_csv("data/311.csv")
# Have a look at the structure
data_311.head()

# %% [markdown]
# Each spatial object in a geo data frame must be an point, line or polygon. GeoPandas uses spatial object types from the shapely package. In this example we use the `Point` type.

# %%
# Create a geo data frame
from shapely.geometry import Point  # import just the Point class from the shapely package
geom = [Point(xy) for xy in zip(data_311.Lon, data_311.Lat)] #create a list of latitude, longitude pairs
SP_311 = gpd.GeoDataFrame(data_311, crs=merged_gdf.crs, geometry=geom)

# %%
# Show the results
SP_311.plot()

# %% [markdown]
# ## Subsetting Data
#
# It is often necessary to subset data; either restricting a data frame to a set of columns or rows; or in the case of spatial data, creating an extract for a particular set of geographic features. Subsetting can occur in a number of different ways

# %%
#Get the frequencies by the categories used within the 311 data
data_311.Category.value_counts()

# %%
# Use the loc method to extract rows from the data which relate to Sewer Issues
sewer_issues = data_311.loc[data_311.Category=="Sewer Issues", :]

# Use the square brackets "[]" to perform the same task
sewer_issues = data_311[data_311.Category=="Sewer Issues"]
sewer_issues.head()  #check out the first rows

# %%
# Extract the IDs for the "Sewer Issues"
sewer_issues_IDs = data_311.loc[data_311.Category=="Sewer Issues", "CaseID"]
sewer_issues_IDs.head()  #check out the first elements

# %% [markdown]
# Subsetting can also be useful for spatial data. In the example below we can list all the regions in England, and using simple queries we can remove, overwrite, and plot only certain rows inside our initial spatial data frame. For example consider you need to remove an area from your original dataset, and you you the code or value to use for the querie, so you can use something like:

# %%
regions_england = gpd.read_file("data/Regions_(December_2021)/RGN_DEC_2021_EN_BGC.shp")

# %%
regions_england.explore('RGN21NM')

# %%
regions_name = regions_england['RGN21NM'].value_counts()
regions_name

# %%
regions_england[regions_england.RGN21NM != "South East"].plot() # Removes South East from the plot

# %%
regions_england[regions_england.RGN21NM == "North East"].plot() # Only plots North East

# %%
regions_england = regions_england[regions_england.RGN21NM != "London"] # Overwrites the regions_england object
regions_england.plot()

# %% [markdown]
# ## Clipping Spatial Data
#
# Clipping is a process of subsetting using overlapping spatial data. The following code uses the outline of the coast of the U.S. to clip the boundaries of the Census Track Shapefile, another geodata frame object. Note: it is a little slow.
#
# The Census Tracts Shapefile was downloaded from the [SF OpenData](https://data.sfgov.org/Geographic-Locations-and-Boundaries/Census-2010-Tracts-for-San-Francisco/rarb-5ahf/data).
#
# > Note: You will find an error; you should be able to fix it at this level.

# %%
#Read in coastal outline (Source from - https://www.census.gov/geo/maps-data/data/cbf/cbf_counties.html)
coast = gpd.read_file("data/Census Tracts USA/cb_2015_us_county_500k.shp")
SF = gpd.read_file("data/Census Tracts USA/tl_2010_06075_tract10.shp")

coast_single = coast.unary_union  #merges the US counties into a single object
SF_clipped_geoms = SF.intersection(coast_single) # Clip the SF spatial data frame object to the coastline - just returns geometries
SF_clipped = SF.copy() #make a copy of the SF dataframe
SF_clipped['geometry'] = SF_clipped_geoms #replace the old geometries with the clipped geometries
SF_clipped = SF_clipped[SF_clipped.intersects(SF_clipped_geoms.unary_union)] #subset to just the observations in the clipped area

#Plot the results
SF_clipped.plot()

# %%
SF_single = SF_clipped.unary_union  #merges SF tracts into a single object
SP_311_PIP = SP_311[SP_311.intersects(SF_single)] # Select the 331 points data that intersect with San Francisco
SP_311_PIP.plot()

# %%
SP_311_PIP.info()

# %% [markdown]
# ## Merging Tabular Data
#
# So far you have utilized a single data frame or spatial object; however, it is often the case that in order to generate information, data from multiple sources are required. Where data share a common "key", these can be used to combine / link tables together. This might for example be an identifier for a zone; and is one of the reasons why most statistical agencies adopt a standard set of geographic codes to identify areas.
#
# In the earlier imported data "earnings" this included a UID column which relates to a Tract ID. We can now import an additional data table called bachelors - this also includes the same ID.

# %%
#Read CSV file - creates a data frame called earnings
bachelors = pd.read_csv("data/ACS_14_5YR_S1501_with_ann.csv")
bachelors.head()

#UID - Tract ID
#Bachelor_Higher - Bachelor degree or higher %
#Bachelor_Higher_m - Bachelor degree or higher % (margin of error)

# %% [markdown]
# Using the matching ID columns on both datasets we can link them together to create a new object with the `merge()` function in pandas:

# %%
#Perform the merge
SF_Tract_ACS = pd.merge(earnings, bachelors, left_on="UID", right_on="UID")
SF_Tract_ACS = pd.merge(earnings, bachelors, on="UID") # An alternative method to the above, but a shortened version as the ID columns are the same on both data frames
#there are many more options - for more details type help(pd.merge)

#The combined data frame now looks like
SF_Tract_ACS.head() # shows the top of the data frame

# %% [markdown]
# ## Removing and Creating Attributes
#
# It is sometimes necessary to remove variables from a tabular object or to create new values. In the following example we will remove some unwanted columns in the SF_clipped object, leaving just the zone id for each polygon.

# %%
#Remind yourself what the data look like...
SF_clipped.head()

# %%
SF_clipped2 = SF_clipped[["GEOID10", "geometry"]] #Makes a new version of the geo data frame with just the values of the GEOID10 and geometry columns

#The data frame within the data slot now looks as follows
SF_clipped2.head()

# %% [markdown]
# These tract ID are supposed to match with those in the "SF_Tract_ACS" object, however, if you are very observant you will notice that there is one issue; the above have a leading zero.

# %%
SF_Tract_ACS.head() # show the top of the SF_Tract_ACS object

# %% [markdown]
# As such, in this instance we will create a new column on the SF_Tract_ACS data frame with a new ID that will match the SF GEOID10 column. We can achieve this using the square brackets (`[]`) notation and will call this new variable "GEOID10".

# %%
# Creates a new variable with a leading zero
SF_Tract_ACS['GEOID10'] = "0" + SF_Tract_ACS.UID.astype(str) #need to convert the UID column to strings before prepending the zero
SF_Tract_ACS.head()

# %% [markdown]
# If you remember from earlier in this practical, the earnings data had some values that were stored as "objects" rather than floats or integers, and the same is true for both the bachelors data; and now the combined `SF_Tract_ACS` object. We can check this again as follows:

# %%
SF_Tract_ACS.info()

# %% [markdown]
# We can also remove the UID column. A quick way of doing this for a single variable is to use the `drop()` method:

# %%
SF_Tract_ACS = SF_Tract_ACS.drop('UID', axis=1)  #axis=1 indicates to drop a column (axis=0 is for rows)

# %% [markdown]
# We will now convert the object variables to numbers. The first stage will be to remove the "-" and "**" characters from the variables with the `replace` function, replacing these with NA values.

# %%
#Replace the "-" and "*" characters
import numpy as np
SF_Tract_ACS.loc[SF_Tract_ACS.earnings=='-', 'earnings'] = np.nan #replace the "-" values with NA
SF_Tract_ACS.loc[SF_Tract_ACS.earnings_m=='**', 'earnings_m'] = np.nan #replace the "**" values with NA
SF_Tract_ACS.loc[SF_Tract_ACS.Bachelor_Higher=='-', 'Bachelor_Higher'] = np.nan #replace the "-" values with NA
SF_Tract_ACS.loc[SF_Tract_ACS.Bachelor_Higher_m=='**', 'Bachelor_Higher_m'] = np.nan #replace the "-" values with NA

# %% [markdown]
# We will now convert these to numeric values:

# %%
SF_Tract_ACS.earnings = SF_Tract_ACS.earnings.astype(float)
SF_Tract_ACS.earnings_m = SF_Tract_ACS.earnings_m.astype(float)
SF_Tract_ACS.Bachelor_Higher = SF_Tract_ACS.Bachelor_Higher.astype(float)
SF_Tract_ACS.Bachelor_Higher_m = SF_Tract_ACS.Bachelor_Higher_m.astype(float)

# %%
SF_Tract_ACS.info()

# %% [markdown]
# Now all the variables other than the "GEOID10" are stored as integers or floats:

# %% [markdown]
# ## Merging Spatial Data
#
# It is also possible to join tabular data onto a spatial object (e.g. a geo data frame) in the same way as with regular data frames. In this example, we will join the newly created `SF_Tract_ACS` data onto the `SF_clipped` data frame.

# %%
SF_clipped = pd.merge(SF_clipped2, SF_Tract_ACS, on="GEOID10") # merge
SF_clipped.head() #show the attribute data

# %% [markdown]
# ## Spatial Joins
#
# Earlier in this practical we created a geo data frame which we later cropped using the `intersects()` method to create the `SP_311_PIP` object. As a reminder of what this looks like it is plotted below:

# %%
SP_311_PIP.explore(tiles="CartoDB positron")

# %% [markdown]
# We will now clean up the associated data frame by removing all of the attributes apart from the category and geometry.

# %%
SP_311_PIP = SP_311_PIP[["Category", "geometry"]] #subset data
SP_311_PIP.head()

# %% [markdown]
# The `intersects()` method was used to clip a dataset to an extent earlier, essentially a [point in polygon](https://en.wikipedia.org/wiki/Point_in_polygon) function. In contrast, the spatial join (`sjoin()`) function performs the point in polygon action and has a really useful feature that it also appends the attributes of the polygon to the point. For example, we might be interested in finding out which census tracts each of the 311 calls resides within. As such, we will implement another point in polygon analysis to create a new object `SF_clipped_311`:

# %%
SF_clipped_311 = gpd.sjoin(SP_311_PIP, SF, how='inner') # point in polygon
#Cleanup the attributes
SF_clipped_311 = SF_clipped_311[["GEOID10","Category","geometry"]]
#Show the top rows of the data
SF_clipped_311.head()

# %% [markdown]
# ## Writing and saving your processed data
#
# In order to share data it is often useful to write data frames or spatial objects back out of Python as external files. This is very simple, and Python supports multiple formats. In these examples, a CSV file and a Shapefile are both created.

# %%
#In this example, we write out a CSV file with the geo data frame SF_clipped_311
SF_clipped_311.to_csv("data/311_Tract_Coded.csv")

# %% [markdown]
# This has created a CSV file "311_Tract_Coded.csv" in your working directory; we will use this in the next practical class - "Basic SQL".
#
# It is also possible to write out a Shapefile

# %%
#This will write out a Shapefile for San Francisco - note, as the column names are a little longer than are allowed within a Shapefile and as such are automatically shortened.
SF_clipped.to_file("data/SF_clipped.shp") #the default is Shapefile, but other spatial formats are supported

# %% [markdown]
# # Working with Web Services
#
# Nowadays, you have access to spatial and numerical data from multiple data sources; many great spatial data sources will include another type of access that isn't often very popular among the spatial data scientist communities, as we tend to use downloaded data to make any analysis. We consider that only through downloaded data will we be able to work more efficiently. Somehow, those caveats are true. However, we also need to consider the rapid improvement in computational capabilities, the use of the Web and Cloud GIS services, and take advantage of the faster internet connections we can access nowadays. As you probably already know, spatial data come in multiple formats, whether the type of data we need to store or the natural phenomena we try to represent; numerous types of spatial web services serve various purposes.
#
# To get to that point, if we work with a window-interface tool like QGIS or ArcGIS, the connection to the spatial data is usually established on local directories; depending on the type of project, you might need to work using a direct connection to a particular spatial database. However, in this example, I will show you how to use web services, in particular spatial web services, to get some numerical and spatial data, load that into your computer memory, process the information and then get the outcomes you can later include as an outcome of any spatial analysis.
#
# Generally, you can think of a web service as a piece of software designed to allow the interaction and communication between different applications over the internet. That is the keystone! You know that the transmission of your data goes through the internet, which means that a web service enables the exchange of data and, in many cases, also functionality between multiple systems, allowing them to work together seamlessly.
#
# Web services use standard web protocols, such as HTTP, and often communicate using formats like XML or JSON. They enable interoperability, scalability, and integration in distributed computing environments.
#
# ## Web Services in Urban Analytics:
#
# In urban analytics, web services facilitate the seamless exchange and analysis of geospatial data, which is vital for understanding and managing urban environments. Spatial Web services provide a platform for sharing geographic information, conducting spatial studies, and delivering real-time data to support urban planning, transportation management, environmental monitoring, and more decision-making processes.
#
# ## Common Spatial Web Services:
#
# Having spatial web services standards is extremely important., the standards are the glue to geospatial information interoperability, and are used by thousands of organizations across the globe and represented in millions of lines of code. They are backed by international organizations, used in proposals, and implemented to speed up the process of innovation. If you want to explore all the geospatial standands, take a look at the OGC web https://www.ogc.org/standards/ IN the following section I will describe the most common spatial web services you migth find when you work with spatial data.
#
# ### Web Map Services (WMS):
#
# A WMS services is a standard protocol for serving georeferenced **map images** over the web. It allows clients to request maps from a server, which then generates and returns the map images.
#
# ### Web Feature Services (WFS):
#
# A WFS service is a standard for serving and exchanging **vector** data over the web. It enables clients to request and retrieve features (geospatial entities) from a server, supporting more complex data interactions compared to WMS, including the editing and symbology capabilites.
#
# ### GeoJSON/JSON Web Services:
#
# These web services use the JSON format to transmit geospatial data. They are often employed for simple and lightweight data exchange, suitable for web applications and APIs. These web services are popular for transmitting spatial data between clients and servers due to their simplicity and human-readability.
#
# ### RESTful APIs (Representational State Transfer):
#
# RESTful APIs follow the principles of REST architecture, providing a set of rules for building web services. They use standard **HTTP methods (GET, POST, PUT, DELETE)** for data manipulation and are often implemented in the form of web APIs. APIs are versatile and widely adopted in numerous geospatial applications and are widely implemented allowing developers to access, manipulate, and retrieve geographic data programmatically.
#
# ### APIs
#
# Application Programming Interface (APIs) represent a 'gate' or otherwise a platform that enables a client (that is you) to interact with a server (for example [Glasgow Open Data](https://developer.glasgow.gov.uk/),  [opendata.bristol.gov.uk](https://opendata.bristol.gov.uk/)).
#
# According to @amazonWhatAPI:
# > In the context of APIs, the word Application refers to any software with a distinct function. Interface can be thought of as a contract of service between two applications. This contract defines how the two communicate with each other using requests and responses. Their API documentation contains information on how developers are to structure those requests and responses.
#
# The client's software (this might be R pr Python for example) sends a request to the server requesting specific data. The response is the data the client asked.
#
# More commonly, the client might be a mobile phone app (e.g. train network status app) and the server is the network operator's server.
#
# APIs can be private or public types. For more inthe description from @amazonWhatAPI [here](https://aws.amazon.com/what-is/api/#:~:text=API%20stands%20for%20Application%20Programming,other%20using%20requests%20and%20responses.)

# %% [markdown]
# In the following example, we will use the Glasglow Open Data API to fetch data from the bike rentals.
# 1. Please go to https://developer.glasgow.gov.uk/
# 2. Sign Up and explore the available APIs
# 3. Go to https://developer.glasgow.gov.uk/api-details#api=mobility&operation=get-getrentals and explore the available parameters to fetch data from the Bike Rentals in Glasgow.
# 4. To your right, you will see a tiny green button, **Try it**, where you can play with the API requests and see if you can get an appropriate response for the last 3 weeks of data. Help: Just add the parameter `3_weeks_ago` in the Value box and then click on the **Send** button to see how the API responds. This is what we will apply but using python to write some analysis.

# %%
import requests
import pandas as pd
import geopandas as gpd

# Let's describe the url, it is usually easier to do it like this, so in the future, you can easily update the URL
url_bikes = "https://api.glasgow.gov.uk/mobility/v1/get_rentals?startDate=2022-05-01&endDate=2023-05-01"
# Making the query to the web server, using the Get method from the requests library 
response = requests.get(url_bikes)
response
# Out:
# <Response [200]>

# %% [markdown]
# You see the response has a 200 code, which means the request as satisfactory, here the possible other codes you can get and hence you can see if your code has any issue. https://www.w3schools.com/tags/ref_httpmessages.asp

# %%
#Now we get the response from the web server, we need to translate that into a format we can manipulate, like JSON.
data = response.json()
data
# careful here you will get a huge outcome; explore what you get, and then you can clear this cell outcome
# Out:
# {'metadata': {'pageSize': 10000, 'page': 1, 'hasNextPage': True},
#  'data': [{'created': '2022-10-21T13:09:57.926Z',
#    'updated': '2022-10-21T13:09:57.926Z',
#    'cityId': '237',
#    'bikeId': '116870',
#    'startDate': '2022-05-01T00:01:40Z',
#    'startPlaceId': '264299',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Broomielaw',
#    'startPlaceStationNumber': 8413,
#    'startPlaceLat': 55.8565998,
#    'startPlaceLong': -4.26352143,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:02:36Z',
#    'endPlaceId': '264299',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Broomielaw',
#    'endPlaceStationNumber': 8413,
#    'endPlaceLat': 55.8565998,
#    'endPlaceLong': -4.26352143,
#    'durationSeconds': 56,
#    'isInvalid': False,
#    'price': 2.0,
#    'isEbike': True},
#   {'created': '2022-10-21T13:09:57.975Z',
#    'updated': '2022-10-21T13:09:57.975Z',
#    'cityId': '237',
#    'bikeId': '143384',
#    'startDate': '2022-05-01T00:04:17Z',
#    'startPlaceId': '28521547',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'King Street South',
#    'startPlaceStationNumber': 8230,
#    'startPlaceLat': 55.85586,
#    'startPlaceLong': -4.24695,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:22:34Z',
#    'endPlaceId': '3812776',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Alexandra Park (south entrance) Alexandra Parade Railway Station',
#    'endPlaceStationNumber': 8457,
#    'endPlaceLat': 55.863128,
#    'endPlaceLong': -4.210282,
#    'durationSeconds': 1097,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.026Z',
#    'updated': '2022-10-21T13:09:58.026Z',
#    'cityId': '237',
#    'bikeId': '129744',
#    'startDate': '2022-05-01T00:04:24Z',
#    'startPlaceId': '266171',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'University of Glasgow (East) - ELECTRIC',
#    'startPlaceStationNumber': 8435,
#    'startPlaceLat': 55.87176257,
#    'startPlaceLong': -4.27806973,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:10:08Z',
#    'endPlaceId': '264302',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Botanic Gardens - ELECTRIC',
#    'endPlaceStationNumber': 8417,
#    'endPlaceLat': 55.87827801,
#    'endPlaceLong': -4.28848743,
#    'durationSeconds': 344,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.076Z',
#    'updated': '2022-10-21T13:09:58.076Z',
#    'cityId': '237',
#    'bikeId': '143168',
#    'startDate': '2022-05-01T00:04:29Z',
#    'startPlaceId': '349455',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'startPlaceStationNumber': 8444,
#    'startPlaceLat': 55.85191762,
#    'startPlaceLong': -4.29449022,
#    'startChannelId': None,
#    'endDate': '2022-05-01T02:57:49Z',
#    'endPlaceId': '349455',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'endPlaceStationNumber': 8444,
#    'endPlaceLat': 55.85191762,
#    'endPlaceLong': -4.29449022,
#    'durationSeconds': 10400,
#    'isInvalid': False,
#    'price': 6.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.126Z',
#    'updated': '2022-10-21T13:09:58.126Z',
#    'cityId': '237',
#    'bikeId': '143248',
#    'startDate': '2022-05-01T00:04:40Z',
#    'startPlaceId': '349455',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'startPlaceStationNumber': 8444,
#    'startPlaceLat': 55.85191762,
#    'startPlaceLong': -4.29449022,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:21:31Z',
#    'endPlaceId': '264295',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - St Enoch Square',
#    'endPlaceStationNumber': 8410,
#    'endPlaceLat': 55.85682863,
#    'endPlaceLong': -4.25529242,
#    'durationSeconds': 4611,
#    'isInvalid': False,
#    'price': 3.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.175Z',
#    'updated': '2022-10-21T13:09:58.175Z',
#    'cityId': '237',
#    'bikeId': '139406',
#    'startDate': '2022-05-01T00:05:59Z',
#    'startPlaceId': '19164571',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Central Station',
#    'startPlaceStationNumber': 8401,
#    'startPlaceLat': 55.86077565,
#    'startPlaceLong': -4.2585969,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:28:50Z',
#    'endPlaceId': '6269629',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Battlefield - ELECTRIC',
#    'endPlaceStationNumber': 8466,
#    'endPlaceLat': 55.82739548,
#    'endPlaceLong': -4.26531851,
#    'durationSeconds': 4971,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.224Z',
#    'updated': '2022-10-21T13:09:58.224Z',
#    'cityId': '237',
#    'bikeId': '143068',
#    'startDate': '2022-05-01T00:06:17Z',
#    'startPlaceId': '349455',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'startPlaceStationNumber': 8444,
#    'startPlaceLat': 55.85191762,
#    'startPlaceLong': -4.29449022,
#    'startChannelId': None,
#    'endDate': '2022-05-01T02:57:36Z',
#    'endPlaceId': '349455',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'endPlaceStationNumber': 8444,
#    'endPlaceLat': 55.85191762,
#    'endPlaceLong': -4.29449022,
#    'durationSeconds': 10279,
#    'isInvalid': False,
#    'price': 6.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.277Z',
#    'updated': '2022-10-21T13:09:58.277Z',
#    'cityId': '237',
#    'bikeId': '143118',
#    'startDate': '2022-05-01T00:09:25Z',
#    'startPlaceId': '266218',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Partick Interchange',
#    'startPlaceStationNumber': 8423,
#    'startPlaceLat': 55.8697069,
#    'startPlaceLong': -4.30845916,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:22:54Z',
#    'endPlaceId': '349455',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'endPlaceStationNumber': 8444,
#    'endPlaceLat': 55.85191762,
#    'endPlaceLong': -4.29449022,
#    'durationSeconds': 809,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.327Z',
#    'updated': '2022-10-21T13:09:58.327Z',
#    'cityId': '237',
#    'bikeId': '143143',
#    'startDate': '2022-05-01T00:09:39Z',
#    'startPlaceId': '349455',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'startPlaceStationNumber': 8444,
#    'startPlaceLat': 55.85191762,
#    'startPlaceLong': -4.29449022,
#    'startChannelId': None,
#    'endDate': '2022-05-01T02:57:40Z',
#    'endPlaceId': '349455',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'endPlaceStationNumber': 8444,
#    'endPlaceLat': 55.85191762,
#    'endPlaceLong': -4.29449022,
#    'durationSeconds': 10081,
#    'isInvalid': False,
#    'price': 6.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.377Z',
#    'updated': '2022-10-21T13:09:58.377Z',
#    'cityId': '237',
#    'bikeId': '139370',
#    'startDate': '2022-05-01T00:10:11Z',
#    'startPlaceId': '349461',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Queens Park West',
#    'startPlaceStationNumber': 8448,
#    'startPlaceLat': 55.83504205,
#    'startPlaceLong': -4.2723459,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:24:55Z',
#    'endPlaceId': '264299',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Broomielaw',
#    'endPlaceStationNumber': 8413,
#    'endPlaceLat': 55.8565998,
#    'endPlaceLong': -4.26352143,
#    'durationSeconds': 884,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.427Z',
#    'updated': '2022-10-21T13:09:58.427Z',
#    'cityId': '237',
#    'bikeId': '116917',
#    'startDate': '2022-05-01T00:12:35Z',
#    'startPlaceId': '19164571',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Central Station',
#    'startPlaceStationNumber': 8401,
#    'startPlaceLat': 55.86077565,
#    'startPlaceLong': -4.2585969,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:33:56Z',
#    'endPlaceId': '42446574',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Corkerhill Railway Station',
#    'endPlaceStationNumber': 8208,
#    'endPlaceLat': 55.83635496,
#    'endPlaceLong': -4.33514877,
#    'durationSeconds': 1281,
#    'isInvalid': False,
#    'price': 4.0,
#    'isEbike': True},
#   {'created': '2022-10-21T13:09:58.479Z',
#    'updated': '2022-10-21T13:09:58.479Z',
#    'cityId': '237',
#    'bikeId': '81699',
#    'startDate': '2022-05-01T00:13:55Z',
#    'startPlaceId': '3812886',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Glasgow Green - Saltmarket / Clyde Place',
#    'startPlaceStationNumber': 8460,
#    'startPlaceLat': 55.85319436,
#    'startPlaceLong': -4.24698293,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:18:31Z',
#    'endPlaceId': '3812886',
#    'endPlaceCityId': '237',
#    'endChannelId': '15',
#    'endPlaceName': 'ELECTRIC - Glasgow Green - Saltmarket / Clyde Place',
#    'endPlaceStationNumber': 8460,
#    'endPlaceLat': 55.85319436,
#    'endPlaceLong': -4.24698293,
#    'durationSeconds': 276,
#    'isInvalid': True,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.529Z',
#    'updated': '2022-10-21T13:09:58.529Z',
#    'cityId': '237',
#    'bikeId': '116901',
#    'startDate': '2022-05-01T00:16:08Z',
#    'startPlaceId': '266171',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'University of Glasgow (East) - ELECTRIC',
#    'startPlaceStationNumber': 8435,
#    'startPlaceLat': 55.87176257,
#    'startPlaceLong': -4.27806973,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:21:12Z',
#    'endPlaceId': '264304',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Kelvingrove Art Gallery - ELECTRIC',
#    'endPlaceStationNumber': 8420,
#    'endPlaceLat': 55.86835244,
#    'endPlaceLong': -4.28940475,
#    'durationSeconds': 304,
#    'isInvalid': False,
#    'price': 2.0,
#    'isEbike': True},
#   {'created': '2022-10-21T13:09:58.577Z',
#    'updated': '2022-10-21T13:09:58.577Z',
#    'cityId': '237',
#    'bikeId': '139442',
#    'startDate': '2022-05-01T00:16:38Z',
#    'startPlaceId': '264392',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Argyle Street Railway Station',
#    'startPlaceStationNumber': 8411,
#    'startPlaceLat': 55.85757531,
#    'startPlaceLong': -4.24997628,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:24:57Z',
#    'endPlaceId': '349452',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Bridgeton',
#    'endPlaceStationNumber': 8441,
#    'endPlaceLat': 55.8489394,
#    'endPlaceLong': -4.22682345,
#    'durationSeconds': 499,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.627Z',
#    'updated': '2022-10-21T13:09:58.627Z',
#    'cityId': '237',
#    'bikeId': '139365',
#    'startDate': '2022-05-01T00:17:59Z',
#    'startPlaceId': '349455',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'startPlaceStationNumber': 8444,
#    'startPlaceLat': 55.85191762,
#    'startPlaceLong': -4.29449022,
#    'startChannelId': None,
#    'endDate': '2022-05-01T02:57:15Z',
#    'endPlaceId': '349455',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'endPlaceStationNumber': 8444,
#    'endPlaceLat': 55.85191762,
#    'endPlaceLong': -4.29449022,
#    'durationSeconds': 9556,
#    'isInvalid': False,
#    'price': 5.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.676Z',
#    'updated': '2022-10-21T13:09:58.676Z',
#    'cityId': '237',
#    'bikeId': '143392',
#    'startDate': '2022-05-01T00:18:04Z',
#    'startPlaceId': '264295',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - St Enoch Square',
#    'startPlaceStationNumber': 8410,
#    'startPlaceLat': 55.85682863,
#    'startPlaceLong': -4.25529242,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:37:11Z',
#    'endPlaceId': '349455',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'endPlaceStationNumber': 8444,
#    'endPlaceLat': 55.85191762,
#    'endPlaceLong': -4.29449022,
#    'durationSeconds': 1147,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.724Z',
#    'updated': '2022-10-21T13:09:58.724Z',
#    'cityId': '237',
#    'bikeId': '143093',
#    'startDate': '2022-05-01T00:18:06Z',
#    'startPlaceId': '349455',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'startPlaceStationNumber': 8444,
#    'startPlaceLat': 55.85191762,
#    'startPlaceLong': -4.29449022,
#    'startChannelId': None,
#    'endDate': '2022-05-01T02:57:57Z',
#    'endPlaceId': '349455',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'endPlaceStationNumber': 8444,
#    'endPlaceLat': 55.85191762,
#    'endPlaceLong': -4.29449022,
#    'durationSeconds': 9591,
#    'isInvalid': False,
#    'price': 5.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.777Z',
#    'updated': '2022-10-21T13:09:58.777Z',
#    'cityId': '237',
#    'bikeId': '143198',
#    'startDate': '2022-05-01T00:18:07Z',
#    'startPlaceId': '264295',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - St Enoch Square',
#    'startPlaceStationNumber': 8410,
#    'startPlaceLat': 55.85682863,
#    'startPlaceLong': -4.25529242,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:36:58Z',
#    'endPlaceId': '349455',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'endPlaceStationNumber': 8444,
#    'endPlaceLat': 55.85191762,
#    'endPlaceLong': -4.29449022,
#    'durationSeconds': 1131,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.827Z',
#    'updated': '2022-10-21T13:09:58.827Z',
#    'cityId': '237',
#    'bikeId': '142962',
#    'startDate': '2022-05-01T00:18:12Z',
#    'startPlaceId': '349455',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'startPlaceStationNumber': 8444,
#    'startPlaceLat': 55.85191762,
#    'startPlaceLong': -4.29449022,
#    'startChannelId': None,
#    'endDate': '2022-05-01T02:57:32Z',
#    'endPlaceId': '349455',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'endPlaceStationNumber': 8444,
#    'endPlaceLat': 55.85191762,
#    'endPlaceLong': -4.29449022,
#    'durationSeconds': 9560,
#    'isInvalid': False,
#    'price': 5.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.877Z',
#    'updated': '2022-10-21T13:09:58.877Z',
#    'cityId': '237',
#    'bikeId': '142979',
#    'startDate': '2022-05-01T00:18:28Z',
#    'startPlaceId': '349455',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'startPlaceStationNumber': 8444,
#    'startPlaceLat': 55.85191762,
#    'startPlaceLong': -4.29449022,
#    'startChannelId': None,
#    'endDate': '2022-05-01T02:57:33Z',
#    'endPlaceId': '349455',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'endPlaceStationNumber': 8444,
#    'endPlaceLat': 55.85191762,
#    'endPlaceLong': -4.29449022,
#    'durationSeconds': 9545,
#    'isInvalid': False,
#    'price': 5.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.927Z',
#    'updated': '2022-10-21T13:09:58.927Z',
#    'cityId': '237',
#    'bikeId': '143295',
#    'startDate': '2022-05-01T00:18:47Z',
#    'startPlaceId': '28521547',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'King Street South',
#    'startPlaceStationNumber': 8230,
#    'startPlaceLat': 55.85586,
#    'startPlaceLong': -4.24695,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:36:57Z',
#    'endPlaceId': '264308',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Mitchell Library',
#    'endPlaceStationNumber': 8425,
#    'endPlaceLat': 55.86478849,
#    'endPlaceLong': -4.27185237,
#    'durationSeconds': 1090,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:58.976Z',
#    'updated': '2022-10-21T13:09:58.976Z',
#    'cityId': '237',
#    'bikeId': '62416',
#    'startDate': '2022-05-01T00:19:55Z',
#    'startPlaceId': '264292',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'George Square - ELECTRIC',
#    'startPlaceStationNumber': 8406,
#    'startPlaceLat': 55.86155,
#    'startPlaceLong': -4.2494,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:33:20Z',
#    'endPlaceId': '6269626',
#    'endPlaceCityId': '237',
#    'endChannelId': '38',
#    'endPlaceName': 'Woodside (North) - ELECTRIC',
#    'endPlaceStationNumber': 8465,
#    'endPlaceLat': 55.87506105,
#    'endPlaceLong': -4.27067757,
#    'durationSeconds': 805,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.026Z',
#    'updated': '2022-10-21T13:09:59.026Z',
#    'cityId': '237',
#    'bikeId': '62282',
#    'startDate': '2022-05-01T00:20:03Z',
#    'startPlaceId': '264292',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'George Square - ELECTRIC',
#    'startPlaceStationNumber': 8406,
#    'startPlaceLat': 55.86155,
#    'startPlaceLong': -4.2494,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:31:27Z',
#    'endPlaceId': '264303',
#    'endPlaceCityId': '237',
#    'endChannelId': '38',
#    'endPlaceName': 'Kelvinbridge Subway',
#    'endPlaceStationNumber': 8418,
#    'endPlaceLat': 55.87500989,
#    'endPlaceLong': -4.28037107,
#    'durationSeconds': 684,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.079Z',
#    'updated': '2022-10-21T13:09:59.079Z',
#    'cityId': '237',
#    'bikeId': '129761',
#    'startDate': '2022-05-01T00:21:23Z',
#    'startPlaceId': '28521334',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Glasgow Central West',
#    'startPlaceStationNumber': 8216,
#    'startPlaceLat': 55.85853,
#    'startPlaceLong': -4.25973,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:37:52Z',
#    'endPlaceId': '349454',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Paisley Road Toll',
#    'endPlaceStationNumber': 8443,
#    'endPlaceLat': 55.85378,
#    'endPlaceLong': -4.279158,
#    'durationSeconds': 989,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.128Z',
#    'updated': '2022-10-21T13:09:59.128Z',
#    'cityId': '237',
#    'bikeId': '143237',
#    'startDate': '2022-05-01T00:22:23Z',
#    'startPlaceId': '349455',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'startPlaceStationNumber': 8444,
#    'startPlaceLat': 55.85191762,
#    'startPlaceLong': -4.29449022,
#    'startChannelId': None,
#    'endDate': '2022-05-01T02:57:56Z',
#    'endPlaceId': '349455',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'endPlaceStationNumber': 8444,
#    'endPlaceLat': 55.85191762,
#    'endPlaceLong': -4.29449022,
#    'durationSeconds': 9333,
#    'isInvalid': False,
#    'price': 5.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.18Z',
#    'updated': '2022-10-21T13:09:59.18Z',
#    'cityId': '237',
#    'bikeId': '143141',
#    'startDate': '2022-05-01T00:22:31Z',
#    'startPlaceId': '28521334',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Glasgow Central West',
#    'startPlaceStationNumber': 8216,
#    'startPlaceLat': 55.85853,
#    'startPlaceLong': -4.25973,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:22:52Z',
#    'endPlaceId': '28521334',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Glasgow Central West',
#    'endPlaceStationNumber': 8216,
#    'endPlaceLat': 55.85853,
#    'endPlaceLong': -4.25973,
#    'durationSeconds': 21,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.231Z',
#    'updated': '2022-10-21T13:09:59.231Z',
#    'cityId': '237',
#    'bikeId': '143141',
#    'startDate': '2022-05-01T00:26:12Z',
#    'startPlaceId': '28521334',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Glasgow Central West',
#    'startPlaceStationNumber': 8216,
#    'startPlaceLat': 55.85853,
#    'startPlaceLong': -4.25973,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:37:20Z',
#    'endPlaceId': '349454',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Paisley Road Toll',
#    'endPlaceStationNumber': 8443,
#    'endPlaceLat': 55.85378,
#    'endPlaceLong': -4.279158,
#    'durationSeconds': 668,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.291Z',
#    'updated': '2022-10-21T13:09:59.291Z',
#    'cityId': '237',
#    'bikeId': '129762',
#    'startDate': '2022-05-01T00:28:50Z',
#    'startPlaceId': '28521474',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Carrick Quay',
#    'startPlaceStationNumber': 8231,
#    'startPlaceLat': 55.85476,
#    'startPlaceLong': -4.25164,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:48:54Z',
#    'endPlaceId': '3812438',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Kelvinhaugh Street / Argyle Street',
#    'endPlaceStationNumber': 8451,
#    'endPlaceLat': 55.86522196,
#    'endPlaceLong': -4.28612709,
#    'durationSeconds': 1204,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.341Z',
#    'updated': '2022-10-21T13:09:59.341Z',
#    'cityId': '237',
#    'bikeId': '139441',
#    'startDate': '2022-05-01T00:29:39Z',
#    'startPlaceId': '31475534',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Springburn Railway Station',
#    'startPlaceStationNumber': 8237,
#    'startPlaceLat': 55.88223188,
#    'startPlaceLong': -4.23042834,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:41:12Z',
#    'endPlaceId': '6269626',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Woodside (North) - ELECTRIC',
#    'endPlaceStationNumber': 8465,
#    'endPlaceLat': 55.87506105,
#    'endPlaceLong': -4.27067757,
#    'durationSeconds': 693,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.39Z',
#    'updated': '2022-10-21T13:09:59.39Z',
#    'cityId': '237',
#    'bikeId': '143395',
#    'startDate': '2022-05-01T00:30:10Z',
#    'startPlaceId': '349458',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Eglinton Toll',
#    'startPlaceStationNumber': 8446,
#    'startPlaceLat': 55.84331359,
#    'startPlaceLong': -4.26225007,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:36:49Z',
#    'endPlaceId': '42614033',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Gorbals Library',
#    'endPlaceStationNumber': 8215,
#    'endPlaceLat': 55.84856441,
#    'endPlaceLong': -4.25099551,
#    'durationSeconds': 399,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.438Z',
#    'updated': '2022-10-21T13:09:59.438Z',
#    'cityId': '237',
#    'bikeId': '129637',
#    'startDate': '2022-05-01T00:30:47Z',
#    'startPlaceId': '266218',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Partick Interchange',
#    'startPlaceStationNumber': 8423,
#    'startPlaceLat': 55.8697069,
#    'startPlaceLong': -4.30845916,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:48:12Z',
#    'endPlaceId': '266169',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Trongate',
#    'endPlaceStationNumber': 8431,
#    'endPlaceLat': 55.85596149,
#    'endPlaceLong': -4.24467087,
#    'durationSeconds': 1045,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.487Z',
#    'updated': '2022-10-21T13:09:59.487Z',
#    'cityId': '237',
#    'bikeId': '143205',
#    'startDate': '2022-05-01T00:31:07Z',
#    'startPlaceId': '349450',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Bellgrove Railway Station (North) - ELECTRIC',
#    'startPlaceStationNumber': 8439,
#    'startPlaceLat': 55.85812327,
#    'startPlaceLong': -4.22451138,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:37:38Z',
#    'endPlaceId': '3812776',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Alexandra Park (south entrance) Alexandra Parade Railway Station',
#    'endPlaceStationNumber': 8457,
#    'endPlaceLat': 55.863128,
#    'endPlaceLong': -4.210282,
#    'durationSeconds': 391,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.539Z',
#    'updated': '2022-10-21T13:09:59.539Z',
#    'cityId': '237',
#    'bikeId': '143232',
#    'startDate': '2022-05-01T00:31:39Z',
#    'startPlaceId': '6269618',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Sauchiehall Street',
#    'startPlaceStationNumber': 8463,
#    'startPlaceLat': 55.865291,
#    'startPlaceLong': -4.261756,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:35:08Z',
#    'endPlaceId': '380893',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Buchanan Street Bus Station',
#    'endPlaceStationNumber': 8404,
#    'endPlaceLat': 55.86497513,
#    'endPlaceLong': -4.25266385,
#    'durationSeconds': 209,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.588Z',
#    'updated': '2022-10-21T13:09:59.588Z',
#    'cityId': '237',
#    'bikeId': '139455',
#    'startDate': '2022-05-01T00:31:49Z',
#    'startPlaceId': '45172531',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Queen Street Railway',
#    'startPlaceStationNumber': 8740,
#    'startPlaceLat': 55.86210198,
#    'startPlaceLong': -4.25230691,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:09:42Z',
#    'endPlaceId': '45172531',
#    'endPlaceCityId': '237',
#    'endChannelId': '15',
#    'endPlaceName': 'Queen Street Railway',
#    'endPlaceStationNumber': 8740,
#    'endPlaceLat': 55.86210198,
#    'endPlaceLong': -4.25230691,
#    'durationSeconds': 2273,
#    'isInvalid': True,
#    'price': 0.5,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.64Z',
#    'updated': '2022-10-21T13:09:59.64Z',
#    'cityId': '237',
#    'bikeId': '105839',
#    'startDate': '2022-05-01T00:33:06Z',
#    'startPlaceId': '264295',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - St Enoch Square',
#    'startPlaceStationNumber': 8410,
#    'startPlaceLat': 55.85682863,
#    'startPlaceLong': -4.25529242,
#    'startChannelId': None,
#    'endDate': '2022-05-01T11:54:12Z',
#    'endPlaceId': '3812694',
#    'endPlaceCityId': '237',
#    'endChannelId': '15',
#    'endPlaceName': 'ELECTRIC - Langside Hall',
#    'endPlaceStationNumber': 8454,
#    'endPlaceLat': 55.83160158,
#    'endPlaceLong': -4.27841306,
#    'durationSeconds': 40866,
#    'isInvalid': False,
#    'price': 10.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.689Z',
#    'updated': '2022-10-21T13:09:59.689Z',
#    'cityId': '237',
#    'bikeId': '143273',
#    'startDate': '2022-05-01T00:34:35Z',
#    'startPlaceId': '380893',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Buchanan Street Bus Station',
#    'startPlaceStationNumber': 8404,
#    'startPlaceLat': 55.86497513,
#    'startPlaceLong': -4.25266385,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:49:31Z',
#    'endPlaceId': '19548002',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Shakespeare Street (Maryhill) - ELECTRIC',
#    'endPlaceStationNumber': 8427,
#    'endPlaceLat': 55.88693447,
#    'endPlaceLong': -4.28502202,
#    'durationSeconds': 896,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.739Z',
#    'updated': '2022-10-21T13:09:59.739Z',
#    'cityId': '237',
#    'bikeId': '103810',
#    'startDate': '2022-05-01T00:35:41Z',
#    'startPlaceId': '264303',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Kelvinbridge Subway',
#    'startPlaceStationNumber': 8418,
#    'startPlaceLat': 55.87500989,
#    'startPlaceLong': -4.28037107,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:12:33Z',
#    'endPlaceId': '380893',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Buchanan Street Bus Station',
#    'endPlaceStationNumber': 8404,
#    'endPlaceLat': 55.86497513,
#    'endPlaceLong': -4.25266385,
#    'durationSeconds': 2212,
#    'isInvalid': False,
#    'price': 4.0,
#    'isEbike': True},
#   {'created': '2022-10-21T13:09:59.791Z',
#    'updated': '2022-10-21T13:09:59.791Z',
#    'cityId': '237',
#    'bikeId': '143008',
#    'startDate': '2022-05-01T00:43:01Z',
#    'startPlaceId': '266218',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Partick Interchange',
#    'startPlaceStationNumber': 8423,
#    'startPlaceLat': 55.8697069,
#    'startPlaceLong': -4.30845916,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:14:50Z',
#    'endPlaceId': '264304',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Kelvingrove Art Gallery - ELECTRIC',
#    'endPlaceStationNumber': 8420,
#    'endPlaceLat': 55.86835244,
#    'endPlaceLong': -4.28940475,
#    'durationSeconds': 1909,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.841Z',
#    'updated': '2022-10-21T13:09:59.841Z',
#    'cityId': '237',
#    'bikeId': '142983',
#    'startDate': '2022-05-01T00:43:31Z',
#    'startPlaceId': '266218',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Partick Interchange',
#    'startPlaceStationNumber': 8423,
#    'startPlaceLat': 55.8697069,
#    'startPlaceLong': -4.30845916,
#    'startChannelId': None,
#    'endDate': '2022-05-01T02:05:32Z',
#    'endPlaceId': '79928892',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'BIKE 46721',
#    'endPlaceStationNumber': None,
#    'endPlaceLat': 55.86415111,
#    'endPlaceLong': -4.25599944,
#    'durationSeconds': 4921,
#    'isInvalid': False,
#    'price': 3.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.891Z',
#    'updated': '2022-10-21T13:09:59.891Z',
#    'cityId': '237',
#    'bikeId': '143232',
#    'startDate': '2022-05-01T00:45:10Z',
#    'startPlaceId': '380893',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Buchanan Street Bus Station',
#    'startPlaceStationNumber': 8404,
#    'startPlaceLat': 55.86497513,
#    'startPlaceLong': -4.25266385,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:09:33Z',
#    'endPlaceId': '266218',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Partick Interchange',
#    'endPlaceStationNumber': 8423,
#    'endPlaceLat': 55.8697069,
#    'endPlaceLong': -4.30845916,
#    'durationSeconds': 1463,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.943Z',
#    'updated': '2022-10-21T13:09:59.943Z',
#    'cityId': '237',
#    'bikeId': '62431',
#    'startDate': '2022-05-01T00:47:11Z',
#    'startPlaceId': '19164571',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Central Station',
#    'startPlaceStationNumber': 8401,
#    'startPlaceLat': 55.86077565,
#    'startPlaceLong': -4.2585969,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:06:10Z',
#    'endPlaceId': '21603723',
#    'endPlaceCityId': '237',
#    'endChannelId': '38',
#    'endPlaceName': 'Ibrox',
#    'endPlaceStationNumber': 8452,
#    'endPlaceLat': 55.85098714,
#    'endPlaceLong': -4.30144787,
#    'durationSeconds': 1139,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:09:59.994Z',
#    'updated': '2022-10-21T13:09:59.994Z',
#    'cityId': '237',
#    'bikeId': '143257',
#    'startDate': '2022-05-01T00:47:14Z',
#    'startPlaceId': '266169',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Trongate',
#    'startPlaceStationNumber': 8431,
#    'startPlaceLat': 55.85596149,
#    'startPlaceLong': -4.24467087,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:52:28Z',
#    'endPlaceId': '264298',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Glasgow Green',
#    'endPlaceStationNumber': 8412,
#    'endPlaceLat': 55.84945,
#    'endPlaceLong': -4.23375,
#    'durationSeconds': 314,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.046Z',
#    'updated': '2022-10-21T13:10:00.046Z',
#    'cityId': '237',
#    'bikeId': '129674',
#    'startDate': '2022-05-01T00:49:03Z',
#    'startPlaceId': '264392',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Argyle Street Railway Station',
#    'startPlaceStationNumber': 8411,
#    'startPlaceLat': 55.85757531,
#    'startPlaceLong': -4.24997628,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:04:46Z',
#    'endPlaceId': '349460',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Queens Park Railway Station',
#    'endPlaceStationNumber': 8447,
#    'endPlaceLat': 55.83497577,
#    'endPlaceLong': -4.26548481,
#    'durationSeconds': 943,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.096Z',
#    'updated': '2022-10-21T13:10:00.096Z',
#    'cityId': '237',
#    'bikeId': '139441',
#    'startDate': '2022-05-01T00:49:07Z',
#    'startPlaceId': '6269626',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Woodside (North) - ELECTRIC',
#    'startPlaceStationNumber': 8465,
#    'startPlaceLat': 55.87506105,
#    'startPlaceLong': -4.27067757,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:05:08Z',
#    'endPlaceId': '31475534',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Springburn Railway Station',
#    'endPlaceStationNumber': 8237,
#    'endPlaceLat': 55.88223188,
#    'endPlaceLong': -4.23042834,
#    'durationSeconds': 961,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.146Z',
#    'updated': '2022-10-21T13:10:00.146Z',
#    'cityId': '237',
#    'bikeId': '129637',
#    'startDate': '2022-05-01T00:49:25Z',
#    'startPlaceId': '266169',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Trongate',
#    'startPlaceStationNumber': 8431,
#    'startPlaceLat': 55.85596149,
#    'startPlaceLong': -4.24467087,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:10:21Z',
#    'endPlaceId': '3812770',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Dalmarnock Railway Station - ELECTRIC',
#    'endPlaceStationNumber': 8456,
#    'endPlaceLat': 55.84256061,
#    'endPlaceLong': -4.21770394,
#    'durationSeconds': 1256,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.195Z',
#    'updated': '2022-10-21T13:10:00.195Z',
#    'cityId': '237',
#    'bikeId': '143295',
#    'startDate': '2022-05-01T00:50:01Z',
#    'startPlaceId': '264308',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Mitchell Library',
#    'startPlaceStationNumber': 8425,
#    'startPlaceLat': 55.86478849,
#    'startPlaceLong': -4.27185237,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:01:04Z',
#    'endPlaceId': '266218',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Partick Interchange',
#    'endPlaceStationNumber': 8423,
#    'endPlaceLat': 55.8697069,
#    'endPlaceLong': -4.30845916,
#    'durationSeconds': 663,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.245Z',
#    'updated': '2022-10-21T13:10:00.245Z',
#    'cityId': '237',
#    'bikeId': '139412',
#    'startDate': '2022-05-01T00:50:53Z',
#    'startPlaceId': '266169',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Trongate',
#    'startPlaceStationNumber': 8431,
#    'startPlaceLat': 55.85596149,
#    'startPlaceLong': -4.24467087,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:10:44Z',
#    'endPlaceId': '3812770',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Dalmarnock Railway Station - ELECTRIC',
#    'endPlaceStationNumber': 8456,
#    'endPlaceLat': 55.84256061,
#    'endPlaceLong': -4.21770394,
#    'durationSeconds': 1191,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.297Z',
#    'updated': '2022-10-21T13:10:00.297Z',
#    'cityId': '237',
#    'bikeId': '143290',
#    'startDate': '2022-05-01T00:54:36Z',
#    'startPlaceId': '19164571',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Central Station',
#    'startPlaceStationNumber': 8401,
#    'startPlaceLat': 55.86077565,
#    'startPlaceLong': -4.2585969,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:34:23Z',
#    'endPlaceId': '6269629',
#    'endPlaceCityId': '237',
#    'endChannelId': '15',
#    'endPlaceName': 'Battlefield - ELECTRIC',
#    'endPlaceStationNumber': 8466,
#    'endPlaceLat': 55.82739548,
#    'endPlaceLong': -4.26531851,
#    'durationSeconds': 2387,
#    'isInvalid': False,
#    'price': 2.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.348Z',
#    'updated': '2022-10-21T13:10:00.348Z',
#    'cityId': '237',
#    'bikeId': '143398',
#    'startDate': '2022-05-01T00:55:00Z',
#    'startPlaceId': '264301',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Queen Margaret Drive / Maryhill Road',
#    'startPlaceStationNumber': 8419,
#    'startPlaceLat': 55.8849,
#    'startPlaceLong': -4.281414,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:08:35Z',
#    'endPlaceId': '315912',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Finnieston Street',
#    'endPlaceStationNumber': 8438,
#    'endPlaceLat': 55.86342182,
#    'endPlaceLong': -4.28067684,
#    'durationSeconds': 815,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.398Z',
#    'updated': '2022-10-21T13:10:00.398Z',
#    'cityId': '237',
#    'bikeId': '139370',
#    'startDate': '2022-05-01T00:55:02Z',
#    'startPlaceId': '264299',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Broomielaw',
#    'startPlaceStationNumber': 8413,
#    'startPlaceLat': 55.8565998,
#    'startPlaceLong': -4.26352143,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:08:05Z',
#    'endPlaceId': '7145152',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Shields Road',
#    'endPlaceStationNumber': 8403,
#    'endPlaceLat': 55.84581338,
#    'endPlaceLong': -4.2752105,
#    'durationSeconds': 783,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.448Z',
#    'updated': '2022-10-21T13:10:00.448Z',
#    'cityId': '237',
#    'bikeId': '143043',
#    'startDate': '2022-05-01T00:56:01Z',
#    'startPlaceId': '266168',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Gallery of Modern Art',
#    'startPlaceStationNumber': 8430,
#    'startPlaceLat': 55.85971592,
#    'startPlaceLong': -4.25194502,
#    'startChannelId': None,
#    'endDate': '2022-05-01T00:56:17Z',
#    'endPlaceId': '266168',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Gallery of Modern Art',
#    'endPlaceStationNumber': 8430,
#    'endPlaceLat': 55.85971592,
#    'endPlaceLong': -4.25194502,
#    'durationSeconds': 16,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.502Z',
#    'updated': '2022-10-21T13:10:00.502Z',
#    'cityId': '237',
#    'bikeId': '143006',
#    'startDate': '2022-05-01T00:56:37Z',
#    'startPlaceId': '6269618',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Sauchiehall Street',
#    'startPlaceStationNumber': 8463,
#    'startPlaceLat': 55.865291,
#    'startPlaceLong': -4.261756,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:03:08Z',
#    'endPlaceId': '266170',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'University of Strathclyde (South)',
#    'endPlaceStationNumber': 8433,
#    'endPlaceLat': 55.860633,
#    'endPlaceLong': -4.2419,
#    'durationSeconds': 391,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.549Z',
#    'updated': '2022-10-21T13:10:00.549Z',
#    'cityId': '237',
#    'bikeId': '143022',
#    'startDate': '2022-05-01T00:57:27Z',
#    'startPlaceId': '3812770',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Dalmarnock Railway Station - ELECTRIC',
#    'startPlaceStationNumber': 8456,
#    'startPlaceLat': 55.84256061,
#    'startPlaceLong': -4.21770394,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:10:45Z',
#    'endPlaceId': '266170',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'University of Strathclyde (South)',
#    'endPlaceStationNumber': 8433,
#    'endPlaceLat': 55.860633,
#    'endPlaceLong': -4.2419,
#    'durationSeconds': 798,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.597Z',
#    'updated': '2022-10-21T13:10:00.597Z',
#    'cityId': '237',
#    'bikeId': '116870',
#    'startDate': '2022-05-01T00:59:44Z',
#    'startPlaceId': '264299',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Broomielaw',
#    'startPlaceStationNumber': 8413,
#    'startPlaceLat': 55.8565998,
#    'startPlaceLong': -4.26352143,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:02:52Z',
#    'endPlaceId': '264299',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Broomielaw',
#    'endPlaceStationNumber': 8413,
#    'endPlaceLat': 55.8565998,
#    'endPlaceLong': -4.26352143,
#    'durationSeconds': 188,
#    'isInvalid': False,
#    'price': 2.0,
#    'isEbike': True},
#   {'created': '2022-10-21T13:10:00.649Z',
#    'updated': '2022-10-21T13:10:00.649Z',
#    'cityId': '237',
#    'bikeId': '142980',
#    'startDate': '2022-05-01T00:59:46Z',
#    'startPlaceId': '264295',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - St Enoch Square',
#    'startPlaceStationNumber': 8410,
#    'startPlaceLat': 55.85682863,
#    'startPlaceLong': -4.25529242,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:00:07Z',
#    'endPlaceId': '264295',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - St Enoch Square',
#    'endPlaceStationNumber': 8410,
#    'endPlaceLat': 55.85682863,
#    'endPlaceLong': -4.25529242,
#    'durationSeconds': 21,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.698Z',
#    'updated': '2022-10-21T13:10:00.698Z',
#    'cityId': '237',
#    'bikeId': '116930',
#    'startDate': '2022-05-01T00:59:50Z',
#    'startPlaceId': '264292',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'George Square - ELECTRIC',
#    'startPlaceStationNumber': 8406,
#    'startPlaceLat': 55.86155,
#    'startPlaceLong': -4.2494,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:14:58Z',
#    'endPlaceId': '3812792',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Duke Street Railway Station',
#    'endPlaceStationNumber': 8458,
#    'endPlaceLat': 55.858222,
#    'endPlaceLong': -4.213473,
#    'durationSeconds': 908,
#    'isInvalid': False,
#    'price': 2.0,
#    'isEbike': True},
#   {'created': '2022-10-21T13:10:00.747Z',
#    'updated': '2022-10-21T13:10:00.747Z',
#    'cityId': '237',
#    'bikeId': '116863',
#    'startDate': '2022-05-01T01:02:30Z',
#    'startPlaceId': '349455',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'startPlaceStationNumber': 8444,
#    'startPlaceLat': 55.85191762,
#    'startPlaceLong': -4.29449022,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:10:57Z',
#    'endPlaceId': '42487542',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Emirates Arena',
#    'endPlaceStationNumber': None,
#    'endPlaceLat': 55.8465151,
#    'endPlaceLong': -4.20847714,
#    'durationSeconds': 507,
#    'isInvalid': False,
#    'price': 2.0,
#    'isEbike': True},
#   {'created': '2022-10-21T13:10:00.795Z',
#    'updated': '2022-10-21T13:10:00.795Z',
#    'cityId': '237',
#    'bikeId': '143187',
#    'startDate': '2022-05-01T01:02:32Z',
#    'startPlaceId': '264295',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - St Enoch Square',
#    'startPlaceStationNumber': 8410,
#    'startPlaceLat': 55.85682863,
#    'startPlaceLong': -4.25529242,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:17:36Z',
#    'endPlaceId': '3812694',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Langside Hall',
#    'endPlaceStationNumber': 8454,
#    'endPlaceLat': 55.83160158,
#    'endPlaceLong': -4.27841306,
#    'durationSeconds': 904,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.845Z',
#    'updated': '2022-10-21T13:10:00.845Z',
#    'cityId': '237',
#    'bikeId': '143175',
#    'startDate': '2022-05-01T01:02:53Z',
#    'startPlaceId': '28521334',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Glasgow Central West',
#    'startPlaceStationNumber': 8216,
#    'startPlaceLat': 55.85853,
#    'startPlaceLong': -4.25973,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:23:48Z',
#    'endPlaceId': '42417389',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Cathcart Railway Station',
#    'endPlaceStationNumber': 8206,
#    'endPlaceLat': 55.81733845,
#    'endPlaceLong': -4.26268793,
#    'durationSeconds': 1255,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.894Z',
#    'updated': '2022-10-21T13:10:00.894Z',
#    'cityId': '237',
#    'bikeId': '143295',
#    'startDate': '2022-05-01T01:04:41Z',
#    'startPlaceId': '266218',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Partick Interchange',
#    'startPlaceStationNumber': 8423,
#    'startPlaceLat': 55.8697069,
#    'startPlaceLong': -4.30845916,
#    'startChannelId': None,
#    'endDate': '2022-05-01T02:38:20Z',
#    'endPlaceId': '266218',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Partick Interchange',
#    'endPlaceStationNumber': 8423,
#    'endPlaceLat': 55.8697069,
#    'endPlaceLong': -4.30845916,
#    'durationSeconds': 5619,
#    'isInvalid': False,
#    'price': 3.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.943Z',
#    'updated': '2022-10-21T13:10:00.943Z',
#    'cityId': '237',
#    'bikeId': '129726',
#    'startDate': '2022-05-01T01:09:31Z',
#    'startPlaceId': '349461',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Queens Park West',
#    'startPlaceStationNumber': 8448,
#    'startPlaceLat': 55.83504205,
#    'startPlaceLong': -4.2723459,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:40:49Z',
#    'endPlaceId': '3812792',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Duke Street Railway Station',
#    'endPlaceStationNumber': 8458,
#    'endPlaceLat': 55.858222,
#    'endPlaceLong': -4.213473,
#    'durationSeconds': 1878,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:00.993Z',
#    'updated': '2022-10-21T13:10:00.993Z',
#    'cityId': '237',
#    'bikeId': '142980',
#    'startDate': '2022-05-01T01:12:09Z',
#    'startPlaceId': '264295',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - St Enoch Square',
#    'startPlaceStationNumber': 8410,
#    'startPlaceLat': 55.85682863,
#    'startPlaceLong': -4.25529242,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:24:07Z',
#    'endPlaceId': '349460',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - Queens Park Railway Station',
#    'endPlaceStationNumber': 8447,
#    'endPlaceLat': 55.83497577,
#    'endPlaceLong': -4.26548481,
#    'durationSeconds': 718,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:01.042Z',
#    'updated': '2022-10-21T13:10:01.042Z',
#    'cityId': '237',
#    'bikeId': '116889',
#    'startDate': '2022-05-01T01:13:17Z',
#    'startPlaceId': '264293',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Merchant Square',
#    'startPlaceStationNumber': 8407,
#    'startPlaceLat': 55.858167,
#    'startPlaceLong': -4.245483,
#    'startChannelId': None,
#    'endDate': '2022-05-01T01:19:43Z',
#    'endPlaceId': '349450',
#    'endPlaceCityId': '237',
#    'endChannelId': '37',
#    'endPlaceName': 'Bellgrove Railway Station (North) - ELECTRIC',
#    'endPlaceStationNumber': 8439,
#    'endPlaceLat': 55.85812327,
#    'endPlaceLong': -4.22451138,
#    'durationSeconds': 386,
#    'isInvalid': False,
#    'price': 2.0,
#    'isEbike': True},
#   {'created': '2022-10-21T13:10:01.092Z',
#    'updated': '2022-10-21T13:10:01.092Z',
# ...
#    'updated': '2022-10-21T13:10:47.646Z',
#    'cityId': '237',
#    'bikeId': '116915',
#    'startDate': '2022-05-01T18:26:29Z',
#    'startPlaceId': '3812438',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Kelvinhaugh Street / Argyle Street',
#    'startPlaceStationNumber': 8451,
#    'startPlaceLat': 55.86522196,
#    'startPlaceLong': -4.28612709,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:45:45Z',
#    'endPlaceId': '349453',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'City of Glasgow College (Riverside Campus) - ELECTRIC',
#    'endPlaceStationNumber': 8442,
#    'endPlaceLat': 55.850554,
#    'endPlaceLong': -4.248127,
#    'durationSeconds': 1156,
#    'isInvalid': False,
#    'price': 2.0,
#    'isEbike': True},
#   {'created': '2022-10-21T13:10:47.696Z',
#    'updated': '2022-10-21T13:10:47.696Z',
#    'cityId': '237',
#    'bikeId': '139422',
#    'startDate': '2022-05-01T18:26:38Z',
#    'startPlaceId': '264300',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#    'startPlaceStationNumber': 8415,
#    'startPlaceLat': 55.85908067,
#    'startPlaceLong': -4.2872107,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:39:51Z',
#    'endPlaceId': '80099379',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'BIKE 46791',
#    'endPlaceStationNumber': None,
#    'endPlaceLat': 55.86106667,
#    'endPlaceLong': -4.24941333,
#    'durationSeconds': 793,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:47.747Z',
#    'updated': '2022-10-21T13:10:47.747Z',
#    'cityId': '237',
#    'bikeId': '139458',
#    'startDate': '2022-05-01T18:29:47Z',
#    'startPlaceId': '45172531',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Queen Street Railway',
#    'startPlaceStationNumber': 8740,
#    'startPlaceLat': 55.86210198,
#    'startPlaceLong': -4.25230691,
#    'startChannelId': None,
#    'endDate': '2022-05-01T20:29:16Z',
#    'endPlaceId': '19738176',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Riverside Museum',
#    'endPlaceStationNumber': 8416,
#    'endPlaceLat': 55.865683,
#    'endPlaceLong': -4.305367,
#    'durationSeconds': 7169,
#    'isInvalid': False,
#    'price': 4.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:47.797Z',
#    'updated': '2022-10-21T13:10:47.797Z',
#    'cityId': '237',
#    'bikeId': '143249',
#    'startDate': '2022-05-01T18:30:00Z',
#    'startPlaceId': '264303',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Kelvinbridge Subway',
#    'startPlaceStationNumber': 8418,
#    'startPlaceLat': 55.87500989,
#    'startPlaceLong': -4.28037107,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:42:08Z',
#    'endPlaceId': '80099924',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'BIKE 46455',
#    'endPlaceStationNumber': None,
#    'endPlaceLat': 55.86486222,
#    'endPlaceLong': -4.25739333,
#    'durationSeconds': 728,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:47.845Z',
#    'updated': '2022-10-21T13:10:47.845Z',
#    'cityId': '237',
#    'bikeId': '143151',
#    'startDate': '2022-05-01T18:30:17Z',
#    'startPlaceId': '349455',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'startPlaceStationNumber': 8444,
#    'startPlaceLat': 55.85191762,
#    'startPlaceLong': -4.29449022,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:55:08Z',
#    'endPlaceId': '264295',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'ELECTRIC - St Enoch Square',
#    'endPlaceStationNumber': 8410,
#    'endPlaceLat': 55.85682863,
#    'endPlaceLong': -4.25529242,
#    'durationSeconds': 1491,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:47.895Z',
#    'updated': '2022-10-21T13:10:47.895Z',
#    'cityId': '237',
#    'bikeId': '143301',
#    'startDate': '2022-05-01T18:30:37Z',
#    'startPlaceId': '55600054',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Bellahouston Park',
#    'startPlaceStationNumber': 8201,
#    'startPlaceLat': 55.84901377,
#    'startPlaceLong': -4.31486264,
#    'startChannelId': None,
#    'endDate': '2022-05-01T19:03:52Z',
#    'endPlaceId': '19738176',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Riverside Museum',
#    'endPlaceStationNumber': 8416,
#    'endPlaceLat': 55.865683,
#    'endPlaceLong': -4.305367,
#    'durationSeconds': 1995,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:47.947Z',
#    'updated': '2022-10-21T13:10:47.947Z',
#    'cityId': '237',
#    'bikeId': '143194',
#    'startDate': '2022-05-01T18:30:40Z',
#    'startPlaceId': '349451',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Barrowlands',
#    'startPlaceStationNumber': 8440,
#    'startPlaceLat': 55.85515155,
#    'startPlaceLong': -4.23529387,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:47:57Z',
#    'endPlaceId': '41822435',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Glasgow Science Centre',
#    'endPlaceStationNumber': 8426,
#    'endPlaceLat': 55.85849961,
#    'endPlaceLong': -4.29297209,
#    'durationSeconds': 1037,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48Z',
#    'updated': '2022-10-21T13:10:48Z',
#    'cityId': '237',
#    'bikeId': '143178',
#    'startDate': '2022-05-01T18:30:50Z',
#    'startPlaceId': '264316',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Bridge Street Subway',
#    'startPlaceStationNumber': 8432,
#    'startPlaceLat': 55.8525,
#    'startPlaceLong': -4.25885,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:41:49Z',
#    'endPlaceId': '19548484',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Cambridge Street - ELECTRIC',
#    'endPlaceStationNumber': 8434,
#    'endPlaceLat': 55.865063,
#    'endPlaceLong': -4.260291,
#    'durationSeconds': 659,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48.05Z',
#    'updated': '2022-10-21T13:10:48.05Z',
#    'cityId': '237',
#    'bikeId': '143305',
#    'startDate': '2022-05-01T18:31:51Z',
#    'startPlaceId': '264300',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#    'startPlaceStationNumber': 8415,
#    'startPlaceLat': 55.85908067,
#    'startPlaceLong': -4.2872107,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:47:36Z',
#    'endPlaceId': '3812438',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Kelvinhaugh Street / Argyle Street',
#    'endPlaceStationNumber': 8451,
#    'endPlaceLat': 55.86522196,
#    'endPlaceLong': -4.28612709,
#    'durationSeconds': 945,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48.101Z',
#    'updated': '2022-10-21T13:10:48.101Z',
#    'cityId': '237',
#    'bikeId': '139455',
#    'startDate': '2022-05-01T18:32:07Z',
#    'startPlaceId': '349455',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#    'startPlaceStationNumber': 8444,
#    'startPlaceLat': 55.85191762,
#    'startPlaceLong': -4.29449022,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:50:32Z',
#    'endPlaceId': '45172531',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Queen Street Railway',
#    'endPlaceStationNumber': 8740,
#    'endPlaceLat': 55.86210198,
#    'endPlaceLong': -4.25230691,
#    'durationSeconds': 1105,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48.15Z',
#    'updated': '2022-10-21T13:10:48.15Z',
#    'cityId': '237',
#    'bikeId': '143258',
#    'startDate': '2022-05-01T18:33:03Z',
#    'startPlaceId': '264300',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#    'startPlaceStationNumber': 8415,
#    'startPlaceLat': 55.85908067,
#    'startPlaceLong': -4.2872107,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:47:30Z',
#    'endPlaceId': '3812438',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Kelvinhaugh Street / Argyle Street',
#    'endPlaceStationNumber': 8451,
#    'endPlaceLat': 55.86522196,
#    'endPlaceLong': -4.28612709,
#    'durationSeconds': 867,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48.2Z',
#    'updated': '2022-10-21T13:10:48.2Z',
#    'cityId': '237',
#    'bikeId': '143183',
#    'startDate': '2022-05-01T18:33:09Z',
#    'startPlaceId': '264300',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#    'startPlaceStationNumber': 8415,
#    'startPlaceLat': 55.85908067,
#    'startPlaceLong': -4.2872107,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:47:36Z',
#    'endPlaceId': '3812438',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Kelvinhaugh Street / Argyle Street',
#    'endPlaceStationNumber': 8451,
#    'endPlaceLat': 55.86522196,
#    'endPlaceLong': -4.28612709,
#    'durationSeconds': 867,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48.25Z',
#    'updated': '2022-10-21T13:10:48.25Z',
#    'cityId': '237',
#    'bikeId': '143085',
#    'startDate': '2022-05-01T18:34:02Z',
#    'startPlaceId': '264300',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#    'startPlaceStationNumber': 8415,
#    'startPlaceLat': 55.85908067,
#    'startPlaceLong': -4.2872107,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:34:21Z',
#    'endPlaceId': '264300',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#    'endPlaceStationNumber': 8415,
#    'endPlaceLat': 55.85908067,
#    'endPlaceLong': -4.2872107,
#    'durationSeconds': 19,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48.3Z',
#    'updated': '2022-10-21T13:10:48.3Z',
#    'cityId': '237',
#    'bikeId': '142998',
#    'startDate': '2022-05-01T18:34:14Z',
#    'startPlaceId': '349460',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'ELECTRIC - Queens Park Railway Station',
#    'startPlaceStationNumber': 8447,
#    'startPlaceLat': 55.83497577,
#    'startPlaceLong': -4.26548481,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:38:53Z',
#    'endPlaceId': '349458',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Eglinton Toll',
#    'endPlaceStationNumber': 8446,
#    'endPlaceLat': 55.84331359,
#    'endPlaceLong': -4.26225007,
#    'durationSeconds': 279,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48.349Z',
#    'updated': '2022-10-21T13:10:48.349Z',
#    'cityId': '237',
#    'bikeId': '143158',
#    'startDate': '2022-05-01T18:34:23Z',
#    'startPlaceId': '349454',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Paisley Road Toll',
#    'startPlaceStationNumber': 8443,
#    'startPlaceLat': 55.85378,
#    'startPlaceLong': -4.279158,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:58:14Z',
#    'endPlaceId': '6269629',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Battlefield - ELECTRIC',
#    'endPlaceStationNumber': 8466,
#    'endPlaceLat': 55.82739548,
#    'endPlaceLong': -4.26531851,
#    'durationSeconds': 1431,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48.399Z',
#    'updated': '2022-10-21T13:10:48.399Z',
#    'cityId': '237',
#    'bikeId': '129673',
#    'startDate': '2022-05-01T18:36:50Z',
#    'startPlaceId': '264300',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#    'startPlaceStationNumber': 8415,
#    'startPlaceLat': 55.85908067,
#    'startPlaceLong': -4.2872107,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:37:25Z',
#    'endPlaceId': '264300',
#    'endPlaceCityId': '237',
#    'endChannelId': None,
#    'endPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#    'endPlaceStationNumber': 8415,
#    'endPlaceLat': 55.85908067,
#    'endPlaceLong': -4.2872107,
#    'durationSeconds': 35,
#    'isInvalid': True,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48.448Z',
#    'updated': '2022-10-21T13:10:48.448Z',
#    'cityId': '237',
#    'bikeId': '143259',
#    'startDate': '2022-05-01T18:36:56Z',
#    'startPlaceId': '28521334',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Glasgow Central West',
#    'startPlaceStationNumber': 8216,
#    'startPlaceLat': 55.85853,
#    'startPlaceLong': -4.25973,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:49:16Z',
#    'endPlaceId': '3812438',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Kelvinhaugh Street / Argyle Street',
#    'endPlaceStationNumber': 8451,
#    'endPlaceLat': 55.86522196,
#    'endPlaceLong': -4.28612709,
#    'durationSeconds': 740,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48.499Z',
#    'updated': '2022-10-21T13:10:48.499Z',
#    'cityId': '237',
#    'bikeId': '116881',
#    'startDate': '2022-05-01T18:36:56Z',
#    'startPlaceId': '28521334',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Glasgow Central West',
#    'startPlaceStationNumber': 8216,
#    'startPlaceLat': 55.85853,
#    'startPlaceLong': -4.25973,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:49:25Z',
#    'endPlaceId': '3812438',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Kelvinhaugh Street / Argyle Street',
#    'endPlaceStationNumber': 8451,
#    'endPlaceLat': 55.86522196,
#    'endPlaceLong': -4.28612709,
#    'durationSeconds': 749,
#    'isInvalid': False,
#    'price': 2.0,
#    'isEbike': True},
#   {'created': '2022-10-21T13:10:48.548Z',
#    'updated': '2022-10-21T13:10:48.548Z',
#    'cityId': '237',
#    'bikeId': '129652',
#    'startDate': '2022-05-01T18:37:10Z',
#    'startPlaceId': '28521474',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Carrick Quay',
#    'startPlaceStationNumber': 8231,
#    'startPlaceLat': 55.85476,
#    'startPlaceLong': -4.25164,
#    'startChannelId': None,
#    'endDate': '2022-05-01T19:11:52Z',
#    'endPlaceId': '28521474',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Carrick Quay',
#    'endPlaceStationNumber': 8231,
#    'endPlaceLat': 55.85476,
#    'endPlaceLong': -4.25164,
#    'durationSeconds': 2082,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48.597Z',
#    'updated': '2022-10-21T13:10:48.597Z',
#    'cityId': '237',
#    'bikeId': '129681',
#    'startDate': '2022-05-01T18:37:32Z',
#    'startPlaceId': '349453',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'City of Glasgow College (Riverside Campus) - ELECTRIC',
#    'startPlaceStationNumber': 8442,
#    'startPlaceLat': 55.850554,
#    'startPlaceLong': -4.248127,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:59:51Z',
#    'endPlaceId': '42613734',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'Riddrie South',
#    'endPlaceStationNumber': 8212,
#    'endPlaceLat': 55.8674046,
#    'endPlaceLong': -4.19278805,
#    'durationSeconds': 1339,
#    'isInvalid': False,
#    'price': 0.0,
#    'isEbike': False},
#   {'created': '2022-10-21T13:10:48.646Z',
#    'updated': '2022-10-21T13:10:48.646Z',
#    'cityId': '237',
#    'bikeId': '139411',
#    'startDate': '2022-05-01T18:37:55Z',
#    'startPlaceId': '6269618',
#    'startPlaceCityId': '237',
#    'startPlaceName': 'Sauchiehall Street',
#    'startPlaceStationNumber': 8463,
#    'startPlaceLat': 55.865291,
#    'startPlaceLong': -4.261756,
#    'startChannelId': None,
#    'endDate': '2022-05-01T18:44:54Z',
#    'endPlaceId': '266171',
#    'endPlaceCityId': '237',
#    'endChannelId': '381',
#    'endPlaceName': 'University of Glasgow (East) - ELECTRIC',
#    'endPlaceStationNumber': 8435,
#    'endPlaceLat': 55.87176257,
#    'endPlaceLong': -4.27806973,
#    'durationSeconds': 419,
#    'isInvalid': False,
#    'price': 1.0,
#    'isEbike': False},
#   ...]}

# %%
# Usually, there are two labels into the web server response the metadata, and the data; we will use the data label
# to get all attributes included. 
rental_data = data['data']
rental_data
# See the structure of the data, you can see
# 'attribute':'value' structure
# each {} define one row or one element
# Again, here you will get a huge outcome; just explore what you get, and then you can clear this cell outcome
# Out:
# [{'created': '2022-10-21T13:09:57.926Z',
#   'updated': '2022-10-21T13:09:57.926Z',
#   'cityId': '237',
#   'bikeId': '116870',
#   'startDate': '2022-05-01T00:01:40Z',
#   'startPlaceId': '264299',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Broomielaw',
#   'startPlaceStationNumber': 8413,
#   'startPlaceLat': 55.8565998,
#   'startPlaceLong': -4.26352143,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:02:36Z',
#   'endPlaceId': '264299',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Broomielaw',
#   'endPlaceStationNumber': 8413,
#   'endPlaceLat': 55.8565998,
#   'endPlaceLong': -4.26352143,
#   'durationSeconds': 56,
#   'isInvalid': False,
#   'price': 2.0,
#   'isEbike': True},
#  {'created': '2022-10-21T13:09:57.975Z',
#   'updated': '2022-10-21T13:09:57.975Z',
#   'cityId': '237',
#   'bikeId': '143384',
#   'startDate': '2022-05-01T00:04:17Z',
#   'startPlaceId': '28521547',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'King Street South',
#   'startPlaceStationNumber': 8230,
#   'startPlaceLat': 55.85586,
#   'startPlaceLong': -4.24695,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:22:34Z',
#   'endPlaceId': '3812776',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Alexandra Park (south entrance) Alexandra Parade Railway Station',
#   'endPlaceStationNumber': 8457,
#   'endPlaceLat': 55.863128,
#   'endPlaceLong': -4.210282,
#   'durationSeconds': 1097,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.026Z',
#   'updated': '2022-10-21T13:09:58.026Z',
#   'cityId': '237',
#   'bikeId': '129744',
#   'startDate': '2022-05-01T00:04:24Z',
#   'startPlaceId': '266171',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'University of Glasgow (East) - ELECTRIC',
#   'startPlaceStationNumber': 8435,
#   'startPlaceLat': 55.87176257,
#   'startPlaceLong': -4.27806973,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:10:08Z',
#   'endPlaceId': '264302',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Botanic Gardens - ELECTRIC',
#   'endPlaceStationNumber': 8417,
#   'endPlaceLat': 55.87827801,
#   'endPlaceLong': -4.28848743,
#   'durationSeconds': 344,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.076Z',
#   'updated': '2022-10-21T13:09:58.076Z',
#   'cityId': '237',
#   'bikeId': '143168',
#   'startDate': '2022-05-01T00:04:29Z',
#   'startPlaceId': '349455',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'startPlaceStationNumber': 8444,
#   'startPlaceLat': 55.85191762,
#   'startPlaceLong': -4.29449022,
#   'startChannelId': None,
#   'endDate': '2022-05-01T02:57:49Z',
#   'endPlaceId': '349455',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'endPlaceStationNumber': 8444,
#   'endPlaceLat': 55.85191762,
#   'endPlaceLong': -4.29449022,
#   'durationSeconds': 10400,
#   'isInvalid': False,
#   'price': 6.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.126Z',
#   'updated': '2022-10-21T13:09:58.126Z',
#   'cityId': '237',
#   'bikeId': '143248',
#   'startDate': '2022-05-01T00:04:40Z',
#   'startPlaceId': '349455',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'startPlaceStationNumber': 8444,
#   'startPlaceLat': 55.85191762,
#   'startPlaceLong': -4.29449022,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:21:31Z',
#   'endPlaceId': '264295',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - St Enoch Square',
#   'endPlaceStationNumber': 8410,
#   'endPlaceLat': 55.85682863,
#   'endPlaceLong': -4.25529242,
#   'durationSeconds': 4611,
#   'isInvalid': False,
#   'price': 3.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.175Z',
#   'updated': '2022-10-21T13:09:58.175Z',
#   'cityId': '237',
#   'bikeId': '139406',
#   'startDate': '2022-05-01T00:05:59Z',
#   'startPlaceId': '19164571',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Central Station',
#   'startPlaceStationNumber': 8401,
#   'startPlaceLat': 55.86077565,
#   'startPlaceLong': -4.2585969,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:28:50Z',
#   'endPlaceId': '6269629',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Battlefield - ELECTRIC',
#   'endPlaceStationNumber': 8466,
#   'endPlaceLat': 55.82739548,
#   'endPlaceLong': -4.26531851,
#   'durationSeconds': 4971,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.224Z',
#   'updated': '2022-10-21T13:09:58.224Z',
#   'cityId': '237',
#   'bikeId': '143068',
#   'startDate': '2022-05-01T00:06:17Z',
#   'startPlaceId': '349455',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'startPlaceStationNumber': 8444,
#   'startPlaceLat': 55.85191762,
#   'startPlaceLong': -4.29449022,
#   'startChannelId': None,
#   'endDate': '2022-05-01T02:57:36Z',
#   'endPlaceId': '349455',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'endPlaceStationNumber': 8444,
#   'endPlaceLat': 55.85191762,
#   'endPlaceLong': -4.29449022,
#   'durationSeconds': 10279,
#   'isInvalid': False,
#   'price': 6.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.277Z',
#   'updated': '2022-10-21T13:09:58.277Z',
#   'cityId': '237',
#   'bikeId': '143118',
#   'startDate': '2022-05-01T00:09:25Z',
#   'startPlaceId': '266218',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Partick Interchange',
#   'startPlaceStationNumber': 8423,
#   'startPlaceLat': 55.8697069,
#   'startPlaceLong': -4.30845916,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:22:54Z',
#   'endPlaceId': '349455',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'endPlaceStationNumber': 8444,
#   'endPlaceLat': 55.85191762,
#   'endPlaceLong': -4.29449022,
#   'durationSeconds': 809,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.327Z',
#   'updated': '2022-10-21T13:09:58.327Z',
#   'cityId': '237',
#   'bikeId': '143143',
#   'startDate': '2022-05-01T00:09:39Z',
#   'startPlaceId': '349455',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'startPlaceStationNumber': 8444,
#   'startPlaceLat': 55.85191762,
#   'startPlaceLong': -4.29449022,
#   'startChannelId': None,
#   'endDate': '2022-05-01T02:57:40Z',
#   'endPlaceId': '349455',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'endPlaceStationNumber': 8444,
#   'endPlaceLat': 55.85191762,
#   'endPlaceLong': -4.29449022,
#   'durationSeconds': 10081,
#   'isInvalid': False,
#   'price': 6.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.377Z',
#   'updated': '2022-10-21T13:09:58.377Z',
#   'cityId': '237',
#   'bikeId': '139370',
#   'startDate': '2022-05-01T00:10:11Z',
#   'startPlaceId': '349461',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Queens Park West',
#   'startPlaceStationNumber': 8448,
#   'startPlaceLat': 55.83504205,
#   'startPlaceLong': -4.2723459,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:24:55Z',
#   'endPlaceId': '264299',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Broomielaw',
#   'endPlaceStationNumber': 8413,
#   'endPlaceLat': 55.8565998,
#   'endPlaceLong': -4.26352143,
#   'durationSeconds': 884,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.427Z',
#   'updated': '2022-10-21T13:09:58.427Z',
#   'cityId': '237',
#   'bikeId': '116917',
#   'startDate': '2022-05-01T00:12:35Z',
#   'startPlaceId': '19164571',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Central Station',
#   'startPlaceStationNumber': 8401,
#   'startPlaceLat': 55.86077565,
#   'startPlaceLong': -4.2585969,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:33:56Z',
#   'endPlaceId': '42446574',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Corkerhill Railway Station',
#   'endPlaceStationNumber': 8208,
#   'endPlaceLat': 55.83635496,
#   'endPlaceLong': -4.33514877,
#   'durationSeconds': 1281,
#   'isInvalid': False,
#   'price': 4.0,
#   'isEbike': True},
#  {'created': '2022-10-21T13:09:58.479Z',
#   'updated': '2022-10-21T13:09:58.479Z',
#   'cityId': '237',
#   'bikeId': '81699',
#   'startDate': '2022-05-01T00:13:55Z',
#   'startPlaceId': '3812886',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Glasgow Green - Saltmarket / Clyde Place',
#   'startPlaceStationNumber': 8460,
#   'startPlaceLat': 55.85319436,
#   'startPlaceLong': -4.24698293,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:18:31Z',
#   'endPlaceId': '3812886',
#   'endPlaceCityId': '237',
#   'endChannelId': '15',
#   'endPlaceName': 'ELECTRIC - Glasgow Green - Saltmarket / Clyde Place',
#   'endPlaceStationNumber': 8460,
#   'endPlaceLat': 55.85319436,
#   'endPlaceLong': -4.24698293,
#   'durationSeconds': 276,
#   'isInvalid': True,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.529Z',
#   'updated': '2022-10-21T13:09:58.529Z',
#   'cityId': '237',
#   'bikeId': '116901',
#   'startDate': '2022-05-01T00:16:08Z',
#   'startPlaceId': '266171',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'University of Glasgow (East) - ELECTRIC',
#   'startPlaceStationNumber': 8435,
#   'startPlaceLat': 55.87176257,
#   'startPlaceLong': -4.27806973,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:21:12Z',
#   'endPlaceId': '264304',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Kelvingrove Art Gallery - ELECTRIC',
#   'endPlaceStationNumber': 8420,
#   'endPlaceLat': 55.86835244,
#   'endPlaceLong': -4.28940475,
#   'durationSeconds': 304,
#   'isInvalid': False,
#   'price': 2.0,
#   'isEbike': True},
#  {'created': '2022-10-21T13:09:58.577Z',
#   'updated': '2022-10-21T13:09:58.577Z',
#   'cityId': '237',
#   'bikeId': '139442',
#   'startDate': '2022-05-01T00:16:38Z',
#   'startPlaceId': '264392',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Argyle Street Railway Station',
#   'startPlaceStationNumber': 8411,
#   'startPlaceLat': 55.85757531,
#   'startPlaceLong': -4.24997628,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:24:57Z',
#   'endPlaceId': '349452',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Bridgeton',
#   'endPlaceStationNumber': 8441,
#   'endPlaceLat': 55.8489394,
#   'endPlaceLong': -4.22682345,
#   'durationSeconds': 499,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.627Z',
#   'updated': '2022-10-21T13:09:58.627Z',
#   'cityId': '237',
#   'bikeId': '139365',
#   'startDate': '2022-05-01T00:17:59Z',
#   'startPlaceId': '349455',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'startPlaceStationNumber': 8444,
#   'startPlaceLat': 55.85191762,
#   'startPlaceLong': -4.29449022,
#   'startChannelId': None,
#   'endDate': '2022-05-01T02:57:15Z',
#   'endPlaceId': '349455',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'endPlaceStationNumber': 8444,
#   'endPlaceLat': 55.85191762,
#   'endPlaceLong': -4.29449022,
#   'durationSeconds': 9556,
#   'isInvalid': False,
#   'price': 5.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.676Z',
#   'updated': '2022-10-21T13:09:58.676Z',
#   'cityId': '237',
#   'bikeId': '143392',
#   'startDate': '2022-05-01T00:18:04Z',
#   'startPlaceId': '264295',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - St Enoch Square',
#   'startPlaceStationNumber': 8410,
#   'startPlaceLat': 55.85682863,
#   'startPlaceLong': -4.25529242,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:37:11Z',
#   'endPlaceId': '349455',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'endPlaceStationNumber': 8444,
#   'endPlaceLat': 55.85191762,
#   'endPlaceLong': -4.29449022,
#   'durationSeconds': 1147,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.724Z',
#   'updated': '2022-10-21T13:09:58.724Z',
#   'cityId': '237',
#   'bikeId': '143093',
#   'startDate': '2022-05-01T00:18:06Z',
#   'startPlaceId': '349455',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'startPlaceStationNumber': 8444,
#   'startPlaceLat': 55.85191762,
#   'startPlaceLong': -4.29449022,
#   'startChannelId': None,
#   'endDate': '2022-05-01T02:57:57Z',
#   'endPlaceId': '349455',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'endPlaceStationNumber': 8444,
#   'endPlaceLat': 55.85191762,
#   'endPlaceLong': -4.29449022,
#   'durationSeconds': 9591,
#   'isInvalid': False,
#   'price': 5.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.777Z',
#   'updated': '2022-10-21T13:09:58.777Z',
#   'cityId': '237',
#   'bikeId': '143198',
#   'startDate': '2022-05-01T00:18:07Z',
#   'startPlaceId': '264295',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - St Enoch Square',
#   'startPlaceStationNumber': 8410,
#   'startPlaceLat': 55.85682863,
#   'startPlaceLong': -4.25529242,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:36:58Z',
#   'endPlaceId': '349455',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'endPlaceStationNumber': 8444,
#   'endPlaceLat': 55.85191762,
#   'endPlaceLong': -4.29449022,
#   'durationSeconds': 1131,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.827Z',
#   'updated': '2022-10-21T13:09:58.827Z',
#   'cityId': '237',
#   'bikeId': '142962',
#   'startDate': '2022-05-01T00:18:12Z',
#   'startPlaceId': '349455',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'startPlaceStationNumber': 8444,
#   'startPlaceLat': 55.85191762,
#   'startPlaceLong': -4.29449022,
#   'startChannelId': None,
#   'endDate': '2022-05-01T02:57:32Z',
#   'endPlaceId': '349455',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'endPlaceStationNumber': 8444,
#   'endPlaceLat': 55.85191762,
#   'endPlaceLong': -4.29449022,
#   'durationSeconds': 9560,
#   'isInvalid': False,
#   'price': 5.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.877Z',
#   'updated': '2022-10-21T13:09:58.877Z',
#   'cityId': '237',
#   'bikeId': '142979',
#   'startDate': '2022-05-01T00:18:28Z',
#   'startPlaceId': '349455',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'startPlaceStationNumber': 8444,
#   'startPlaceLat': 55.85191762,
#   'startPlaceLong': -4.29449022,
#   'startChannelId': None,
#   'endDate': '2022-05-01T02:57:33Z',
#   'endPlaceId': '349455',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'endPlaceStationNumber': 8444,
#   'endPlaceLat': 55.85191762,
#   'endPlaceLong': -4.29449022,
#   'durationSeconds': 9545,
#   'isInvalid': False,
#   'price': 5.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.927Z',
#   'updated': '2022-10-21T13:09:58.927Z',
#   'cityId': '237',
#   'bikeId': '143295',
#   'startDate': '2022-05-01T00:18:47Z',
#   'startPlaceId': '28521547',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'King Street South',
#   'startPlaceStationNumber': 8230,
#   'startPlaceLat': 55.85586,
#   'startPlaceLong': -4.24695,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:36:57Z',
#   'endPlaceId': '264308',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Mitchell Library',
#   'endPlaceStationNumber': 8425,
#   'endPlaceLat': 55.86478849,
#   'endPlaceLong': -4.27185237,
#   'durationSeconds': 1090,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:58.976Z',
#   'updated': '2022-10-21T13:09:58.976Z',
#   'cityId': '237',
#   'bikeId': '62416',
#   'startDate': '2022-05-01T00:19:55Z',
#   'startPlaceId': '264292',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'George Square - ELECTRIC',
#   'startPlaceStationNumber': 8406,
#   'startPlaceLat': 55.86155,
#   'startPlaceLong': -4.2494,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:33:20Z',
#   'endPlaceId': '6269626',
#   'endPlaceCityId': '237',
#   'endChannelId': '38',
#   'endPlaceName': 'Woodside (North) - ELECTRIC',
#   'endPlaceStationNumber': 8465,
#   'endPlaceLat': 55.87506105,
#   'endPlaceLong': -4.27067757,
#   'durationSeconds': 805,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.026Z',
#   'updated': '2022-10-21T13:09:59.026Z',
#   'cityId': '237',
#   'bikeId': '62282',
#   'startDate': '2022-05-01T00:20:03Z',
#   'startPlaceId': '264292',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'George Square - ELECTRIC',
#   'startPlaceStationNumber': 8406,
#   'startPlaceLat': 55.86155,
#   'startPlaceLong': -4.2494,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:31:27Z',
#   'endPlaceId': '264303',
#   'endPlaceCityId': '237',
#   'endChannelId': '38',
#   'endPlaceName': 'Kelvinbridge Subway',
#   'endPlaceStationNumber': 8418,
#   'endPlaceLat': 55.87500989,
#   'endPlaceLong': -4.28037107,
#   'durationSeconds': 684,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.079Z',
#   'updated': '2022-10-21T13:09:59.079Z',
#   'cityId': '237',
#   'bikeId': '129761',
#   'startDate': '2022-05-01T00:21:23Z',
#   'startPlaceId': '28521334',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Glasgow Central West',
#   'startPlaceStationNumber': 8216,
#   'startPlaceLat': 55.85853,
#   'startPlaceLong': -4.25973,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:37:52Z',
#   'endPlaceId': '349454',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Paisley Road Toll',
#   'endPlaceStationNumber': 8443,
#   'endPlaceLat': 55.85378,
#   'endPlaceLong': -4.279158,
#   'durationSeconds': 989,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.128Z',
#   'updated': '2022-10-21T13:09:59.128Z',
#   'cityId': '237',
#   'bikeId': '143237',
#   'startDate': '2022-05-01T00:22:23Z',
#   'startPlaceId': '349455',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'startPlaceStationNumber': 8444,
#   'startPlaceLat': 55.85191762,
#   'startPlaceLong': -4.29449022,
#   'startChannelId': None,
#   'endDate': '2022-05-01T02:57:56Z',
#   'endPlaceId': '349455',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'endPlaceStationNumber': 8444,
#   'endPlaceLat': 55.85191762,
#   'endPlaceLong': -4.29449022,
#   'durationSeconds': 9333,
#   'isInvalid': False,
#   'price': 5.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.18Z',
#   'updated': '2022-10-21T13:09:59.18Z',
#   'cityId': '237',
#   'bikeId': '143141',
#   'startDate': '2022-05-01T00:22:31Z',
#   'startPlaceId': '28521334',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Glasgow Central West',
#   'startPlaceStationNumber': 8216,
#   'startPlaceLat': 55.85853,
#   'startPlaceLong': -4.25973,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:22:52Z',
#   'endPlaceId': '28521334',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Glasgow Central West',
#   'endPlaceStationNumber': 8216,
#   'endPlaceLat': 55.85853,
#   'endPlaceLong': -4.25973,
#   'durationSeconds': 21,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.231Z',
#   'updated': '2022-10-21T13:09:59.231Z',
#   'cityId': '237',
#   'bikeId': '143141',
#   'startDate': '2022-05-01T00:26:12Z',
#   'startPlaceId': '28521334',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Glasgow Central West',
#   'startPlaceStationNumber': 8216,
#   'startPlaceLat': 55.85853,
#   'startPlaceLong': -4.25973,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:37:20Z',
#   'endPlaceId': '349454',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Paisley Road Toll',
#   'endPlaceStationNumber': 8443,
#   'endPlaceLat': 55.85378,
#   'endPlaceLong': -4.279158,
#   'durationSeconds': 668,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.291Z',
#   'updated': '2022-10-21T13:09:59.291Z',
#   'cityId': '237',
#   'bikeId': '129762',
#   'startDate': '2022-05-01T00:28:50Z',
#   'startPlaceId': '28521474',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Carrick Quay',
#   'startPlaceStationNumber': 8231,
#   'startPlaceLat': 55.85476,
#   'startPlaceLong': -4.25164,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:48:54Z',
#   'endPlaceId': '3812438',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Kelvinhaugh Street / Argyle Street',
#   'endPlaceStationNumber': 8451,
#   'endPlaceLat': 55.86522196,
#   'endPlaceLong': -4.28612709,
#   'durationSeconds': 1204,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.341Z',
#   'updated': '2022-10-21T13:09:59.341Z',
#   'cityId': '237',
#   'bikeId': '139441',
#   'startDate': '2022-05-01T00:29:39Z',
#   'startPlaceId': '31475534',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Springburn Railway Station',
#   'startPlaceStationNumber': 8237,
#   'startPlaceLat': 55.88223188,
#   'startPlaceLong': -4.23042834,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:41:12Z',
#   'endPlaceId': '6269626',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Woodside (North) - ELECTRIC',
#   'endPlaceStationNumber': 8465,
#   'endPlaceLat': 55.87506105,
#   'endPlaceLong': -4.27067757,
#   'durationSeconds': 693,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.39Z',
#   'updated': '2022-10-21T13:09:59.39Z',
#   'cityId': '237',
#   'bikeId': '143395',
#   'startDate': '2022-05-01T00:30:10Z',
#   'startPlaceId': '349458',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Eglinton Toll',
#   'startPlaceStationNumber': 8446,
#   'startPlaceLat': 55.84331359,
#   'startPlaceLong': -4.26225007,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:36:49Z',
#   'endPlaceId': '42614033',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Gorbals Library',
#   'endPlaceStationNumber': 8215,
#   'endPlaceLat': 55.84856441,
#   'endPlaceLong': -4.25099551,
#   'durationSeconds': 399,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.438Z',
#   'updated': '2022-10-21T13:09:59.438Z',
#   'cityId': '237',
#   'bikeId': '129637',
#   'startDate': '2022-05-01T00:30:47Z',
#   'startPlaceId': '266218',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Partick Interchange',
#   'startPlaceStationNumber': 8423,
#   'startPlaceLat': 55.8697069,
#   'startPlaceLong': -4.30845916,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:48:12Z',
#   'endPlaceId': '266169',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Trongate',
#   'endPlaceStationNumber': 8431,
#   'endPlaceLat': 55.85596149,
#   'endPlaceLong': -4.24467087,
#   'durationSeconds': 1045,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.487Z',
#   'updated': '2022-10-21T13:09:59.487Z',
#   'cityId': '237',
#   'bikeId': '143205',
#   'startDate': '2022-05-01T00:31:07Z',
#   'startPlaceId': '349450',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Bellgrove Railway Station (North) - ELECTRIC',
#   'startPlaceStationNumber': 8439,
#   'startPlaceLat': 55.85812327,
#   'startPlaceLong': -4.22451138,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:37:38Z',
#   'endPlaceId': '3812776',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Alexandra Park (south entrance) Alexandra Parade Railway Station',
#   'endPlaceStationNumber': 8457,
#   'endPlaceLat': 55.863128,
#   'endPlaceLong': -4.210282,
#   'durationSeconds': 391,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.539Z',
#   'updated': '2022-10-21T13:09:59.539Z',
#   'cityId': '237',
#   'bikeId': '143232',
#   'startDate': '2022-05-01T00:31:39Z',
#   'startPlaceId': '6269618',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Sauchiehall Street',
#   'startPlaceStationNumber': 8463,
#   'startPlaceLat': 55.865291,
#   'startPlaceLong': -4.261756,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:35:08Z',
#   'endPlaceId': '380893',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Buchanan Street Bus Station',
#   'endPlaceStationNumber': 8404,
#   'endPlaceLat': 55.86497513,
#   'endPlaceLong': -4.25266385,
#   'durationSeconds': 209,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.588Z',
#   'updated': '2022-10-21T13:09:59.588Z',
#   'cityId': '237',
#   'bikeId': '139455',
#   'startDate': '2022-05-01T00:31:49Z',
#   'startPlaceId': '45172531',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Queen Street Railway',
#   'startPlaceStationNumber': 8740,
#   'startPlaceLat': 55.86210198,
#   'startPlaceLong': -4.25230691,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:09:42Z',
#   'endPlaceId': '45172531',
#   'endPlaceCityId': '237',
#   'endChannelId': '15',
#   'endPlaceName': 'Queen Street Railway',
#   'endPlaceStationNumber': 8740,
#   'endPlaceLat': 55.86210198,
#   'endPlaceLong': -4.25230691,
#   'durationSeconds': 2273,
#   'isInvalid': True,
#   'price': 0.5,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.64Z',
#   'updated': '2022-10-21T13:09:59.64Z',
#   'cityId': '237',
#   'bikeId': '105839',
#   'startDate': '2022-05-01T00:33:06Z',
#   'startPlaceId': '264295',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - St Enoch Square',
#   'startPlaceStationNumber': 8410,
#   'startPlaceLat': 55.85682863,
#   'startPlaceLong': -4.25529242,
#   'startChannelId': None,
#   'endDate': '2022-05-01T11:54:12Z',
#   'endPlaceId': '3812694',
#   'endPlaceCityId': '237',
#   'endChannelId': '15',
#   'endPlaceName': 'ELECTRIC - Langside Hall',
#   'endPlaceStationNumber': 8454,
#   'endPlaceLat': 55.83160158,
#   'endPlaceLong': -4.27841306,
#   'durationSeconds': 40866,
#   'isInvalid': False,
#   'price': 10.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.689Z',
#   'updated': '2022-10-21T13:09:59.689Z',
#   'cityId': '237',
#   'bikeId': '143273',
#   'startDate': '2022-05-01T00:34:35Z',
#   'startPlaceId': '380893',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Buchanan Street Bus Station',
#   'startPlaceStationNumber': 8404,
#   'startPlaceLat': 55.86497513,
#   'startPlaceLong': -4.25266385,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:49:31Z',
#   'endPlaceId': '19548002',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Shakespeare Street (Maryhill) - ELECTRIC',
#   'endPlaceStationNumber': 8427,
#   'endPlaceLat': 55.88693447,
#   'endPlaceLong': -4.28502202,
#   'durationSeconds': 896,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.739Z',
#   'updated': '2022-10-21T13:09:59.739Z',
#   'cityId': '237',
#   'bikeId': '103810',
#   'startDate': '2022-05-01T00:35:41Z',
#   'startPlaceId': '264303',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Kelvinbridge Subway',
#   'startPlaceStationNumber': 8418,
#   'startPlaceLat': 55.87500989,
#   'startPlaceLong': -4.28037107,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:12:33Z',
#   'endPlaceId': '380893',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Buchanan Street Bus Station',
#   'endPlaceStationNumber': 8404,
#   'endPlaceLat': 55.86497513,
#   'endPlaceLong': -4.25266385,
#   'durationSeconds': 2212,
#   'isInvalid': False,
#   'price': 4.0,
#   'isEbike': True},
#  {'created': '2022-10-21T13:09:59.791Z',
#   'updated': '2022-10-21T13:09:59.791Z',
#   'cityId': '237',
#   'bikeId': '143008',
#   'startDate': '2022-05-01T00:43:01Z',
#   'startPlaceId': '266218',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Partick Interchange',
#   'startPlaceStationNumber': 8423,
#   'startPlaceLat': 55.8697069,
#   'startPlaceLong': -4.30845916,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:14:50Z',
#   'endPlaceId': '264304',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Kelvingrove Art Gallery - ELECTRIC',
#   'endPlaceStationNumber': 8420,
#   'endPlaceLat': 55.86835244,
#   'endPlaceLong': -4.28940475,
#   'durationSeconds': 1909,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.841Z',
#   'updated': '2022-10-21T13:09:59.841Z',
#   'cityId': '237',
#   'bikeId': '142983',
#   'startDate': '2022-05-01T00:43:31Z',
#   'startPlaceId': '266218',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Partick Interchange',
#   'startPlaceStationNumber': 8423,
#   'startPlaceLat': 55.8697069,
#   'startPlaceLong': -4.30845916,
#   'startChannelId': None,
#   'endDate': '2022-05-01T02:05:32Z',
#   'endPlaceId': '79928892',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'BIKE 46721',
#   'endPlaceStationNumber': None,
#   'endPlaceLat': 55.86415111,
#   'endPlaceLong': -4.25599944,
#   'durationSeconds': 4921,
#   'isInvalid': False,
#   'price': 3.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.891Z',
#   'updated': '2022-10-21T13:09:59.891Z',
#   'cityId': '237',
#   'bikeId': '143232',
#   'startDate': '2022-05-01T00:45:10Z',
#   'startPlaceId': '380893',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Buchanan Street Bus Station',
#   'startPlaceStationNumber': 8404,
#   'startPlaceLat': 55.86497513,
#   'startPlaceLong': -4.25266385,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:09:33Z',
#   'endPlaceId': '266218',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Partick Interchange',
#   'endPlaceStationNumber': 8423,
#   'endPlaceLat': 55.8697069,
#   'endPlaceLong': -4.30845916,
#   'durationSeconds': 1463,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.943Z',
#   'updated': '2022-10-21T13:09:59.943Z',
#   'cityId': '237',
#   'bikeId': '62431',
#   'startDate': '2022-05-01T00:47:11Z',
#   'startPlaceId': '19164571',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Central Station',
#   'startPlaceStationNumber': 8401,
#   'startPlaceLat': 55.86077565,
#   'startPlaceLong': -4.2585969,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:06:10Z',
#   'endPlaceId': '21603723',
#   'endPlaceCityId': '237',
#   'endChannelId': '38',
#   'endPlaceName': 'Ibrox',
#   'endPlaceStationNumber': 8452,
#   'endPlaceLat': 55.85098714,
#   'endPlaceLong': -4.30144787,
#   'durationSeconds': 1139,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:09:59.994Z',
#   'updated': '2022-10-21T13:09:59.994Z',
#   'cityId': '237',
#   'bikeId': '143257',
#   'startDate': '2022-05-01T00:47:14Z',
#   'startPlaceId': '266169',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Trongate',
#   'startPlaceStationNumber': 8431,
#   'startPlaceLat': 55.85596149,
#   'startPlaceLong': -4.24467087,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:52:28Z',
#   'endPlaceId': '264298',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Glasgow Green',
#   'endPlaceStationNumber': 8412,
#   'endPlaceLat': 55.84945,
#   'endPlaceLong': -4.23375,
#   'durationSeconds': 314,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.046Z',
#   'updated': '2022-10-21T13:10:00.046Z',
#   'cityId': '237',
#   'bikeId': '129674',
#   'startDate': '2022-05-01T00:49:03Z',
#   'startPlaceId': '264392',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Argyle Street Railway Station',
#   'startPlaceStationNumber': 8411,
#   'startPlaceLat': 55.85757531,
#   'startPlaceLong': -4.24997628,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:04:46Z',
#   'endPlaceId': '349460',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Queens Park Railway Station',
#   'endPlaceStationNumber': 8447,
#   'endPlaceLat': 55.83497577,
#   'endPlaceLong': -4.26548481,
#   'durationSeconds': 943,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.096Z',
#   'updated': '2022-10-21T13:10:00.096Z',
#   'cityId': '237',
#   'bikeId': '139441',
#   'startDate': '2022-05-01T00:49:07Z',
#   'startPlaceId': '6269626',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Woodside (North) - ELECTRIC',
#   'startPlaceStationNumber': 8465,
#   'startPlaceLat': 55.87506105,
#   'startPlaceLong': -4.27067757,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:05:08Z',
#   'endPlaceId': '31475534',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Springburn Railway Station',
#   'endPlaceStationNumber': 8237,
#   'endPlaceLat': 55.88223188,
#   'endPlaceLong': -4.23042834,
#   'durationSeconds': 961,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.146Z',
#   'updated': '2022-10-21T13:10:00.146Z',
#   'cityId': '237',
#   'bikeId': '129637',
#   'startDate': '2022-05-01T00:49:25Z',
#   'startPlaceId': '266169',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Trongate',
#   'startPlaceStationNumber': 8431,
#   'startPlaceLat': 55.85596149,
#   'startPlaceLong': -4.24467087,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:10:21Z',
#   'endPlaceId': '3812770',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Dalmarnock Railway Station - ELECTRIC',
#   'endPlaceStationNumber': 8456,
#   'endPlaceLat': 55.84256061,
#   'endPlaceLong': -4.21770394,
#   'durationSeconds': 1256,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.195Z',
#   'updated': '2022-10-21T13:10:00.195Z',
#   'cityId': '237',
#   'bikeId': '143295',
#   'startDate': '2022-05-01T00:50:01Z',
#   'startPlaceId': '264308',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Mitchell Library',
#   'startPlaceStationNumber': 8425,
#   'startPlaceLat': 55.86478849,
#   'startPlaceLong': -4.27185237,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:01:04Z',
#   'endPlaceId': '266218',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Partick Interchange',
#   'endPlaceStationNumber': 8423,
#   'endPlaceLat': 55.8697069,
#   'endPlaceLong': -4.30845916,
#   'durationSeconds': 663,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.245Z',
#   'updated': '2022-10-21T13:10:00.245Z',
#   'cityId': '237',
#   'bikeId': '139412',
#   'startDate': '2022-05-01T00:50:53Z',
#   'startPlaceId': '266169',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Trongate',
#   'startPlaceStationNumber': 8431,
#   'startPlaceLat': 55.85596149,
#   'startPlaceLong': -4.24467087,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:10:44Z',
#   'endPlaceId': '3812770',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Dalmarnock Railway Station - ELECTRIC',
#   'endPlaceStationNumber': 8456,
#   'endPlaceLat': 55.84256061,
#   'endPlaceLong': -4.21770394,
#   'durationSeconds': 1191,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.297Z',
#   'updated': '2022-10-21T13:10:00.297Z',
#   'cityId': '237',
#   'bikeId': '143290',
#   'startDate': '2022-05-01T00:54:36Z',
#   'startPlaceId': '19164571',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Central Station',
#   'startPlaceStationNumber': 8401,
#   'startPlaceLat': 55.86077565,
#   'startPlaceLong': -4.2585969,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:34:23Z',
#   'endPlaceId': '6269629',
#   'endPlaceCityId': '237',
#   'endChannelId': '15',
#   'endPlaceName': 'Battlefield - ELECTRIC',
#   'endPlaceStationNumber': 8466,
#   'endPlaceLat': 55.82739548,
#   'endPlaceLong': -4.26531851,
#   'durationSeconds': 2387,
#   'isInvalid': False,
#   'price': 2.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.348Z',
#   'updated': '2022-10-21T13:10:00.348Z',
#   'cityId': '237',
#   'bikeId': '143398',
#   'startDate': '2022-05-01T00:55:00Z',
#   'startPlaceId': '264301',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Queen Margaret Drive / Maryhill Road',
#   'startPlaceStationNumber': 8419,
#   'startPlaceLat': 55.8849,
#   'startPlaceLong': -4.281414,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:08:35Z',
#   'endPlaceId': '315912',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Finnieston Street',
#   'endPlaceStationNumber': 8438,
#   'endPlaceLat': 55.86342182,
#   'endPlaceLong': -4.28067684,
#   'durationSeconds': 815,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.398Z',
#   'updated': '2022-10-21T13:10:00.398Z',
#   'cityId': '237',
#   'bikeId': '139370',
#   'startDate': '2022-05-01T00:55:02Z',
#   'startPlaceId': '264299',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Broomielaw',
#   'startPlaceStationNumber': 8413,
#   'startPlaceLat': 55.8565998,
#   'startPlaceLong': -4.26352143,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:08:05Z',
#   'endPlaceId': '7145152',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Shields Road',
#   'endPlaceStationNumber': 8403,
#   'endPlaceLat': 55.84581338,
#   'endPlaceLong': -4.2752105,
#   'durationSeconds': 783,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.448Z',
#   'updated': '2022-10-21T13:10:00.448Z',
#   'cityId': '237',
#   'bikeId': '143043',
#   'startDate': '2022-05-01T00:56:01Z',
#   'startPlaceId': '266168',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Gallery of Modern Art',
#   'startPlaceStationNumber': 8430,
#   'startPlaceLat': 55.85971592,
#   'startPlaceLong': -4.25194502,
#   'startChannelId': None,
#   'endDate': '2022-05-01T00:56:17Z',
#   'endPlaceId': '266168',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Gallery of Modern Art',
#   'endPlaceStationNumber': 8430,
#   'endPlaceLat': 55.85971592,
#   'endPlaceLong': -4.25194502,
#   'durationSeconds': 16,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.502Z',
#   'updated': '2022-10-21T13:10:00.502Z',
#   'cityId': '237',
#   'bikeId': '143006',
#   'startDate': '2022-05-01T00:56:37Z',
#   'startPlaceId': '6269618',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Sauchiehall Street',
#   'startPlaceStationNumber': 8463,
#   'startPlaceLat': 55.865291,
#   'startPlaceLong': -4.261756,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:03:08Z',
#   'endPlaceId': '266170',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'University of Strathclyde (South)',
#   'endPlaceStationNumber': 8433,
#   'endPlaceLat': 55.860633,
#   'endPlaceLong': -4.2419,
#   'durationSeconds': 391,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.549Z',
#   'updated': '2022-10-21T13:10:00.549Z',
#   'cityId': '237',
#   'bikeId': '143022',
#   'startDate': '2022-05-01T00:57:27Z',
#   'startPlaceId': '3812770',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Dalmarnock Railway Station - ELECTRIC',
#   'startPlaceStationNumber': 8456,
#   'startPlaceLat': 55.84256061,
#   'startPlaceLong': -4.21770394,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:10:45Z',
#   'endPlaceId': '266170',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'University of Strathclyde (South)',
#   'endPlaceStationNumber': 8433,
#   'endPlaceLat': 55.860633,
#   'endPlaceLong': -4.2419,
#   'durationSeconds': 798,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.597Z',
#   'updated': '2022-10-21T13:10:00.597Z',
#   'cityId': '237',
#   'bikeId': '116870',
#   'startDate': '2022-05-01T00:59:44Z',
#   'startPlaceId': '264299',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Broomielaw',
#   'startPlaceStationNumber': 8413,
#   'startPlaceLat': 55.8565998,
#   'startPlaceLong': -4.26352143,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:02:52Z',
#   'endPlaceId': '264299',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Broomielaw',
#   'endPlaceStationNumber': 8413,
#   'endPlaceLat': 55.8565998,
#   'endPlaceLong': -4.26352143,
#   'durationSeconds': 188,
#   'isInvalid': False,
#   'price': 2.0,
#   'isEbike': True},
#  {'created': '2022-10-21T13:10:00.649Z',
#   'updated': '2022-10-21T13:10:00.649Z',
#   'cityId': '237',
#   'bikeId': '142980',
#   'startDate': '2022-05-01T00:59:46Z',
#   'startPlaceId': '264295',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - St Enoch Square',
#   'startPlaceStationNumber': 8410,
#   'startPlaceLat': 55.85682863,
#   'startPlaceLong': -4.25529242,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:00:07Z',
#   'endPlaceId': '264295',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - St Enoch Square',
#   'endPlaceStationNumber': 8410,
#   'endPlaceLat': 55.85682863,
#   'endPlaceLong': -4.25529242,
#   'durationSeconds': 21,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.698Z',
#   'updated': '2022-10-21T13:10:00.698Z',
#   'cityId': '237',
#   'bikeId': '116930',
#   'startDate': '2022-05-01T00:59:50Z',
#   'startPlaceId': '264292',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'George Square - ELECTRIC',
#   'startPlaceStationNumber': 8406,
#   'startPlaceLat': 55.86155,
#   'startPlaceLong': -4.2494,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:14:58Z',
#   'endPlaceId': '3812792',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Duke Street Railway Station',
#   'endPlaceStationNumber': 8458,
#   'endPlaceLat': 55.858222,
#   'endPlaceLong': -4.213473,
#   'durationSeconds': 908,
#   'isInvalid': False,
#   'price': 2.0,
#   'isEbike': True},
#  {'created': '2022-10-21T13:10:00.747Z',
#   'updated': '2022-10-21T13:10:00.747Z',
#   'cityId': '237',
#   'bikeId': '116863',
#   'startDate': '2022-05-01T01:02:30Z',
#   'startPlaceId': '349455',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'startPlaceStationNumber': 8444,
#   'startPlaceLat': 55.85191762,
#   'startPlaceLong': -4.29449022,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:10:57Z',
#   'endPlaceId': '42487542',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Emirates Arena',
#   'endPlaceStationNumber': None,
#   'endPlaceLat': 55.8465151,
#   'endPlaceLong': -4.20847714,
#   'durationSeconds': 507,
#   'isInvalid': False,
#   'price': 2.0,
#   'isEbike': True},
#  {'created': '2022-10-21T13:10:00.795Z',
#   'updated': '2022-10-21T13:10:00.795Z',
#   'cityId': '237',
#   'bikeId': '143187',
#   'startDate': '2022-05-01T01:02:32Z',
#   'startPlaceId': '264295',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - St Enoch Square',
#   'startPlaceStationNumber': 8410,
#   'startPlaceLat': 55.85682863,
#   'startPlaceLong': -4.25529242,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:17:36Z',
#   'endPlaceId': '3812694',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Langside Hall',
#   'endPlaceStationNumber': 8454,
#   'endPlaceLat': 55.83160158,
#   'endPlaceLong': -4.27841306,
#   'durationSeconds': 904,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.845Z',
#   'updated': '2022-10-21T13:10:00.845Z',
#   'cityId': '237',
#   'bikeId': '143175',
#   'startDate': '2022-05-01T01:02:53Z',
#   'startPlaceId': '28521334',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Glasgow Central West',
#   'startPlaceStationNumber': 8216,
#   'startPlaceLat': 55.85853,
#   'startPlaceLong': -4.25973,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:23:48Z',
#   'endPlaceId': '42417389',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Cathcart Railway Station',
#   'endPlaceStationNumber': 8206,
#   'endPlaceLat': 55.81733845,
#   'endPlaceLong': -4.26268793,
#   'durationSeconds': 1255,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.894Z',
#   'updated': '2022-10-21T13:10:00.894Z',
#   'cityId': '237',
#   'bikeId': '143295',
#   'startDate': '2022-05-01T01:04:41Z',
#   'startPlaceId': '266218',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Partick Interchange',
#   'startPlaceStationNumber': 8423,
#   'startPlaceLat': 55.8697069,
#   'startPlaceLong': -4.30845916,
#   'startChannelId': None,
#   'endDate': '2022-05-01T02:38:20Z',
#   'endPlaceId': '266218',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Partick Interchange',
#   'endPlaceStationNumber': 8423,
#   'endPlaceLat': 55.8697069,
#   'endPlaceLong': -4.30845916,
#   'durationSeconds': 5619,
#   'isInvalid': False,
#   'price': 3.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.943Z',
#   'updated': '2022-10-21T13:10:00.943Z',
#   'cityId': '237',
#   'bikeId': '129726',
#   'startDate': '2022-05-01T01:09:31Z',
#   'startPlaceId': '349461',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Queens Park West',
#   'startPlaceStationNumber': 8448,
#   'startPlaceLat': 55.83504205,
#   'startPlaceLong': -4.2723459,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:40:49Z',
#   'endPlaceId': '3812792',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Duke Street Railway Station',
#   'endPlaceStationNumber': 8458,
#   'endPlaceLat': 55.858222,
#   'endPlaceLong': -4.213473,
#   'durationSeconds': 1878,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:00.993Z',
#   'updated': '2022-10-21T13:10:00.993Z',
#   'cityId': '237',
#   'bikeId': '142980',
#   'startDate': '2022-05-01T01:12:09Z',
#   'startPlaceId': '264295',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - St Enoch Square',
#   'startPlaceStationNumber': 8410,
#   'startPlaceLat': 55.85682863,
#   'startPlaceLong': -4.25529242,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:24:07Z',
#   'endPlaceId': '349460',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - Queens Park Railway Station',
#   'endPlaceStationNumber': 8447,
#   'endPlaceLat': 55.83497577,
#   'endPlaceLong': -4.26548481,
#   'durationSeconds': 718,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:01.042Z',
#   'updated': '2022-10-21T13:10:01.042Z',
#   'cityId': '237',
#   'bikeId': '116889',
#   'startDate': '2022-05-01T01:13:17Z',
#   'startPlaceId': '264293',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Merchant Square',
#   'startPlaceStationNumber': 8407,
#   'startPlaceLat': 55.858167,
#   'startPlaceLong': -4.245483,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:19:43Z',
#   'endPlaceId': '349450',
#   'endPlaceCityId': '237',
#   'endChannelId': '37',
#   'endPlaceName': 'Bellgrove Railway Station (North) - ELECTRIC',
#   'endPlaceStationNumber': 8439,
#   'endPlaceLat': 55.85812327,
#   'endPlaceLong': -4.22451138,
#   'durationSeconds': 386,
#   'isInvalid': False,
#   'price': 2.0,
#   'isEbike': True},
#  {'created': '2022-10-21T13:10:01.092Z',
#   'updated': '2022-10-21T13:10:01.092Z',
#   'cityId': '237',
#   'bikeId': '116901',
#   'startDate': '2022-05-01T01:13:42Z',
#   'startPlaceId': '264304',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Kelvingrove Art Gallery - ELECTRIC',
#   'startPlaceStationNumber': 8420,
#   'startPlaceLat': 55.86835244,
#   'startPlaceLong': -4.28940475,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:14:12Z',
#   'endPlaceId': '264304',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Kelvingrove Art Gallery - ELECTRIC',
#   'endPlaceStationNumber': 8420,
#   'endPlaceLat': 55.86835244,
#   'endPlaceLong': -4.28940475,
#   'durationSeconds': 30,
#   'isInvalid': False,
#   'price': 2.0,
#   'isEbike': True},
#  {'created': '2022-10-21T13:10:01.143Z',
#   'updated': '2022-10-21T13:10:01.143Z',
#   'cityId': '237',
#   'bikeId': '116867',
#   'startDate': '2022-05-01T01:14:21Z',
#   'startPlaceId': '3812438',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Kelvinhaugh Street / Argyle Street',
#   'startPlaceStationNumber': 8451,
#   'startPlaceLat': 55.86522196,
#   'startPlaceLong': -4.28612709,
#   'startChannelId': None,
#   'endDate': '2022-05-01T01:23:11Z',
#   'endPlaceId': '31234332',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Hyndland Road',
#   'endPlaceStationNumber': 8232,
#   'endPlaceLat': 55.87697501,
#   'endPlaceLong': -4.3062222,
#   'durationSeconds': 530,
#   'isInvalid': True,
#   'price': 2.0,
#   'isEbike': True},
#  {'created': '2022-10-21T13:10:01.194Z',
#   'updated': '2022-10-21T13:10:01.194Z',
#   'cityId': '237',
#   'bikeId': '116901',
#   'startDate': '2022-05-01T01:14:46Z',
#   'startPlaceId': '264304',
# ...
#   'startPlaceName': 'BIKE 46626',
#   'startPlaceStationNumber': None,
#   'startPlaceLat': 55.86005778,
#   'startPlaceLong': -4.25579667,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:26:45Z',
#   'endPlaceId': '80036278',
#   'endPlaceCityId': '237',
#   'endChannelId': None,
#   'endPlaceName': 'BIKE 46626',
#   'endPlaceStationNumber': None,
#   'endPlaceLat': 55.86005778,
#   'endPlaceLong': -4.25579667,
#   'durationSeconds': 32,
#   'isInvalid': True,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:47.646Z',
#   'updated': '2022-10-21T13:10:47.646Z',
#   'cityId': '237',
#   'bikeId': '116915',
#   'startDate': '2022-05-01T18:26:29Z',
#   'startPlaceId': '3812438',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Kelvinhaugh Street / Argyle Street',
#   'startPlaceStationNumber': 8451,
#   'startPlaceLat': 55.86522196,
#   'startPlaceLong': -4.28612709,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:45:45Z',
#   'endPlaceId': '349453',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'City of Glasgow College (Riverside Campus) - ELECTRIC',
#   'endPlaceStationNumber': 8442,
#   'endPlaceLat': 55.850554,
#   'endPlaceLong': -4.248127,
#   'durationSeconds': 1156,
#   'isInvalid': False,
#   'price': 2.0,
#   'isEbike': True},
#  {'created': '2022-10-21T13:10:47.696Z',
#   'updated': '2022-10-21T13:10:47.696Z',
#   'cityId': '237',
#   'bikeId': '139422',
#   'startDate': '2022-05-01T18:26:38Z',
#   'startPlaceId': '264300',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#   'startPlaceStationNumber': 8415,
#   'startPlaceLat': 55.85908067,
#   'startPlaceLong': -4.2872107,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:39:51Z',
#   'endPlaceId': '80099379',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'BIKE 46791',
#   'endPlaceStationNumber': None,
#   'endPlaceLat': 55.86106667,
#   'endPlaceLong': -4.24941333,
#   'durationSeconds': 793,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:47.747Z',
#   'updated': '2022-10-21T13:10:47.747Z',
#   'cityId': '237',
#   'bikeId': '139458',
#   'startDate': '2022-05-01T18:29:47Z',
#   'startPlaceId': '45172531',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Queen Street Railway',
#   'startPlaceStationNumber': 8740,
#   'startPlaceLat': 55.86210198,
#   'startPlaceLong': -4.25230691,
#   'startChannelId': None,
#   'endDate': '2022-05-01T20:29:16Z',
#   'endPlaceId': '19738176',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Riverside Museum',
#   'endPlaceStationNumber': 8416,
#   'endPlaceLat': 55.865683,
#   'endPlaceLong': -4.305367,
#   'durationSeconds': 7169,
#   'isInvalid': False,
#   'price': 4.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:47.797Z',
#   'updated': '2022-10-21T13:10:47.797Z',
#   'cityId': '237',
#   'bikeId': '143249',
#   'startDate': '2022-05-01T18:30:00Z',
#   'startPlaceId': '264303',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Kelvinbridge Subway',
#   'startPlaceStationNumber': 8418,
#   'startPlaceLat': 55.87500989,
#   'startPlaceLong': -4.28037107,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:42:08Z',
#   'endPlaceId': '80099924',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'BIKE 46455',
#   'endPlaceStationNumber': None,
#   'endPlaceLat': 55.86486222,
#   'endPlaceLong': -4.25739333,
#   'durationSeconds': 728,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:47.845Z',
#   'updated': '2022-10-21T13:10:47.845Z',
#   'cityId': '237',
#   'bikeId': '143151',
#   'startDate': '2022-05-01T18:30:17Z',
#   'startPlaceId': '349455',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'startPlaceStationNumber': 8444,
#   'startPlaceLat': 55.85191762,
#   'startPlaceLong': -4.29449022,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:55:08Z',
#   'endPlaceId': '264295',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'ELECTRIC - St Enoch Square',
#   'endPlaceStationNumber': 8410,
#   'endPlaceLat': 55.85682863,
#   'endPlaceLong': -4.25529242,
#   'durationSeconds': 1491,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:47.895Z',
#   'updated': '2022-10-21T13:10:47.895Z',
#   'cityId': '237',
#   'bikeId': '143301',
#   'startDate': '2022-05-01T18:30:37Z',
#   'startPlaceId': '55600054',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Bellahouston Park',
#   'startPlaceStationNumber': 8201,
#   'startPlaceLat': 55.84901377,
#   'startPlaceLong': -4.31486264,
#   'startChannelId': None,
#   'endDate': '2022-05-01T19:03:52Z',
#   'endPlaceId': '19738176',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Riverside Museum',
#   'endPlaceStationNumber': 8416,
#   'endPlaceLat': 55.865683,
#   'endPlaceLong': -4.305367,
#   'durationSeconds': 1995,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:47.947Z',
#   'updated': '2022-10-21T13:10:47.947Z',
#   'cityId': '237',
#   'bikeId': '143194',
#   'startDate': '2022-05-01T18:30:40Z',
#   'startPlaceId': '349451',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Barrowlands',
#   'startPlaceStationNumber': 8440,
#   'startPlaceLat': 55.85515155,
#   'startPlaceLong': -4.23529387,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:47:57Z',
#   'endPlaceId': '41822435',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Glasgow Science Centre',
#   'endPlaceStationNumber': 8426,
#   'endPlaceLat': 55.85849961,
#   'endPlaceLong': -4.29297209,
#   'durationSeconds': 1037,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48Z',
#   'updated': '2022-10-21T13:10:48Z',
#   'cityId': '237',
#   'bikeId': '143178',
#   'startDate': '2022-05-01T18:30:50Z',
#   'startPlaceId': '264316',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Bridge Street Subway',
#   'startPlaceStationNumber': 8432,
#   'startPlaceLat': 55.8525,
#   'startPlaceLong': -4.25885,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:41:49Z',
#   'endPlaceId': '19548484',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Cambridge Street - ELECTRIC',
#   'endPlaceStationNumber': 8434,
#   'endPlaceLat': 55.865063,
#   'endPlaceLong': -4.260291,
#   'durationSeconds': 659,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48.05Z',
#   'updated': '2022-10-21T13:10:48.05Z',
#   'cityId': '237',
#   'bikeId': '143305',
#   'startDate': '2022-05-01T18:31:51Z',
#   'startPlaceId': '264300',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#   'startPlaceStationNumber': 8415,
#   'startPlaceLat': 55.85908067,
#   'startPlaceLong': -4.2872107,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:47:36Z',
#   'endPlaceId': '3812438',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Kelvinhaugh Street / Argyle Street',
#   'endPlaceStationNumber': 8451,
#   'endPlaceLat': 55.86522196,
#   'endPlaceLong': -4.28612709,
#   'durationSeconds': 945,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48.101Z',
#   'updated': '2022-10-21T13:10:48.101Z',
#   'cityId': '237',
#   'bikeId': '139455',
#   'startDate': '2022-05-01T18:32:07Z',
#   'startPlaceId': '349455',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Cessnock Subway Station',
#   'startPlaceStationNumber': 8444,
#   'startPlaceLat': 55.85191762,
#   'startPlaceLong': -4.29449022,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:50:32Z',
#   'endPlaceId': '45172531',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Queen Street Railway',
#   'endPlaceStationNumber': 8740,
#   'endPlaceLat': 55.86210198,
#   'endPlaceLong': -4.25230691,
#   'durationSeconds': 1105,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48.15Z',
#   'updated': '2022-10-21T13:10:48.15Z',
#   'cityId': '237',
#   'bikeId': '143258',
#   'startDate': '2022-05-01T18:33:03Z',
#   'startPlaceId': '264300',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#   'startPlaceStationNumber': 8415,
#   'startPlaceLat': 55.85908067,
#   'startPlaceLong': -4.2872107,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:47:30Z',
#   'endPlaceId': '3812438',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Kelvinhaugh Street / Argyle Street',
#   'endPlaceStationNumber': 8451,
#   'endPlaceLat': 55.86522196,
#   'endPlaceLong': -4.28612709,
#   'durationSeconds': 867,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48.2Z',
#   'updated': '2022-10-21T13:10:48.2Z',
#   'cityId': '237',
#   'bikeId': '143183',
#   'startDate': '2022-05-01T18:33:09Z',
#   'startPlaceId': '264300',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#   'startPlaceStationNumber': 8415,
#   'startPlaceLat': 55.85908067,
#   'startPlaceLong': -4.2872107,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:47:36Z',
#   'endPlaceId': '3812438',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Kelvinhaugh Street / Argyle Street',
#   'endPlaceStationNumber': 8451,
#   'endPlaceLat': 55.86522196,
#   'endPlaceLong': -4.28612709,
#   'durationSeconds': 867,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48.25Z',
#   'updated': '2022-10-21T13:10:48.25Z',
#   'cityId': '237',
#   'bikeId': '143085',
#   'startDate': '2022-05-01T18:34:02Z',
#   'startPlaceId': '264300',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#   'startPlaceStationNumber': 8415,
#   'startPlaceLat': 55.85908067,
#   'startPlaceLong': -4.2872107,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:34:21Z',
#   'endPlaceId': '264300',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#   'endPlaceStationNumber': 8415,
#   'endPlaceLat': 55.85908067,
#   'endPlaceLong': -4.2872107,
#   'durationSeconds': 19,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48.3Z',
#   'updated': '2022-10-21T13:10:48.3Z',
#   'cityId': '237',
#   'bikeId': '142998',
#   'startDate': '2022-05-01T18:34:14Z',
#   'startPlaceId': '349460',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'ELECTRIC - Queens Park Railway Station',
#   'startPlaceStationNumber': 8447,
#   'startPlaceLat': 55.83497577,
#   'startPlaceLong': -4.26548481,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:38:53Z',
#   'endPlaceId': '349458',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Eglinton Toll',
#   'endPlaceStationNumber': 8446,
#   'endPlaceLat': 55.84331359,
#   'endPlaceLong': -4.26225007,
#   'durationSeconds': 279,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48.349Z',
#   'updated': '2022-10-21T13:10:48.349Z',
#   'cityId': '237',
#   'bikeId': '143158',
#   'startDate': '2022-05-01T18:34:23Z',
#   'startPlaceId': '349454',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Paisley Road Toll',
#   'startPlaceStationNumber': 8443,
#   'startPlaceLat': 55.85378,
#   'startPlaceLong': -4.279158,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:58:14Z',
#   'endPlaceId': '6269629',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Battlefield - ELECTRIC',
#   'endPlaceStationNumber': 8466,
#   'endPlaceLat': 55.82739548,
#   'endPlaceLong': -4.26531851,
#   'durationSeconds': 1431,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48.399Z',
#   'updated': '2022-10-21T13:10:48.399Z',
#   'cityId': '237',
#   'bikeId': '129673',
#   'startDate': '2022-05-01T18:36:50Z',
#   'startPlaceId': '264300',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#   'startPlaceStationNumber': 8415,
#   'startPlaceLat': 55.85908067,
#   'startPlaceLong': -4.2872107,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:37:25Z',
#   'endPlaceId': '264300',
#   'endPlaceCityId': '237',
#   'endChannelId': None,
#   'endPlaceName': 'Scottish Event Campus (formerly S.E.C.C)',
#   'endPlaceStationNumber': 8415,
#   'endPlaceLat': 55.85908067,
#   'endPlaceLong': -4.2872107,
#   'durationSeconds': 35,
#   'isInvalid': True,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48.448Z',
#   'updated': '2022-10-21T13:10:48.448Z',
#   'cityId': '237',
#   'bikeId': '143259',
#   'startDate': '2022-05-01T18:36:56Z',
#   'startPlaceId': '28521334',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Glasgow Central West',
#   'startPlaceStationNumber': 8216,
#   'startPlaceLat': 55.85853,
#   'startPlaceLong': -4.25973,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:49:16Z',
#   'endPlaceId': '3812438',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Kelvinhaugh Street / Argyle Street',
#   'endPlaceStationNumber': 8451,
#   'endPlaceLat': 55.86522196,
#   'endPlaceLong': -4.28612709,
#   'durationSeconds': 740,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48.499Z',
#   'updated': '2022-10-21T13:10:48.499Z',
#   'cityId': '237',
#   'bikeId': '116881',
#   'startDate': '2022-05-01T18:36:56Z',
#   'startPlaceId': '28521334',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Glasgow Central West',
#   'startPlaceStationNumber': 8216,
#   'startPlaceLat': 55.85853,
#   'startPlaceLong': -4.25973,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:49:25Z',
#   'endPlaceId': '3812438',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Kelvinhaugh Street / Argyle Street',
#   'endPlaceStationNumber': 8451,
#   'endPlaceLat': 55.86522196,
#   'endPlaceLong': -4.28612709,
#   'durationSeconds': 749,
#   'isInvalid': False,
#   'price': 2.0,
#   'isEbike': True},
#  {'created': '2022-10-21T13:10:48.548Z',
#   'updated': '2022-10-21T13:10:48.548Z',
#   'cityId': '237',
#   'bikeId': '129652',
#   'startDate': '2022-05-01T18:37:10Z',
#   'startPlaceId': '28521474',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Carrick Quay',
#   'startPlaceStationNumber': 8231,
#   'startPlaceLat': 55.85476,
#   'startPlaceLong': -4.25164,
#   'startChannelId': None,
#   'endDate': '2022-05-01T19:11:52Z',
#   'endPlaceId': '28521474',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Carrick Quay',
#   'endPlaceStationNumber': 8231,
#   'endPlaceLat': 55.85476,
#   'endPlaceLong': -4.25164,
#   'durationSeconds': 2082,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48.597Z',
#   'updated': '2022-10-21T13:10:48.597Z',
#   'cityId': '237',
#   'bikeId': '129681',
#   'startDate': '2022-05-01T18:37:32Z',
#   'startPlaceId': '349453',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'City of Glasgow College (Riverside Campus) - ELECTRIC',
#   'startPlaceStationNumber': 8442,
#   'startPlaceLat': 55.850554,
#   'startPlaceLong': -4.248127,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:59:51Z',
#   'endPlaceId': '42613734',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'Riddrie South',
#   'endPlaceStationNumber': 8212,
#   'endPlaceLat': 55.8674046,
#   'endPlaceLong': -4.19278805,
#   'durationSeconds': 1339,
#   'isInvalid': False,
#   'price': 0.0,
#   'isEbike': False},
#  {'created': '2022-10-21T13:10:48.646Z',
#   'updated': '2022-10-21T13:10:48.646Z',
#   'cityId': '237',
#   'bikeId': '139411',
#   'startDate': '2022-05-01T18:37:55Z',
#   'startPlaceId': '6269618',
#   'startPlaceCityId': '237',
#   'startPlaceName': 'Sauchiehall Street',
#   'startPlaceStationNumber': 8463,
#   'startPlaceLat': 55.865291,
#   'startPlaceLong': -4.261756,
#   'startChannelId': None,
#   'endDate': '2022-05-01T18:44:54Z',
#   'endPlaceId': '266171',
#   'endPlaceCityId': '237',
#   'endChannelId': '381',
#   'endPlaceName': 'University of Glasgow (East) - ELECTRIC',
#   'endPlaceStationNumber': 8435,
#   'endPlaceLat': 55.87176257,
#   'endPlaceLong': -4.27806973,
#   'durationSeconds': 419,
#   'isInvalid': False,
#   'price': 1.0,
#   'isEbike': False},
#  ...]

# %%
rental_pd = pd.DataFrame(rental_data)
#Can you guess what we are doing here?
rental_pd.head()
# Out:
#                     created                   updated cityId  bikeId  \
# 0  2022-10-21T13:09:57.926Z  2022-10-21T13:09:57.926Z    237  116870
# 1  2022-10-21T13:09:57.975Z  2022-10-21T13:09:57.975Z    237  143384
# 2  2022-10-21T13:09:58.026Z  2022-10-21T13:09:58.026Z    237  129744
# 3  2022-10-21T13:09:58.076Z  2022-10-21T13:09:58.076Z    237  143168
# 4  2022-10-21T13:09:58.126Z  2022-10-21T13:09:58.126Z    237  143248
#
#               startDate startPlaceId startPlaceCityId  \
# 0  2022-05-01T00:01:40Z       264299              237
# 1  2022-05-01T00:04:17Z     28521547              237
# 2  2022-05-01T00:04:24Z       266171              237
# 3  2022-05-01T00:04:29Z       349455              237
# 4  2022-05-01T00:04:40Z       349455              237
#
#                             startPlaceName  startPlaceStationNumber  \
# 0                    ELECTRIC - Broomielaw                   8413.0
# 1                        King Street South                   8230.0
# 2  University of Glasgow (East) - ELECTRIC                   8435.0
# 3       ELECTRIC - Cessnock Subway Station                   8444.0
# 4       ELECTRIC - Cessnock Subway Station                   8444.0
#
#    startPlaceLat  ...  endPlaceCityId endChannelId  \
# 0      55.856600  ...             237          381
# 1      55.855860  ...             237          381
# 2      55.871763  ...             237          381
# 3      55.851918  ...             237          381
# 4      55.851918  ...             237          381
#
#                                         endPlaceName endPlaceStationNumber  \
# 0                              ELECTRIC - Broomielaw                8413.0
# 1  Alexandra Park (south entrance) Alexandra Para...                8457.0
# 2                         Botanic Gardens - ELECTRIC                8417.0
# 3                 ELECTRIC - Cessnock Subway Station                8444.0
# 4                         ELECTRIC - St Enoch Square                8410.0
#
#   endPlaceLat endPlaceLong durationSeconds  isInvalid  price  isEbike
# 0   55.856600    -4.263521              56      False    2.0     True
# 1   55.863128    -4.210282            1097      False    1.0    False
# 2   55.878278    -4.288487             344      False    1.0    False
# 3   55.851918    -4.294490           10400      False    6.0    False
# 4   55.856829    -4.255292            4611      False    3.0    False
#
# [5 rows x 24 columns]

# %%
rental_pd.shape

# %%
rental_pd.columns

# %%
# Check for NaN in the coordinates column
nan_in_column_Lat = rental_pd['startPlaceLat'].isna().any()
nan_in_column_Long = rental_pd['startPlaceLong'].isna().any()

print(nan_in_column_Lat,nan_in_column_Lat)

# Alternatively, you can use the following to count NaN values
nan_in_column_Lat = rental_pd['startPlaceLat'].isna().sum()
nan_in_column_Long = rental_pd['startPlaceLong'].isna().sum()
print(nan_in_column_Lat,nan_in_column_Lat)

# %%
clean_rental_pd = rental_pd.dropna(subset=['startPlaceLat', 'startPlaceLong', 'endPlaceLat','endPlaceLong'])
clean_rental_pd.info()

# %% [markdown]
# Now, using the GeoPandas Documentation site, we can see how to build a Geodataframe using the Lat and Long attributes. This dataset includes two sets of coordinates, one for when the user gets the bike and another one for when the user returns the bike.
#
# https://geopandas.org/en/stable/gallery/create_geopandas_from_pandas.html

# %%
gdf_bikes_start = gpd.GeoDataFrame(clean_rental_pd, geometry=gpd.points_from_xy(clean_rental_pd['startPlaceLong'], clean_rental_pd['startPlaceLat']))
gdf_bikes_end = gpd.GeoDataFrame(clean_rental_pd, geometry=gpd.points_from_xy(clean_rental_pd['endPlaceLong'], clean_rental_pd['endPlaceLat']))

# Print the GeoDataFrame
gdf_bikes_start.info()
# Do we need all those columns? And you see, there is also a lot of pre-processing to do with all the object Dtype

# %% [markdown]
# Let's plot one of the GeoPandasDataFrame

# %%
gdf_bikes_start.explore()

# %% [markdown]
# What is wrong with the previous map? why the points arent well located?

# %%
gdf_bikes_start.crs

# %% [markdown]
# You see what the problem is?, let me fix that...

# %%
gdf_bikes_start = gdf_bikes_start.set_crs("EPSG:4326")

# %%
gdf_bikes_start.explore()

# %% [markdown]
# You could have fixed that problem from the moment you created the GeoPandasDataFrame, just follow the example included in the documentation link: https://geopandas.org/en/stable/gallery/create_geopandas_from_pandas.html

# %%
gdf_bikes_start.dtypes

# %%
keep_cols = [
    "startDate",
    "startPlaceId",
    "startPlaceName",
    "durationSeconds",
    "isInvalid",
    "price",
    "isEbike",
    "startPlaceLat",
    "startPlaceLong",
    "geometry",
]
gdf_bikes_start = gdf_bikes_start[keep_cols]
gdf_bikes_start.head()

# %% [markdown]
# Updating the requiered and more appropiated Dtypes for the remainng columns

# %%
gdf_bikes_start.startPlaceId = gdf_bikes_start.startPlaceId.astype(int)
gdf_bikes_start.startPlaceName = gdf_bikes_start.startPlaceName.astype(str)
gdf_bikes_start['startDate'] = pd.to_datetime(gdf_bikes_start['startDate'], format='%Y-%m-%dT%H:%M:%SZ')

# %%
gdf_bikes_start.dtypes
#gdf_bikes_start['startPlaceName'].unique()

# %%
gdf_bikes_start.head()

# %% [markdown]
# Now, we want to see where the more dense areas are and where the bikes get collected so that we will use a simple but straightforward cluster analysis. We will explore this in more detail later in this course; for now, let's apply an ML library in Python sklearn (https://scikit-learn.org/stable/index.html) and define only 4 cluster areas. We will use the geometry attribute to get our Lat and Long values, which are required for the sklearn library fit_predict method.
#
# Before that, let's explore how we get the Lat and the Long values in the way the cluster method requires.

# %%
from sklearn.cluster import KMeans
num_clusters = 4

kmeans_collection = KMeans(n_clusters=num_clusters, random_state=42)
gdf_bikes_start['kmeans_cluster'] = kmeans_collection.fit_predict(gdf_bikes_start[['startPlaceLong', 'startPlaceLat']])

# %%
gdf_bikes_start.head()

# %%
import leafmap

m = leafmap.Map(center=(55.860166, -4.257505),
                zoom=12,
                draw_control=False,
                measure_control=False,
                fullscreen_control=False,
                attribution_control=True,
                   
               )

m.add_basemap("CartoDB.Positron")
m.add_data(
    gdf_bikes_start,
    column='kmeans_cluster',
    legend_title='Clusters',
    cmap='Set1',
    k=4,
)

#Ploting the map
m

# %% [markdown]
# Part No 1:
#
# Using the same workflow previously described, now calculate the clustered areas for the GeoPandasDataFrame gdf_bikes_end
# Make sure you don't have any NaN in your columns, add a CRS, clean up the unnecessary attributes, calculate the cluster values, and plot a map of 4 calculated clusters for the return locations.

# %%
gdf_bikes_end = gdf_bikes_end.set_crs("EPSG:4326")
gdf_bikes_end.explore()

# %%
gdf_bikes_end.endPlaceId = gdf_bikes_end.endPlaceId.astype(int)
gdf_bikes_end.endPlaceName = gdf_bikes_end.endPlaceName.astype(str)
gdf_bikes_end['endDate'] = pd.to_datetime(gdf_bikes_end['endDate'], format='%Y-%m-%dT%H:%M:%SZ')

# %%
keep_cols = [
    "endDate",
    "endPlaceId",
    "endPlaceName",
    "durationSeconds",
    "isInvalid",
    "price",
    "isEbike",
    "endPlaceLat",
    "endPlaceLong",
    "geometry",
]
gdf_bikes_end = gdf_bikes_end[keep_cols]
gdf_bikes_end.head()

# %%
kmeans_collection = KMeans(n_clusters=num_clusters, random_state=42)
gdf_bikes_end['kmeans_cluster'] = kmeans_collection.fit_predict(gdf_bikes_end[['endPlaceLong', 'endPlaceLat']])

# %%
e = leafmap.Map(center=(55.860166, -4.257505),
                zoom=12,
                draw_control=False,
                measure_control=False,
                fullscreen_control=False,
                attribution_control=True,
                   
               )

e.add_basemap("CartoDB.Positron")
e.add_data(
    gdf_bikes_end,
    column='kmeans_cluster',
    legend_title='Clusters',
    cmap='Set1',
    k=4,
)

#Ploting the map
e

# %% [markdown]
# # Challenge No 2:
#
# **Part No 1:**
#
# 1. Using the same workflow previously described, now calculate the clustered areas for the GeoPandasDataFrame `gdf_bikes_end`
# 2. Make sure you don't have any NaN in your columns, add a CRS, clean up the unnecessary attributes, calculate the cluster values, and plot a map of 4 calculated clusters for the return locations.
#
# **Part No 2:**
#
# 1. Using the Glasglow Open Data API ( Transit) https://developer.glasgow.gov.uk/api-details#api=traffic&operation=traffic-sensor-locations fetch all the sensor locations in the city.
# 2. Map the sensor
# 3. Find the WorkingZones and Calculate/Map the areas with more and fewer sensors distributed in the city.
# 4. You will need:
#    * Get two separate Geopandas DataFrames, one for the traffic sensors and another one for the WorkingZones.
#    * Using `sJoin` ( Spatial Join) https://geopandas.org/en/stable/docs/reference/api/geopandas.sjoin.html
#    calculate the overlay of sensors and polygons.
#    * Using group_by https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html to count the number of sensors per WorkingZone
#    * Make sure you add the counts into the WorkingZone polygons of Glasgow so you can create a map of Zones with more and fewer traffic sensors.
#    * Of course, you will need extra steps where you manipulate the data and extract what you need, for instance, clipping the Working Zones only for Glasgow.
# 5. Make sure you comment on your code and describe how you are manipulating the data.

# %%
url_sensors = "https://api.glasgow.gov.uk/traffic/v1/movement/sites"
# Making the query to the web server, using the Get method from the requests library 
response2 = requests.get(url_sensors)
response2
# Out:
# <Response [200]>

# %%
data = response2.json() #convert API data to list data
data
# Out:
# [{'siteId': 'GH020A_B',
#   'from': {'description': 'Gallowgate west to Sword St',
#    'lat': '55.8543754827825',
#    'long': '-4.217259197086495'},
#   'to': {'description': 'Gallowgate west to Sword St',
#    'lat': '55.854434529999814',
#    'long': '-4.216974959509279'}},
#  {'siteId': 'GJ3301_D',
#   'from': {'description': 'Carmunnock Rd southbound',
#    'lat': '55.821736212748405',
#    'long': '-4.2561270616272875'},
#   'to': {'description': 'Carmunnock Rd southbound',
#    'lat': '55.82105417976632',
#    'long': '-4.25607160697339'}},
#  {'siteId': 'GH020A_A',
#   'from': {'description': 'Gallowgate east to Sword St',
#    'lat': '55.85539015389372',
#    'long': '-4.225769520669405'},
#   'to': {'description': 'Gallowgate east to Sword St',
#    'lat': '55.85526881737797',
#    'long': '-4.2260182328994995'}},
#  {'siteId': 'GJ3301_C',
#   'from': {'description': 'Carmunnock Rd northbound to Kings Park Avenue',
#    'lat': '55.81925458152306',
#    'long': '-4.255696036412074'},
#   'to': {'description': 'Carmunnock Rd northbound to Kings Park Avenue',
#    'lat': '55.81849086854625',
#    'long': '-4.255683756017223'}},
#  {'siteId': 'GJ3301_B',
#   'from': {'description': 'Kings Park Ave westbound to Carmunnock Rd',
#    'lat': '55.820288451422314',
#    'long': '-4.250775113480551'},
#   'to': {'description': 'Kings Park Ave westbound to Carmunnock Rd',
#    'lat': '55.82016283016515',
#    'long': '-4.2502729750640285'}},
#  {'siteId': 'GJ3301_A',
#   'from': {'description': 'Kings Park Rd southbound',
#    'lat': '55.82321777097949',
#    'long': '-4.258160608689249'},
#   'to': {'description': 'Kings Park Rd southbound',
#    'lat': '55.82410688116023',
#    'long': '-4.258196175251756'}},
#  {'siteId': 'GC2381_T',
#   'from': {'description': 'Bulldale Road',
#    'lat': '55.88630723491306',
#    'long': '-4.376194906434908'},
#   'to': {'description': 'Bulldale Road',
#    'lat': '55.886899038949245',
#    'long': '-4.3753355419780835'}},
#  {'siteId': 'GC2381_S',
#   'from': {'description': 'Dumbarton Road Outbound to Bulldale Rd.',
#    'lat': '55.88563301564599',
#    'long': '-4.372475677796264'},
#   'to': {'description': 'Dumbarton Road Outbound to Bulldale Rd.',
#    'lat': '55.88540387234871',
#    'long': '-4.371774067792365'}},
#  {'siteId': 'GC2381_R',
#   'from': {'description': 'Dumbarton Road inbound to Bulldale St',
#    'lat': '55.88791083146969',
#    'long': '-4.3778601932779795'},
#   'to': {'description': 'Dumbarton Road inbound to Bulldale St',
#    'lat': '55.88820586620821',
#    'long': '-4.378405994326701'}},
#  {'siteId': 'GD2701_D',
#   'from': {'description': 'Shiskine Drive',
#    'lat': '55.89713453859071',
#    'long': '-4.29825305864195'},
#   'to': {'description': 'Shiskine Drive',
#    'lat': '55.89670336618549',
#    'long': '-4.299203285213263'}},
#  {'siteId': 'GF0301_S',
#   'from': {'description': 'Royston Rd w/b',
#    'lat': '55.87871919955157',
#    'long': '-4.191340047273297'},
#   'to': {'description': 'Royston Rd w/b',
#    'lat': '55.87839021402277',
#    'long': '-4.194167303027818'}},
#  {'siteId': 'GD2701_B',
#   'from': {'description': 'Maryhill Road outbound towards Shiskine Drive',
#    'lat': '55.89515227975689',
#    'long': '-4.298039841472587'},
#   'to': {'description': 'Maryhill Road outbound towards Shiskine Drive',
#    'lat': '55.89394772975637',
#    'long': '-4.2970889096571705'}},
#  {'siteId': 'GD2701_A',
#   'from': {'description': 'Maryhill Road inbound to Shiskine Drive',
#    'lat': '55.89918876489169',
#    'long': '-4.302309747084052'},
#   'to': {'description': 'Maryhill Road inbound to Shiskine Drive',
#    'lat': '55.89916542948992',
#    'long': '-4.302596303354128'}},
#  {'siteId': 'GL265A_L',
#   'from': {'description': 'Pacific Dr eastbound',
#    'lat': '55.856827323061815',
#    'long': '-4.289959555824773'},
#   'to': {'description': 'Pacific Dr eastbound',
#    'lat': '55.85685847943426',
#    'long': '-4.290217055996317'}},
#  {'siteId': 'GF0301_D',
#   'from': {'description': 'Royston Rd e/b to Robroyston Rd',
#    'lat': '55.87810851407745',
#    'long': '-4.190810017915082'},
#   'to': {'description': 'Royston Rd e/b to Robroyston Rd',
#    'lat': '55.878817107346244',
#    'long': '-4.191393528638299'}},
#  {'siteId': 'GF0301_C',
#   'from': {'description': 'Royston Rd w/b to Robroyston Rd',
#    'lat': '55.879206944843226',
#    'long': '-4.189688801744091'},
#   'to': {'description': 'Royston Rd w/b to Robroyston Rd',
#    'lat': '55.878817107346244',
#    'long': '-4.191393528638299'}},
#  {'siteId': 'GJ275A_V',
#   'from': {'description': 'Cathcart Rd northbound to Preston St',
#    'lat': '55.83693354635203',
#    'long': '-4.257135210420471'},
#   'to': {'description': 'Cathcart Rd northbound to Preston St',
#    'lat': '55.83687762899016',
#    'long': '-4.25724376518555'}},
#  {'siteId': 'GF0301_B',
#   'from': {'description': 'Langdale St n/b',
#    'lat': '55.87947536584209',
#    'long': '-4.191270748509423'},
#   'to': {'description': 'Langdale St n/b',
#    'lat': '55.878817107346244',
#    'long': '-4.191393528638299'}},
#  {'siteId': 'GC4151_G',
#   'from': {'description': 'On-ramp Westbound to Clydeside Expressway',
#    'lat': '55.86069950889394',
#    'long': '-4.283267802105605'},
#   'to': {'description': 'On-ramp Westbound to Clydeside Expressway',
#    'lat': '55.86038667864348',
#    'long': '-4.2826901232101795'}},
#  {'siteId': 'GC4151_E',
#   'from': {'description': 'Congress Way Northbound Outside to Pointhouse Rd',
#    'lat': '55.85985056415024',
#    'long': '-4.283489648996855'},
#   'to': {'description': 'Congress Way Northbound Outside to Pointhouse Rd',
#    'lat': '55.85935619571898',
#    'long': '-4.283492595662314'}},
#  {'siteId': 'GC4151_C',
#   'from': {'description': 'Congress Way Northbound Inside to Pointhouse Road',
#    'lat': '55.85986733438599',
#    'long': '-4.283554554728458'},
#   'to': {'description': 'Congress Way Northbound Inside to Pointhouse Road',
#    'lat': '55.85935619571898',
#    'long': '-4.283492595662314'}},
#  {'siteId': 'GC4151_A',
#   'from': {'description': 'Stobcross Road Eastbound to Pointhouse Road',
#    'lat': '55.860894822588506',
#    'long': '-4.284365958508686'},
#   'to': {'description': 'Stobcross Road Eastbound to Pointhouse Road',
#    'lat': '55.86038667864348',
#    'long': '-4.2826901232101795'}},
#  {'siteId': 'GH195A_B',
#   'from': {'description': 'London Road westbound to Kent St',
#    'lat': '55.853557522976224',
#    'long': '-4.237120627922957'},
#   'to': {'description': 'London Road westbound to Kent St',
#    'lat': '55.85345791330956',
#    'long': '-4.236667530649426'}},
#  {'siteId': 'GH195A_A',
#   'from': {'description': 'London Road e/b to Kent St.',
#    'lat': '55.854617352151365',
#    'long': '-4.240121510355179'},
#   'to': {'description': 'London Road e/b to Kent St.',
#    'lat': '55.854652939873155',
#    'long': '-4.240634856680875'}},
#  {'siteId': 'GL2651_R',
#   'from': {'description': 'Govan Rd Westbound',
#    'lat': '55.85521346050558',
#    'long': '-4.295536954188497'},
#   'to': {'description': 'Govan Rd Westbound',
#    'lat': '55.85534127437887',
#    'long': '-4.295912000825322'}},
#  {'siteId': 'GB0501_D',
#   'from': {'description': 'Glasgow Bridge SB to Clyde Place',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Glasgow Bridge SB to Clyde Place',
#    'lat': '0',
#    'long': '0'}},
#  {'siteId': 'GB0501_A',
#   'from': {'description': 'Clyde Place to Bridge Street eastbound',
#    'lat': '55.8549006837386',
#    'long': '-4.259519372285604'},
#   'to': {'description': 'Clyde Place to Bridge Street eastbound',
#    'lat': '55.85476337655625',
#    'long': '-4.25965520363947'}},
#  {'siteId': 'GA2801_G',
#   'from': {'description': 'Renfrew Street eastbound to Renfield Street offside',
#    'lat': '55.86536126095586',
#    'long': '-4.256626759612004'},
#   'to': {'description': 'Renfrew Street eastbound to Renfield Street offside',
#    'lat': '55.86530300068848',
#    'long': '-4.256863117405453'}},
#  {'siteId': 'GG1101_T',
#   'from': {'description': 'Stepps Road nb from Bellrock St',
#    'lat': '55.86881911962045',
#    'long': '-4.156529385070701'},
#   'to': {'description': 'Stepps Road nb from Bellrock St',
#    'lat': '55.86853966661047',
#    'long': '-4.156577825463893'}},
#  {'siteId': 'GG1101_S',
#   'from': {'description': 'M8 Off-Ramp WB',
#    'lat': '55.869034246707436',
#    'long': '-4.155022867360321'},
#   'to': {'description': 'M8 Off-Ramp WB',
#    'lat': '55.86853966661047',
#    'long': '-4.156577825463893'}},
#  {'siteId': 'GG1101_R',
#   'from': {'description': 'Stepps Road s/b',
#    'lat': '55.86655956269573',
#    'long': '-4.155205423438159'},
#   'to': {'description': 'Stepps Road s/b',
#    'lat': '55.866837896546805',
#    'long': '-4.1552208441953615'}},
#  {'siteId': 'GA2801_B',
#   'from': {'description': 'Renfrew Street westbound',
#    'lat': '55.86507327370817',
#    'long': '-4.254196711337344'},
#   'to': {'description': 'Renfrew Street westbound',
#    'lat': '55.865281629386',
#    'long': '-4.25508782149662'}},
#  {'siteId': 'GA2801_A',
#   'from': {'description': 'Renfrew Street eastbound to Renfield Street nearside',
#    'lat': '55.86540615045904',
#    'long': '-4.256629363666894'},
#   'to': {'description': 'Renfrew Street eastbound to Renfield Street nearside',
#    'lat': '55.86530300068848',
#    'long': '-4.256863117405453'}},
#  {'siteId': 'GK4951_C',
#   'from': {'description': 'Nitshill Road Westbound to Kyleakin Rd',
#    'lat': '55.8016647512256',
#    'long': '-4.328541221239083'},
#   'to': {'description': 'Nitshill Road Westbound to Kyleakin Rd',
#    'lat': '55.80152058659404',
#    'long': '-4.328085826495753'}},
#  {'siteId': 'GK4951_B',
#   'from': {'description': 'Loganswell Road Northbound',
#    'lat': '55.80126196952965',
#    'long': '-4.328453342423473'},
#   'to': {'description': 'Loganswell Road Northbound',
#    'lat': '55.80152058659404',
#    'long': '-4.328085826495753'}},
#  {'siteId': 'GK4951_A',
#   'from': {'description': 'Nitshill Rd Westbound to Loganswell Rd',
#    'lat': '55.801386681125614',
#    'long': '-4.3270885241399295'},
#   'to': {'description': 'Nitshill Rd Westbound to Loganswell Rd',
#    'lat': '55.80152058659404',
#    'long': '-4.328085826495753'}},
#  {'siteId': 'GH3301_F',
#   'from': {'description': 'Dalmarnock Road eastbound LT to Springfield Rd',
#    'lat': '55.84129415766746',
#    'long': '-4.21552392052753'},
#   'to': {'description': 'Dalmarnock Road eastbound LT to Springfield Rd',
#    'lat': '55.84116817560765',
#    'long': '-4.215532724464075'}},
#  {'siteId': 'GH3301_D',
#   'from': {'description': 'Springfield Road southbound',
#    'lat': '55.841390120120394',
#    'long': '-4.214187690112489'},
#   'to': {'description': 'Springfield Road southbound',
#    'lat': '55.84116817560765',
#    'long': '-4.215532724464075'}},
#  {'siteId': 'GH3301_B',
#   'from': {'description': 'Dalmarnock Road westbound to Springfield Rd',
#    'lat': '55.840571955234964',
#    'long': '-4.214205053485609'},
#   'to': {'description': 'Dalmarnock Road westbound to Springfield Rd',
#    'lat': '55.840448271219856',
#    'long': '-4.214086215304658'}},
#  {'siteId': 'GH3301_A',
#   'from': {'description': 'Dalmarnock Road s/b to Springfield Rd',
#    'lat': '55.84249771563329',
#    'long': '-4.2170619200955155'},
#   'to': {'description': 'Dalmarnock Road s/b to Springfield Rd',
#    'lat': '55.84296866880256',
#    'long': '-4.217360281901309'}},
#  {'siteId': 'GC1301_V',
#   'from': {'description': 'Radnor Street to Sauchiehall Street',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Radnor Street to Sauchiehall Street',
#    'lat': '0',
#    'long': '0'}},
#  {'siteId': 'GC1301_T',
#   'from': {'description': 'Sauchiehall St to Radnor St.',
#    'lat': '55.86744731675164',
#    'long': '-4.288203198759974'},
#   'to': {'description': 'Sauchiehall St to Radnor St.',
#    'lat': '55.866792607151226',
#    'long': '-4.2886122154594855'}},
#  {'siteId': 'GC1301_S',
#   'from': {'description': 'Kelvin Way',
#    'lat': '55.86659977957889',
#    'long': '-4.287865644847315'},
#   'to': {'description': 'Kelvin Way',
#    'lat': '55.866792607151226',
#    'long': '-4.2886122154594855'}},
#  {'siteId': 'GC1301_R',
#   'from': {'description': 'Argyle Street to Sauchiehall Street',
#    'lat': '55.867603590185865',
#    'long': '-4.290913616788351'},
#   'to': {'description': 'Argyle Street to Sauchiehall Street',
#    'lat': '55.867770895760586',
#    'long': '-4.291099290903467'}},
#  {'siteId': 'GH1001_L',
#   'from': {'description': 'Gallowgate westbound Left Turn into EERR',
#    'lat': '55.85297616211061',
#    'long': '-4.208615665888693'},
#   'to': {'description': 'Gallowgate westbound Left Turn into EERR',
#    'lat': '55.8537827682205',
#    'long': '-4.208741328572016'}},
#  {'siteId': 'GH1001_J',
#   'from': {'description': 'Gallowgate westbound to roundabout',
#    'lat': '55.85342955763155',
#    'long': '-4.209392334896589'},
#   'to': {'description': 'Gallowgate westbound to roundabout',
#    'lat': '55.8537827682205',
#    'long': '-4.208741328572016'}},
#  {'siteId': 'GG012A_S',
#   'from': {'description': 'Alexandra Parade',
#    'lat': '55.86364519155325',
#    'long': '-4.217052326028468'},
#   'to': {'description': 'Alexandra Parade',
#    'lat': '55.86340122093017',
#    'long': '-4.216127474018917'}},
#  {'siteId': 'GG012A_R',
#   'from': {'description': 'Alexandra Parade to Armadale',
#    'lat': '55.863287109702064',
#    'long': '-4.213979452532824'},
#   'to': {'description': 'Alexandra Parade to Armadale',
#    'lat': '55.863337171675575',
#    'long': '-4.213694634168933'}},
#  {'siteId': 'GH1001_F',
#   'from': {'description': 'EERR southbound internal to Gallowgate',
#    'lat': '55.85395879914559',
#    'long': '-4.20844774374272'},
#   'to': {'description': 'EERR southbound internal to Gallowgate',
#    'lat': '55.8537827682205',
#    'long': '-4.208741328572016'}},
#  {'siteId': 'GH1001_E',
#   'from': {'description': 'Biggar St northbound from roundabout',
#    'lat': '55.85407254814759',
#    'long': '-4.209620570161432'},
#   'to': {'description': 'Biggar St northbound from roundabout',
#    'lat': '55.8537827682205',
#    'long': '-4.208741328572016'}},
#  {'siteId': 'GH1001_D',
#   'from': {'description': 'EERR northbound to Gallowgate',
#    'lat': '55.84870080262547',
#    'long': '-4.209970627469236'},
#   'to': {'description': 'EERR northbound to Gallowgate',
#    'lat': '55.84828321696496',
#    'long': '-4.21020252482527'}},
#  {'siteId': 'GH1001_C',
#   'from': {'description': 'Biggar St southbound',
#    'lat': '55.853719920746975',
#    'long': '-4.208737761770545'},
#   'to': {'description': 'Biggar St southbound',
#    'lat': '55.8537827682205',
#    'long': '-4.208741328572016'}},
#  {'siteId': 'GH1001_B',
#   'from': {'description': 'Gallowgate west to Holywell St',
#    'lat': '55.85295590290567',
#    'long': '-4.20323019248114'},
#   'to': {'description': 'Gallowgate west to Holywell St',
#    'lat': '55.85129181252292',
#    'long': '-4.197783860320688'}},
#  {'siteId': 'GH1001_A',
#   'from': {'description': 'Gallowgate eastbound from roundabout',
#    'lat': '55.85372297155631',
#    'long': '-4.209568767493034'},
#   'to': {'description': 'Gallowgate eastbound from roundabout',
#    'lat': '55.8537827682205',
#    'long': '-4.208741328572016'}},
#  {'siteId': 'GK0351_V',
#   'from': {'description': 'Pollokshaws Road inbound to Allison Street',
#    'lat': '55.836412076242205',
#    'long': '-4.270328695468586'},
#   'to': {'description': 'Pollokshaws Road inbound to Allison Street',
#    'lat': '55.836313908834434',
#    'long': '-4.270291031106442'}},
#  {'siteId': 'GD120A_A',
#   'from': {'description': 'Clarence Drive e/b towards Hyndland Road',
#    'lat': '55.87724251706178',
#    'long': '-4.308476302116165'},
#   'to': {'description': 'Clarence Drive e/b towards Hyndland Road',
#    'lat': '55.877285607163955',
#    'long': '-4.3085747862544945'}},
#  {'siteId': 'GK0351_T',
#   'from': {'description': 'Pollokshaws Road outbound to Allison Street',
#    'lat': '55.83798644490389',
#    'long': '-4.268296297205533'},
#   'to': {'description': 'Pollokshaws Road outbound to Allison Street',
#    'lat': '55.83834658561153',
#    'long': '-4.267774245631587'}},
#  {'siteId': 'GK0351_R',
#   'from': {'description': 'Nithsdale Street',
#    'lat': '55.837181815696056',
#    'long': '-4.270501339796873'},
#   'to': {'description': 'Nithsdale Street',
#    'lat': '55.83699328827396',
#    'long': '-4.269516121116813'}},
#  {'siteId': 'GA5051_V',
#   'from': {'description': 'Saltmarket northbound to Greendyke St',
#    'lat': '55.853428168395425',
#    'long': '-4.246683750619731'},
#   'to': {'description': 'Saltmarket northbound to Greendyke St',
#    'lat': '55.85306846618108',
#    'long': '-4.2466949406691255'}},
#  {'siteId': 'GA5051_U',
#   'from': {'description': 'Greendyke Street',
#    'lat': '55.853953189003654',
#    'long': '-4.244509124668593'},
#   'to': {'description': 'Greendyke Street',
#    'lat': '55.85434316247106',
#    'long': '-4.245793874097538'}},
#  {'siteId': 'GB1301_X',
#   'from': {'description': 'Cumberland Street eastbound inside lane',
#    'lat': '55.848179176367914',
#    'long': '-4.254560209726458'},
#   'to': {'description': 'Cumberland Street eastbound inside lane',
#    'lat': '55.84801444539721',
#    'long': '-4.2542311608821075'}},
#  {'siteId': 'GB1301_V',
#   'from': {'description': 'Hospital Street northbound',
#    'lat': '55.84730197077243',
#    'long': '-4.254365627919512'},
#   'to': {'description': 'Hospital Street northbound',
#    'lat': '55.84801444539721',
#    'long': '-4.2542311608821075'}},
#  {'siteId': 'GB1301_T',
#   'from': {'description': 'Hospital Street southbound to Cumberland Street',
#    'lat': '55.849495854109286',
#    'long': '-4.252351907449826'},
#   'to': {'description': 'Hospital Street southbound to Cumberland Street',
#    'lat': '55.84989585166228',
#    'long': '-4.252103459291707'}},
#  {'siteId': 'GH002A_S',
#   'from': {'description': 'Gallowgate East to Kent St',
#    'lat': '55.85560650193221',
#    'long': '-4.238117230640115'},
#   'to': {'description': 'Gallowgate East to Kent St',
#    'lat': '55.85555788324583',
#    'long': '-4.237331491980359'}},
#  {'siteId': 'GA5051_P',
#   'from': {'description': 'Bridgegate',
#    'lat': '55.85487391441056',
#    'long': '-4.246751236943732'},
#   'to': {'description': 'Bridgegate',
#    'lat': '55.85434316247106',
#    'long': '-4.245793874097538'}},
#  {'siteId': 'GH002A_R',
#   'from': {'description': 'Gallowgate West to Kent St',
#    'lat': '55.85532160836109',
#    'long': '-4.235991707786897'},
#   'to': {'description': 'Gallowgate West to Kent St',
#    'lat': '55.85555788324583',
#    'long': '-4.237331491980359'}},
#  {'siteId': 'GB1301_R',
#   'from': {'description': 'Cumberland Street eastbound outside lane',
#    'lat': '55.84814297209656',
#    'long': '-4.254574088234247'},
#   'to': {'description': 'Cumberland Street eastbound outside lane',
#    'lat': '55.84801444539721',
#    'long': '-4.2542311608821075'}},
#  {'siteId': 'GA5051_H',
#   'from': {'description': 'Saltmarket south to Greendyke St',
#    'lat': '55.855894182399155',
#    'long': '-4.24452520424949'},
#   'to': {'description': 'Saltmarket south to Greendyke St',
#    'lat': '55.85593615982788',
#    'long': '-4.244687411447339'}},
#  {'siteId': 'GJ3551_W',
#   'from': {'description': 'Clarkston Road NB R/T towards Old Castle Road',
#    'lat': '55.81738258550053',
#    'long': '-4.262196297709536'},
#   'to': {'description': 'Clarkston Road NB R/T towards Old Castle Road',
#    'lat': '55.81845089826761',
#    'long': '-4.261284553016745'}},
#  {'siteId': 'GJ3551_V',
#   'from': {'description': 'Clarkston Road NB Ahead towards Old Castle Road',
#    'lat': '55.81739068322613',
#    'long': '-4.262244656347269'},
#   'to': {'description': 'Clarkston Road NB Ahead towards Old Castle Road',
#    'lat': '55.81845089826761',
#    'long': '-4.261284553016745'}},
#  {'siteId': 'GJ3551_T',
#   'from': {'description': 'Holmlea Road southbound towards Old Castle Road',
#    'lat': '55.819078294291884',
#    'long': '-4.260889944193136'},
#   'to': {'description': 'Holmlea Road southbound towards Old Castle Road',
#    'lat': '55.81845089826761',
#    'long': '-4.261284553016745'}},
#  {'siteId': 'GC0321_H',
#   'from': {'description': 'Castlebank St to Hayburn St offside',
#    'lat': '55.86811529639363',
#    'long': '-4.309213276354216'},
#   'to': {'description': 'Castlebank St to Hayburn St offside',
#    'lat': '55.868337050735796',
#    'long': '-4.308890778710218'}},
#  {'siteId': 'GC0321_F',
#   'from': {'description': 'Castlebank St eastbound nearside',
#    'lat': '55.86806342207265',
#    'long': '-4.311975403552451'},
#   'to': {'description': 'Castlebank St eastbound nearside',
#    'lat': '55.86841240916866',
#    'long': '-4.31062152360615'}},
#  {'siteId': 'GC0321_D',
#   'from': {'description': 'Link Road to Hayburn St',
#    'lat': '55.86846332374293',
#    'long': '-4.309345826900188'},
#   'to': {'description': 'Link Road to Hayburn St',
#    'lat': '55.868337050735796',
#    'long': '-4.308890778710218'}},
#  {'siteId': 'GC0321_B',
#   'from': {'description': 'Castlebank St to Hayburn St nearside',
#    'lat': '55.86807070822497',
#    'long': '-4.309194645327121'},
#   'to': {'description': 'Castlebank St to Hayburn St nearside',
#    'lat': '55.868337050735796',
#    'long': '-4.308890778710218'}},
#  {'siteId': 'GC0321_A',
#   'from': {'description': 'Castlebank St eastbound offside',
#    'lat': '55.86803618938978',
#    'long': '-4.31198976867953'},
#   'to': {'description': 'Castlebank St eastbound offside',
#    'lat': '55.86841240916866',
#    'long': '-4.31062152360615'}},
#  {'siteId': 'GA1301_P',
#   'from': {'description': 'Broomielaw westbound from KGV Bridge',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Broomielaw westbound from KGV Bridge',
#    'lat': '0',
#    'long': '0'}},
#  {'siteId': 'GA1301_G',
#   'from': {'description': 'York St R/T from Broomielaw',
#    'lat': '55.85706130313036',
#    'long': '-4.262744781578143'},
#   'to': {'description': 'York St R/T from Broomielaw',
#    'lat': '55.856875703704084',
#    'long': '-4.262574198531883'}},
#  {'siteId': 'GL1151_D',
#   'from': {'description': 'Broomloan Road southbound',
#    'lat': '55.850616992734636',
#    'long': '-4.311578020227955'},
#   'to': {'description': 'Broomloan Road southbound',
#    'lat': '55.849972125056624',
#    'long': '-4.310980546666565'}},
#  {'siteId': 'GD200A_S',
#   'from': {'description': 'Maryhill Road outbound to Great Western Road',
#    'lat': '55.87014169388683',
#    'long': '-4.268892500320476'},
#   'to': {'description': 'Maryhill Road outbound to Great Western Road',
#    'lat': '55.870462248447126',
#    'long': '-4.268079997790708'}},
#  {'siteId': 'GL1151_C',
#   'from': {'description': 'Dumbreck Road northbound to PRW / Dumbreck Rd',
#    'lat': '55.84921742483298',
#    'long': '-4.310488406707863'},
#   'to': {'description': 'Dumbreck Road northbound to PRW / Dumbreck Rd',
#    'lat': '55.84852706403615',
#    'long': '-4.309920225454224'}},
#  {'siteId': 'GD200A_R',
#   'from': {'description': 'Maryhill Road inbound towards G W R',
#    'lat': '55.872706993173516',
#    'long': '-4.269170047463331'},
#   'to': {'description': 'Maryhill Road inbound towards G W R',
#    'lat': '55.872895232727615',
#    'long': '-4.269197016816533'}},
#  {'siteId': 'GL1151_B',
#   'from': {'description': 'Paisley Road West westbound',
#    'lat': '55.85004788539256',
#    'long': '-4.309339470394715'},
#   'to': {'description': 'Paisley Road West westbound',
#    'lat': '55.849972125056624',
#    'long': '-4.310980546666565'}},
#  {'siteId': 'GL1151_A',
#   'from': {'description': 'Paisley Road West eastbound',
#    'lat': '55.849657571018625',
#    'long': '-4.311936424489083'},
#   'to': {'description': 'Paisley Road West eastbound',
#    'lat': '55.849972125056624',
#    'long': '-4.310980546666565'}},
#  {'siteId': 'GH312A_T',
#   'from': {'description': 's/b from Shawfield Dr from J2 / Poplin',
#    'lat': '55.84075769993983',
#    'long': '-4.227808021667737'},
#   'to': {'description': 's/b from Shawfield Dr from J2 / Poplin',
#    'lat': '55.83806956683952',
#    'long': '-4.231327608671311'}},
#  {'siteId': 'GA1301_B',
#   'from': {'description': 'Broomielaw westbound from York Street',
#    'lat': '55.85692922356656',
#    'long': '-4.265038089789566'},
#   'to': {'description': 'Broomielaw westbound from York Street',
#    'lat': '55.85686164638997',
#    'long': '-4.264315098440796'}},
#  {'siteId': 'GA1301_A',
#   'from': {'description': 'Broomielaw to York Street.',
#    'lat': '55.856959063447256',
#    'long': '-4.26390531049521'},
#   'to': {'description': 'Broomielaw to York Street.',
#    'lat': '55.85686164638997',
#    'long': '-4.264315098440796'}},
#  {'siteId': 'GD0651_W',
#   'from': {'description': 'Great Western Rd westbound R/T',
#    'lat': '55.888834293713586',
#    'long': '-4.321015152448036'},
#   'to': {'description': 'Great Western Rd westbound R/T',
#    'lat': '55.88870234315834',
#    'long': '-4.320863340913476'}},
#  {'siteId': 'GD0651_S',
#   'from': {'description': 'Great Western Road to Ascot Ave',
#    'lat': '55.88753559795142',
#    'long': '-4.317915128219077'},
#   'to': {'description': 'Great Western Road to Ascot Ave',
#    'lat': '55.887688516051426',
#    'long': '-4.317908255897963'}},
#  {'siteId': 'GD0651_R',
#   'from': {'description': 'Great Western Rd to Ascot Ave.',
#    'lat': '55.88922103772199',
#    'long': '-4.322429605710496'},
#   'to': {'description': 'Great Western Rd to Ascot Ave.',
#    'lat': '55.88923959554618',
#    'long': '-4.322398729442261'}},
#  {'siteId': 'GH312A_D',
#   'from': {'description': 'Shawfield Drive southbound to Clyde Walkway',
#    'lat': '55.84219933396287',
#    'long': '-4.226117518705436'},
#   'to': {'description': 'Shawfield Drive southbound to Clyde Walkway',
#    'lat': '55.84248518977821',
#    'long': '-4.226213727774215'}},
#  {'siteId': 'GB0751_V',
#   'from': {'description': 'Eglinton Street northbound to Cumberland St',
#    'lat': '55.84708106668321',
#    'long': '-4.2610144172166216'},
#   'to': {'description': 'Eglinton Street northbound to Cumberland St',
#    'lat': '55.84699480770674',
#    'long': '-4.260817707095752'}},
#  {'siteId': 'GB0751_T',
#   'from': {'description': 'Eglinton Street southbound to Cumberland Street',
#    'lat': '55.85049447586942',
#    'long': '-4.259647009961128'},
#   'to': {'description': 'Eglinton Street southbound to Cumberland Street',
#    'lat': '55.85063225821452',
#    'long': '-4.259974538694813'}},
#  {'siteId': 'GB0751_S',
#   'from': {'description': 'Cathcart Road to Cumberland Street',
#    'lat': '55.848209730275',
#    'long': '-4.255344777421482'},
#   'to': {'description': 'Cathcart Road to Cumberland Street',
#    'lat': '55.848092816760634',
#    'long': '-4.254858740826407'}},
#  {'siteId': 'GA4401_Y',
#   'from': {'description': 'Bus Station exit eastbound',
#    'lat': '55.86477919409067',
#    'long': '-4.249640707541476'},
#   'to': {'description': 'Bus Station exit eastbound',
#    'lat': '55.86471962992503',
#    'long': '-4.2489660093951676'}},
#  {'siteId': 'GA4401_Q',
#   'from': {'description': 'Killermont St westbound R/T from N. Hanover St',
#    'lat': '55.86455160575039',
#    'long': '-4.249307903173464'},
#   'to': {'description': 'Killermont St westbound R/T from N. Hanover St',
#    'lat': '55.86471962992503',
#    'long': '-4.2489660093951676'}},
#  {'siteId': 'GA4401_N',
#   'from': {'description': 'North Hanover St southbound to Killermont St',
#    'lat': '55.86535684098523',
#    'long': '-4.2485233737672115'},
#   'to': {'description': 'North Hanover St southbound to Killermont St',
#    'lat': '55.865470928123024',
#    'long': '-4.248673811036969'}},
#  {'siteId': 'GJ290A_N',
#   'from': {'description': 'Cathcart Rd northbound',
#    'lat': '55.83271790874834',
#    'long': '-4.2556932157246905'},
#   'to': {'description': 'Cathcart Rd northbound',
#    'lat': '55.83318476235378',
#    'long': '-4.255720253928153'}},
#  {'siteId': 'GA4401_M',
#   'from': {'description': 'North Hanover St northbound to Killermont St',
#    'lat': '55.8633899477641',
#    'long': '-4.249432518576116'},
#   'to': {'description': 'North Hanover St northbound to Killermont St',
#    'lat': '55.86325987773686',
#    'long': '-4.249664722294599'}},
#  {'siteId': 'GJ290A_M',
#   'from': {'description': 'Cathcart Rd southbound to Albert Rd',
#    'lat': '55.834909019823165',
#    'long': '-4.256283253088819'},
#   'to': {'description': 'Cathcart Rd southbound to Albert Rd',
#    'lat': '55.83514156835417',
#    'long': '-4.256344636200412'}},
#  {'siteId': 'GA4401_K',
#   'from': {'description': 'Killermont Street St eastbound to North Hanover St',
#    'lat': '55.86490099279722',
#    'long': '-4.252316796864651'},
#   'to': {'description': 'Killermont Street St eastbound to North Hanover St',
#    'lat': '55.865156707614595',
#    'long': '-4.2540577042514345'}},
#  {'siteId': 'GL2801_S',
#   'from': {'description': 'Govan Road westbound',
#    'lat': '55.85624527823334',
#    'long': '-4.285978514211548'},
#   'to': {'description': 'Govan Road westbound',
#    'lat': '55.855990477928046',
#    'long': '-4.28518058528346'}},
#  {'siteId': 'GL2801_R',
#   'from': {'description': 'Govan Road eastbound (f/l)',
#    'lat': '55.85624846009274',
#    'long': '-4.285323566368859'},
#   'to': {'description': 'Govan Road eastbound (f/l)',
#    'lat': '55.855990477928046',
#    'long': '-4.28518058528346'}},
#  {'siteId': 'GC155A_A',
#   'from': {'description': 'Dumbarton Road inbound to Western Inf.',
#    'lat': '55.870056548361696',
#    'long': '-4.2967326358773645'},
#   'to': {'description': 'Dumbarton Road inbound to Western Inf.',
#    'lat': '55.869880197121404',
#    'long': '-4.2955873194386385'}},
#  {'siteId': 'GL2801_B',
#   'from': {'description': 'Govan Road eastbound (F/L)',
#    'lat': '55.85651261150937',
#    'long': '-4.286585442207979'},
#   'to': {'description': 'Govan Road eastbound (F/L)',
#    'lat': '55.85644820814138',
#    'long': '-4.288115640401873'}},
#  {'siteId': 'GG267A_B',
#   'from': {'description': 'Shettleston Road to Blair Street',
#    'lat': '55.85223752966005',
#    'long': '-4.177962054873924'},
#   'to': {'description': 'Shettleston Road to Blair Street',
#    'lat': '55.852166048604',
#    'long': '-4.177430820965412'}},
#  {'siteId': 'GG267A_A',
#   'from': {'description': 'Shettleston Road to Blair Street',
#    'lat': '55.85274381385316',
#    'long': '-4.182863381641116'},
#   'to': {'description': 'Shettleston Road to Blair Street',
#    'lat': '55.852697985952794',
#    'long': '-4.18342000725699'}},
#  {'siteId': 'GA2101_C',
#   'from': {'description': 'West Regent Street eastbound',
#    'lat': '55.86264962734015',
#    'long': '-4.257955741740505'},
#   'to': {'description': 'West Regent Street eastbound',
#    'lat': '55.862642993422256',
#    'long': '-4.25782750543661'}},
#  {'siteId': 'GA2101_A',
#   'from': {'description': 'West Regent Street eastbound',
#    'lat': '55.86340326237511',
#    'long': '-4.259006331320647'},
#   'to': {'description': 'West Regent Street eastbound',
#    'lat': '55.86335752086073',
#    'long': '-4.257581303461147'}},
#  {'siteId': 'GK5141_R',
#   'from': {'description': 'Woodneuk Rd Southbound',
#    'lat': '55.81021478562821',
#    'long': '-4.352002772504004'},
#   'to': {'description': 'Woodneuk Rd Southbound',
#    'lat': '55.80986784958291',
#    'long': '-4.352285081796666'}},
#  {'siteId': 'GB1551_W',
#   'from': {'description': 'Westbound Right Turn into Camden Terrace',
#    'lat': '55.8464467938294',
#    'long': '-4.250514116570925'},
#   'to': {'description': 'Westbound Right Turn into Camden Terrace',
#    'lat': '55.84560870404568',
#    'long': '-4.250146178756491'}},
#  {'siteId': 'GL1821_X',
#   'from': {'description': 'Paisley Road West eastbound R/T',
#    'lat': '55.84534250908411',
#    'long': '-4.347575080845519'},
#   'to': {'description': 'Paisley Road West eastbound R/T',
#    'lat': '55.84569171226189',
#    'long': '-4.347644064242421'}},
#  {'siteId': 'GK5141_D',
#   'from': {'description': 'Nitshill Rd Eastbound to Glen Moriston',
#    'lat': '55.80760292836235',
#    'long': '-4.347584079369231'},
#   'to': {'description': 'Nitshill Rd Eastbound to Glen Moriston',
#    'lat': '55.80819435245893',
#    'long': '-4.349087964527667'}},
#  {'siteId': 'GL1821_V',
#   'from': {'description': 'Mosspark Drive',
#    'lat': '55.84540124604075',
#    'long': '-4.347323027783867'},
#   'to': {'description': 'Mosspark Drive',
#    'lat': '55.84569171226189',
#    'long': '-4.347644064242421'}},
#  {'siteId': 'GB1551_T',
#   'from': {'description': 'Camden Terrace',
#    'lat': '55.845897093956474',
#    'long': '-4.250594159531877'},
#   'to': {'description': 'Camden Terrace',
#    'lat': '55.84560870404568',
#    'long': '-4.250146178756491'}},
#  {'siteId': 'GB1551_S',
#   'from': {'description': 'Caledonia Rd westbound to Camden Terr',
#    'lat': '55.845226292576825',
#    'long': '-4.24894198294951'},
#   'to': {'description': 'Caledonia Rd westbound to Camden Terr',
#    'lat': '55.8451373881192',
#    'long': '-4.2488889245192105'}},
#  {'siteId': 'GK5141_B',
#   'from': {'description': 'Nitshill Rd Westbound',
#    'lat': '55.81071992563584',
#    'long': '-4.355193432458751'},
#   'to': {'description': 'Nitshill Rd Westbound',
#    'lat': '55.81086661759488',
#    'long': '-4.35504269022466'}},
#  {'siteId': 'GD1451_F',
#   'from': {'description': 'Southbrae Drive Eastbound',
#    'lat': '55.88337934350126',
#    'long': '-4.328124888674801'},
#   'to': {'description': 'Southbrae Drive Eastbound',
#    'lat': '55.88368793243936',
#    'long': '-4.326064624857545'}},
#  {'siteId': 'GL1821_S',
#   'from': {'description': 'Paisley Road West westbound to Mosspark Dr',
#    'lat': '55.84550045400156',
#    'long': '-4.344006265387408'},
#   'to': {'description': 'Paisley Road West westbound to Mosspark Dr',
#    'lat': '55.84574649238161',
#    'long': '-4.3438293824379475'}},
#  {'siteId': 'GD1451_E',
#   'from': {'description': 'Crow Road Southbound RT',
#    'lat': '55.883185799690786',
#    'long': '-4.3260025982811054'},
#   'to': {'description': 'Crow Road Southbound RT',
#    'lat': '55.88368793243936',
#    'long': '-4.326064624857545'}},
#  {'siteId': 'GL1821_R',
#   'from': {'description': 'Paisley Road West eastbound',
#    'lat': '55.84575359406552',
#    'long': '-4.349580753000242'},
#   'to': {'description': 'Paisley Road West eastbound',
#    'lat': '55.84569171226189',
#    'long': '-4.347644064242421'}},
#  {'siteId': 'GD1451_D',
#   'from': {'description': 'Crow Road Southbound', 'lat': '0', 'long': '0'},
#   'to': {'description': 'Crow Road Southbound', 'lat': '0', 'long': '0'}},
#  {'siteId': 'GD1451_C',
#   'from': {'description': 'Crow Road Northbound',
#    'lat': '55.883771144626195',
#    'long': '-4.325941681104589'},
#   'to': {'description': 'Crow Road Northbound',
#    'lat': '55.88537132047088',
#    'long': '-4.325445764623142'}},
#  {'siteId': 'GI0601_W',
#   'from': {'description': 'M74 off-ramp eastbound inside',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'M74 off-ramp eastbound inside',
#    'lat': '55.838280729980546',
#    'long': '-4.240475302309936'}},
#  {'siteId': 'GI0601_V',
#   'from': {'description': 'Polmadie Rd northbound to M74 eastbound',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Polmadie Rd northbound to M74 eastbound',
#    'lat': '55.837623810988134',
#    'long': '-4.24150756825777'}},
#  {'siteId': 'GG2151_V',
#   'from': {'description': 'Bellgrove St northbound',
#    'lat': '55.85774784916511',
#    'long': '-4.224610058030884'},
#   'to': {'description': 'Bellgrove St northbound',
#    'lat': '55.85820833060708',
#    'long': '-4.2244925690859905'}},
#  {'siteId': 'GI0601_T',
#   'from': {'description': 'Polmadie Road southbound to M74 eastbound',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Polmadie Road southbound to M74 eastbound',
#    'lat': '55.83840070086405',
#    'long': '-4.239316294000794'}},
#  {'siteId': 'GG2151_T',
#   'from': {'description': 'Westercraig southbound (one way SB)',
#    'lat': '55.85870411586409',
#    'long': '-4.223913685680131'},
#   'to': {'description': 'Westercraig southbound (one way SB)',
#    'lat': '55.85820833060708',
#    'long': '-4.2244925690859905'}},
#  {'siteId': 'GG2151_S',
#   'from': {'description': 'Duke St. eastbound to Bellgrove',
#    'lat': '55.859012506786335',
#    'long': '-4.229715996716747'},
#   'to': {'description': 'Duke St. eastbound to Bellgrove',
#    'lat': '55.858936631359896',
#    'long': '-4.229935365584897'}},
#  {'siteId': 'GI0601_R',
#   'from': {'description': 'M74 off-ramp eastbound outside',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'M74 off-ramp eastbound outside',
#    'lat': '55.838280729980546',
#    'long': '-4.240475302309936'}},
#  {'siteId': 'GG2151_R',
#   'from': {'description': 'Duke St. westbound',
#    'lat': '55.85833640316464',
#    'long': '-4.221383888355596'},
#   'to': {'description': 'Duke St. westbound',
#    'lat': '55.85828743430807',
#    'long': '-4.221109441773829'}},
#  {'siteId': 'GK0501_D',
#   'from': {'description': 'Pollokshaws Road outbound to Minard Road',
#    'lat': '55.83394260631425',
#    'long': '-4.274592372020509'},
#   'to': {'description': 'Pollokshaws Road outbound to Minard Road',
#    'lat': '55.83432823150459',
#    'long': '-4.274151768372783'}},
#  {'siteId': 'GK0501_C',
#   'from': {'description': 'Pollokshaws Road inbound to Minard Road',
#    'lat': '55.83075213023767',
#    'long': '-4.280410174073082'},
#   'to': {'description': 'Pollokshaws Road inbound to Minard Road',
#    'lat': '55.83022560271131',
#    'long': '-4.281177758397061'}},
#  {'siteId': 'GK0501_B',
#   'from': {'description': 'Langside Avenue',
#    'lat': '55.830898484503535',
#    'long': '-4.277847819660646'},
#   'to': {'description': 'Langside Avenue',
#    'lat': '55.83155999993093',
#    'long': '-4.278525255393111'}},
#  {'siteId': 'GK0501_A',
#   'from': {'description': 'Minard Road',
#    'lat': '55.83195553710533',
#    'long': '-4.2794905592678285'},
#   'to': {'description': 'Minard Road',
#    'lat': '55.83155999993093',
#    'long': '-4.278525255393111'}},
#  {'siteId': 'GH338B_A',
#   'from': {'description': 'Dalmarnock Road eastbound to Birkwood St. EB',
#    'lat': '55.84045286681901',
#    'long': '-4.213830922680041'},
#   'to': {'description': 'Dalmarnock Road eastbound to Birkwood St. EB',
#    'lat': '55.840448271219856',
#    'long': '-4.214086215304658'}},
#  {'siteId': 'GF215A_V',
#   'from': {'description': 'Cumbernauld Rd northbound to Naver St',
#    'lat': '55.869265181955654',
#    'long': '-4.190295905938847'},
#   'to': {'description': 'Cumbernauld Rd northbound to Naver St',
#    'lat': '55.86916841037575',
#    'long': '-4.190178569819827'}},
#  {'siteId': 'GA5201_D',
#   'from': {'description': 'High St southbound to Bell St',
#    'lat': '55.858870241145745',
#    'long': '-4.241500914430377'},
#   'to': {'description': 'High St southbound to Bell St',
#    'lat': '55.85898462824174',
#    'long': '-4.24163534267433'}},
#  {'siteId': 'GF215A_T',
#   'from': {'description': 'Cumbernauld Rd southbound to Naver St',
#    'lat': '55.872800026631786',
#    'long': '-4.185587493418333'},
#   'to': {'description': 'Cumbernauld Rd southbound to Naver St',
#    'lat': '55.87289491528983',
#    'long': '-4.185305090000423'}},
#  {'siteId': 'GA5201_B',
#   'from': {'description': 'Bell St westbound',
#    'lat': '55.857289491404686',
#    'long': '-4.2419371685787635'},
#   'to': {'description': 'Bell St westbound',
#    'lat': '55.857593538264496',
#    'long': '-4.242513960854066'}},
#  {'siteId': 'GA5201_A',
#   'from': {'description': 'Bell St eastbound',
#    'lat': '55.85783410821877',
#    'long': '-4.243614422514919'},
#   'to': {'description': 'Bell St eastbound',
#    'lat': '55.857593538264496',
#    'long': '-4.242513960854066'}},
#  {'siteId': 'GB0141_V',
#   'from': {'description': 'West Street to Wallace St northbound outside lanes',
#    'lat': '55.851648048670604',
#    'long': '-4.265337856755604'},
#   'to': {'description': 'West Street to Wallace St northbound outside lanes',
#    'lat': '55.85158947840783',
#    'long': '-4.2655900781266585'}},
#  {'siteId': 'GB0141_U',
#   'from': {'description': 'West Street to Wallace St northbound inside lane',
#    'lat': '55.85166453475065',
#    'long': '-4.265418700971182'},
#   'to': {'description': 'West Street to Wallace St northbound inside lane',
#    'lat': '55.85158947840783',
#    'long': '-4.2655900781266585'}},
#  {'siteId': 'GA1551_J',
#   'from': {'description': 'Argyle Street w/b from Oswald Street',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Argyle Street w/b from Oswald Street',
#    'lat': '0',
#    'long': '0'}},
#  {'siteId': 'GG2581_F',
#   'from': {'description': 'Shettleston Road westbound to Duke St inside lane',
#    'lat': '55.85463829456522',
#    'long': '-4.1965987463374566'},
#   'to': {'description': 'Shettleston Road westbound to Duke St inside lane',
#    'lat': '55.85507451899186',
#    'long': '-4.1978377008337'}},
#  {'siteId': 'GK5051_T',
#   'from': {'description': 'Kyleakin Road Southbound',
#    'lat': '55.803446829332714',
#    'long': '-4.331727431547246'},
#   'to': {'description': 'Kyleakin Road Southbound',
#    'lat': '55.802872682850285',
#    'long': '-4.332618614081079'}},
#  {'siteId': 'GK5051_S',
#   'from': {'description': 'Nitshill Rd Westbound to M77',
#    'lat': '55.802960643090685',
#    'long': '-4.332719619718705'},
#   'to': {'description': 'Nitshill Rd Westbound to M77',
#    'lat': '55.802872682850285',
#    'long': '-4.332618614081079'}},
#  {'siteId': 'GG2581_C',
#   'from': {'description': 'Duke St. to Duke St East',
#    'lat': '55.85352498428161',
#    'long': '-4.1975424875028144'},
#   'to': {'description': 'Duke St. to Duke St East',
#    'lat': '55.85347866716663',
#    'long': '-4.197619759233908'}},
#  {'siteId': 'GK5051_R',
#   'from': {'description': 'Nitshill Rd Eastbound to Loganswell Rd',
#    'lat': '55.802829705590845',
#    'long': '-4.332041584373695'},
#   'to': {'description': 'Nitshill Rd Eastbound to Loganswell Rd',
#    'lat': '55.802872682850285',
#    'long': '-4.332618614081079'}},
#  {'siteId': 'GG2581_B',
#   'from': {'description': 'Shettleston Road westbound to Duke St outside lane',
#    'lat': '55.85466551443288',
#    'long': '-4.196584304821799'},
#   'to': {'description': 'Shettleston Road westbound to Duke St outside lane',
#    'lat': '55.85507451899186',
#    'long': '-4.1978377008337'}},
#  {'siteId': 'GL1301_T',
#   'from': {'description': 'Paisley Road West westbound',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Paisley Road West westbound',
#    'lat': '0',
#    'long': '0'}},
#  {'siteId': 'GG2581_A',
#   'from': {'description': 'Shettleston Road eastbound to Duke St East',
#    'lat': '55.85532646700769',
#    'long': '-4.198826597978703'},
#   'to': {'description': 'Shettleston Road eastbound to Duke St East',
#    'lat': '55.855537380135324',
#    'long': '-4.199094167081915'}},
#  {'siteId': 'GL1301_S',
#   'from': {'description': 'Jura St', 'lat': '0', 'long': '0'},
#   'to': {'description': 'Jura St', 'lat': '0', 'long': '0'}},
#  {'siteId': 'GL1301_R',
#   'from': {'description': 'Paisley Road West eastbound',
#    'lat': '0',
#    'long': '0'},
#   'to': {'description': 'Paisley Road West eastbound',
#    'lat': '0',
#    'long': '0'}},
#  {'siteId': 'GD2251_S',
#   'from': {'description': 'Maryhill Road outbound towards Fire Station',
#    'lat': '55.88073133287157',
#    'long': '-4.275090597183299'},
#   'to': {'description': 'Maryhill Road outbound towards Fire Station',
#    'lat': '55.88085188241169',
#    'long': '-4.27488979510388'}},
#  {'siteId': 'GH337A_B',
#   'from': {'description': 'Dalmarnock Road westbound to Birkwood St',
#    'lat': '55.83854202944291',
#    'long': '-4.210639820452077'},
#   'to': {'description': 'Dalmarnock Road westbound to Birkwood St',
#    'lat': '55.838817486281165',
#    'long': '-4.210815172545751'}},
#  {'siteId': 'GD2251_R',
#   'from': {'description': 'Maryhill Road inbound to Fire Station',
#    'lat': '55.88412038865245',
#    'long': '-4.280389856662116'},
#   'to': {'description': 'Maryhill Road inbound to Fire Station',
#    'lat': '55.884272417997686',
#    'long': '-4.280430756019544'}},
#  {'siteId': 'GK4591_B',
#   'from': {'description': 'Crookston Rd northbound',
#    'lat': '55.830131053641765',
#    'long': '-4.363281369101331'},
#   'to': {'description': 'Crookston Rd northbound',
#    'lat': '55.82978431166565',
#    'long': '-4.363084679123617'}},
#  {'siteId': 'GK4591_A',
#   'from': {'description': 'Crookston Rd southbound',
#    'lat': '55.82517130267535',
#    'long': '-4.363204018408259'},
#   'to': {'description': 'Crookston Rd southbound',
#    'lat': '55.82519424957813',
#    'long': '-4.363412974588296'}},
#  {'siteId': 'GL2621_T',
#   'from': {'description': 'Govan Rd Northbound',
#    'lat': '55.85527973642665',
#    'long': '-4.29728252494175'},
#   'to': {'description': 'Govan Rd Northbound',
#    'lat': '55.85534127437887',
#    'long': '-4.295912000825322'}},
#  {'siteId': 'GC0051_G',
#   'from': {'description': 'Elderslie Street North',
#    'lat': '55.86387922610634',
#    'long': '-4.275607258691609'},
#   'to': {'description': 'Elderslie Street North',
#    'lat': '55.86298912434018',
#    'long': '-4.275139671119664'}},
#  {'siteId': 'GA4651_V',
#   'from': {'description': 'Gorbals Street n/b to Victoria Bridge',
#    'lat': '55.85232937827657',
#    'long': '-4.252707611714965'},
#   'to': {'description': 'Gorbals Street n/b to Victoria Bridge',
#    'lat': '55.851641793066776',
#    'long': '-4.252955398146887'}},
#  {'siteId': 'GC0051_F',
#   'from': {'description': 'Elderslie Street South',
#    'lat': '55.862322996481275',
#    'long': '-4.275196603969021'},
#   'to': {'description': 'Elderslie Street South',
#    'lat': '55.86298912434018',
#    'long': '-4.275139671119664'}},
#  {'siteId': 'GC0051_E',
#   'from': {'description': 'St Vincent Street West to Elderslie St',
#    'lat': '55.86305638424973',
#    'long': '-4.271499789957201'},
#   'to': {'description': 'St Vincent Street West to Elderslie St',
#    'lat': '55.863004166197506',
#    'long': '-4.26994652479772'}},
#  {'siteId': 'GA4651_T',
#   'from': {'description': 'Stockwell Street Southbound',
#    'lat': '55.855578694138686',
#    'long': '-4.249987620993227'},
#   'to': {'description': 'Stockwell Street Southbound',
#    'lat': '55.85544548450444',
#    'long': '-4.2499000269930995'}},
#  {'siteId': 'GC0051_D',
#   'from': {'description': 'Argyle Street to Elderslie Street',
#    'lat': '55.86338219860943',
#    'long': '-4.279637561166447'},
#   'to': {'description': 'Argyle Street to Elderslie Street',
#    'lat': '55.86335655106783',
#    'long': '-4.280051584897541'}},
#  {'siteId': 'GA0571_V',
#   'from': {'description': 'Douglas St Northbound from Cadogan St',
#    'lat': '55.860225861048335',
#    'long': '-4.265134118419911'},
#   'to': {'description': 'Douglas St Northbound from Cadogan St',
#    'lat': '55.86071079831662',
#    'long': '-4.26466695088232'}},
#  {'siteId': 'GA4651_S',
#   'from': {'description': 'Clyde Street westbound to Stockwell St',
#    'lat': '55.85408462969502',
#    'long': '-4.249613639611782'},
#   'to': {'description': 'Clyde Street westbound to Stockwell St',
#    'lat': '55.85306846618108',
#    'long': '-4.2466949406691255'}},
#  {'siteId': 'GA4651_R',
#   'from': {'description': 'Clyde Street Eastbound',
#    'lat': '55.854849793412924',
#    'long': '-4.251511339891655'},
#   'to': {'description': 'Clyde Street Eastbound',
#    'lat': '55.85459359919607',
#    'long': '-4.250777504302567'}},
#  {'siteId': 'GG1171_D',
#   'from': {'description': 'Stepps Road NB R/T into Gartloch Rd (E)',
#    'lat': '55.87144147137224',
#    'long': '-4.158688848927345'},
#   'to': {'description': 'Stepps Road NB R/T into Gartloch Rd (E)',
#    'lat': '55.8713589959702',
#    'long': '-4.15929168603979'}},
#  {'siteId': 'GG1171_C',
#   'from': {'description': 'Stepps Road',
#    'lat': '52.26705443478302',
#    'long': '-3.978915403761452'},
#   'to': {'description': 'Stepps Road',
#    'lat': '55.8713589959702',
#    'long': '-4.15929168603979'}},
#  {'siteId': 'GG1171_B',
#   'from': {'description': 'Gartloch Road (E)',
#    'lat': '55.87140410787499',
#    'long': '-4.157232175344292'},
#   'to': {'description': 'Gartloch Road (E)',
#    'lat': '55.8713589959702',
#    'long': '-4.15929168603979'}},
#  {'siteId': 'GG1171_A',
#   'from': {'description': 'Borthwick Street',
#    'lat': '55.871039713323285',
#    'long': '-4.160073183625248'},
#   'to': {'description': 'Borthwick Street',
#    'lat': '55.8713589959702',
#    'long': '-4.15929168603979'}},
#  {'siteId': 'GA0571_N',
#   'from': {'description': 'Waterloo St Westbound inside to Douglas St',
#    'lat': '55.86070723971057',
#    'long': '-4.263883692348966'},
#   'to': {'description': 'Waterloo St Westbound inside to Douglas St',
#    'lat': '55.86074562868264',
#    'long': '-4.263262680588069'}},
#  {'siteId': 'GD0801_C',
#   'from': {'description': 'Lynedoch Street',
#    'lat': '55.86856661921254',
#    'long': '-4.273883500913411'},
#   'to': {'description': 'Lynedoch Street',
#    'lat': '55.86859136135907',
#    'long': '-4.273517317222294'}},
#  {'siteId': 'GD0801_A',
#   'from': {'description': 'Woodlands Road Southbound to Lynedoch Street',
#    'lat': '55.86921845642285',
#    'long': '-4.274113419119813'},
#   'to': {'description': 'Woodlands Road Southbound to Lynedoch Street',
#    'lat': '55.86859136135907',
# ...
#   'to': {'description': 'Bilsland Drive',
#    'lat': '55.886541465689234',
#    'long': '-4.256800832635375'}},
#  {'siteId': 'GE0301_T',
#   'from': {'description': 'Balmore Road outbound towards Hawthorn Street',
#    'lat': '55.88537610015535',
#    'long': '-4.25663722825672'},
#   'to': {'description': 'Balmore Road outbound towards Hawthorn Street',
#    'lat': '55.885282615637884',
#    'long': '-4.256343968236027'}},
#  {'siteId': 'GE0301_S',
#   'from': {'description': 'Hawthorn Street',
#    'lat': '55.886564601291575',
#    'long': '-4.255538867901006'},
#   'to': {'description': 'Hawthorn Street',
#    'lat': '55.886541465689234',
#    'long': '-4.256800832635375'}},
#  {'siteId': 'GE0301_R',
#   'from': {'description': 'Balmore Rd inbound towards Hawthorn St',
#    'lat': '55.89068099986828',
#    'long': '-4.258960363041584'},
#   'to': {'description': 'Balmore Rd inbound towards Hawthorn St',
#    'lat': '55.890818780368626',
#    'long': '-4.259288231746152'}},
#  {'siteId': 'GD260A_B',
#   'from': {'description': 'Maryhill Road outbound towards Sandbank Street',
#    'lat': '55.89110456999437',
#    'long': '-4.290987350024925'},
#   'to': {'description': 'Maryhill Road outbound towards Sandbank Street',
#    'lat': '55.890529884306325',
#    'long': '-4.289993891196285'}},
#  {'siteId': 'GD260A_A',
#   'from': {'description': 'Maryhill Road inbound towards Sandbank Street',
#    'lat': '55.89347400383256',
#    'long': '-4.296948945976821'},
#   'to': {'description': 'Maryhill Road inbound towards Sandbank Street',
#    'lat': '55.89394772975637',
#    'long': '-4.2970889096571705'}},
#  {'siteId': 'GD030A_S',
#   'from': {'description': 'GWR to Cecil St',
#    'lat': '55.876502925859334',
#    'long': '-4.285506649293601'},
#   'to': {'description': 'GWR to Cecil St',
#    'lat': '55.87641522514137',
#    'long': '-4.28538958413702'}},
#  {'siteId': 'GD030A_R',
#   'from': {'description': 'GWR to Cecil St.',
#    'lat': '55.87765798836764',
#    'long': '-4.289123814393541'},
#   'to': {'description': 'GWR to Cecil St.',
#    'lat': '55.87777179017829',
#    'long': '-4.2897700247368356'}},
#  {'siteId': 'GH0101_B',
#   'from': {'description': 'Gallowgate west to Barrack St',
#    'lat': '55.85537253283011',
#    'long': '-4.226743188856404'},
#   'to': {'description': 'Gallowgate west to Barrack St',
#    'lat': '55.85526881737797',
#    'long': '-4.2260182328994995'}},
#  {'siteId': 'GH0101_A',
#   'from': {'description': 'Gallowgate east to Barrack St.',
#    'lat': '55.855506997151515',
#    'long': '-4.234692132089879'},
#   'to': {'description': 'Gallowgate east to Barrack St.',
#    'lat': '55.855840661390054',
#    'long': '-4.232650064049586'}},
#  {'siteId': 'GA4151_V',
#   'from': {'description': 'Queen St.',
#    'lat': '55.86116829908267',
#    'long': '-4.251493436028325'},
#   'to': {'description': 'Queen St.',
#    'lat': '55.8616195332612',
#    'long': '-4.251391701174512'}},
#  {'siteId': 'GB0401_X',
#   'from': {'description': 'Clyde Place to Commerce Street eastbound outside lane',
#    'lat': '55.85513382354682',
#    'long': '-4.2619935727729565'},
#   'to': {'description': 'Clyde Place to Commerce Street eastbound outside lane',
#    'lat': '55.85476337655625',
#    'long': '-4.25965520363947'}},
#  {'siteId': 'GB0401_V',
#   'from': {'description': 'Commerce Street northbound to Clyde Place',
#    'lat': '55.85401868549479',
#    'long': '-4.26007532256916'},
#   'to': {'description': 'Commerce Street northbound to Clyde Place',
#    'lat': '55.8537771620326',
#    'long': '-4.260013363076228'}},
#  {'siteId': 'GC4051_F',
#   'from': {'description': 'Congress Road Inside to Congress Way',
#    'lat': '55.8590140293683',
#    'long': '-4.284495236395233'},
#   'to': {'description': 'Congress Road Inside to Congress Way',
#    'lat': '55.85864141064304',
#    'long': '-4.284233660871131'}},
#  {'siteId': 'GC4051_D',
#   'from': {'description': 'Congress Way Southbound to Congress Rd',
#    'lat': '55.859280521632435',
#    'long': '-4.283695896232739'},
#   'to': {'description': 'Congress Way Southbound to Congress Rd',
#    'lat': '55.85935619571898',
#    'long': '-4.283492595662314'}},
#  {'siteId': 'GB0401_R',
#   'from': {'description': 'Clyde Place to Commerce Street eastbound',
#    'lat': '55.855188277845784',
#    'long': '-4.2619647812568875'},
#   'to': {'description': 'Clyde Place to Commerce Street eastbound',
#    'lat': '55.85476337655625',
#    'long': '-4.25965520363947'}},
#  {'siteId': 'GC4051_B',
#   'from': {'description': 'Finnieston Quay eastbound to S.E.C.C',
#    'lat': '55.857841346257544',
#    'long': '-4.2818217217682'},
#   'to': {'description': 'Finnieston Quay eastbound to S.E.C.C',
#    'lat': '55.85774831166304',
#    'long': '-4.2819920405285306'}},
#  {'siteId': 'GC4051_A',
#   'from': {'description': 'Congress Road Outside to Congress Way',
#    'lat': '55.85899459169434',
#    'long': '-4.284573995247211'},
#   'to': {'description': 'Congress Road Outside to Congress Way',
#    'lat': '55.85864141064304',
#    'long': '-4.284233660871131'}},
#  {'siteId': 'GK4851_S',
#   'from': {'description': 'Crookston Rd northbound',
#    'lat': '55.83248638394767',
#    'long': '-4.362785508685784'},
#   'to': {'description': 'Crookston Rd northbound',
#    'lat': '55.83239976472467',
#    'long': '-4.363083672970994'}},
#  {'siteId': 'GH320A_B',
#   'from': {'description': 'Dalmarnock Road westbound to Dale St',
#    'lat': '55.844682621217736',
#    'long': '-4.219997746293337'},
#   'to': {'description': 'Dalmarnock Road westbound to Dale St',
#    'lat': '55.844494367966725',
#    'long': '-4.21997103772343'}},
#  {'siteId': 'GH320A_A',
#   'from': {'description': 'Dalmarnock Road eastbound to Dale St',
#    'lat': '55.8459831505471',
#    'long': '-4.221637402893596'},
#   'to': {'description': 'Dalmarnock Road eastbound to Dale St',
#    'lat': '55.845487003307056',
#    'long': '-4.221241682068287'}},
#  {'siteId': 'GA2701_D',
#   'from': {'description': 'Renfield street southbound to Bath Street',
#    'lat': '55.864391257964655',
#    'long': '-4.255611563952369'},
#   'to': {'description': 'Renfield street southbound to Bath Street',
#    'lat': '55.864353004607004',
#    'long': '-4.2557372027795095'}},
#  {'siteId': 'GA2701_B',
#   'from': {'description': 'Bath Street westbound from West Nile St',
#    'lat': '55.86360948968639',
#    'long': '-4.254623310621573'},
#   'to': {'description': 'Bath Street westbound from West Nile St',
#    'lat': '55.863845557995276',
#    'long': '-4.255963489217906'}},
#  {'siteId': 'GD1621_A',
#   'from': {'description': 'Great Western Rd to Anniesland Cross',
#    'lat': '55.89193614888848',
#    'long': '-4.329517157091596'},
#   'to': {'description': 'Great Western Rd to Anniesland Cross',
#    'lat': '55.891609635960464',
#    'long': '-4.329673514038679'}},
#  {'siteId': 'GA0401_T',
#   'from': {'description': 'Elmbank St',
#    'lat': '55.86395258867079',
#    'long': '-4.268227863465616'},
#   'to': {'description': 'Elmbank St',
#    'lat': '55.86512927308056',
#    'long': '-4.268264508431323'}},
#  {'siteId': 'GA0401_S',
#   'from': {'description': 'St Vincent Street Westbound',
#    'lat': '55.862545696704125',
#    'long': '-4.266052272953681'},
#   'to': {'description': 'St Vincent Street Westbound',
#    'lat': '55.86257394307593',
#    'long': '-4.265494568722255'}},
#  {'siteId': 'GA0401_R',
#   'from': {'description': 'St Vincent Street East to Elmbank St',
#    'lat': '55.86305832768834',
#    'long': '-4.269933703376354'},
#   'to': {'description': 'St Vincent Street East to Elmbank St',
#    'lat': '55.863004166197506',
#    'long': '-4.26994652479772'}},
#  {'siteId': 'GC120A_G',
#   'from': {'description': 'Argyle Street towards Kelvingrove Street',
#    'lat': '55.86510999051392',
#    'long': '-4.2853326955192514'},
#   'to': {'description': 'Argyle Street towards Kelvingrove Street',
#    'lat': '55.86528999934927',
#    'long': '-4.286286244928538'}},
#  {'siteId': 'GA5471_D',
#   'from': {'description': 'Motorway off ramp Castle St. southbound',
#    'lat': '55.865429441247834',
#    'long': '-4.236157121242562'},
#   'to': {'description': 'Motorway off ramp Castle St. southbound',
#    'lat': '55.8648959825708',
#    'long': '-4.235838776125701'}},
#  {'siteId': 'GA5471_C',
#   'from': {'description': 'Castle St. northbound',
#    'lat': '55.86402333571597',
#    'long': '-4.23687539121088'},
#   'to': {'description': 'Castle St. northbound',
#    'lat': '55.86401203541582',
#    'long': '-4.237002596556166'}},
#  {'siteId': 'GA5471_B',
#   'from': {'description': 'Castle Street to Ramp C',
#    'lat': '55.8661546764245',
#    'long': '-4.234824293822307'},
#   'to': {'description': 'Castle Street to Ramp C',
#    'lat': '55.86610225828142',
#    'long': '-4.234741368662251'}},
#  {'siteId': 'GC1631_X',
#   'from': {'description': 'Hayburn St nearside',
#    'lat': '55.86866138186298',
#    'long': '-4.310764187114153'},
#   'to': {'description': 'Hayburn St nearside',
#    'lat': '55.86929848850435',
#    'long': '-4.3108180231697855'}},
#  {'siteId': 'GC1631_W',
#   'from': {'description': 'Meadow Road',
#    'lat': '55.86919639352558',
#    'long': '-4.3119468443932005'},
#   'to': {'description': 'Meadow Road',
#    'lat': '55.86929848850435',
#    'long': '-4.3108180231697855'}},
#  {'siteId': 'GC1631_V',
#   'from': {'description': 'Hayburn St offside',
#    'lat': '55.86865988245911',
#    'long': '-4.310844018539943'},
#   'to': {'description': 'Hayburn St offside',
#    'lat': '55.86929848850435',
#    'long': '-4.3108180231697855'}},
#  {'siteId': 'GH4521_F',
#   'from': {'description': 'Fullarton Road s/b',
#    'lat': '55.835999692078374',
#    'long': '-4.172246863649164'},
#   'to': {'description': 'Fullarton Road s/b',
#    'lat': '55.836126235853115',
#    'long': '-4.172206011428887'}},
#  {'siteId': 'GJ0351_D',
#   'from': {'description': 'Aikenhead Road southbound to Menock Rd',
#    'lat': '55.82017210003487',
#    'long': '-4.250257546433559'},
#   'to': {'description': 'Aikenhead Road southbound to Menock Rd',
#    'lat': '55.82016283016515',
#    'long': '-4.2502729750640285'}},
#  {'siteId': 'GH4521_E',
#   'from': {'description': 'M74  e/b off ramp',
#    'lat': '55.83637722366697',
#    'long': '-4.173769128718611'},
#   'to': {'description': 'M74  e/b off ramp',
#    'lat': '55.836126235853115',
#    'long': '-4.172206011428887'}},
#  {'siteId': 'GJ0351_C',
#   'from': {'description': 'Aikenhead Road northbound',
#    'lat': '55.818430366496436',
#    'long': '-4.25015697041314'},
#   'to': {'description': 'Aikenhead Road northbound',
#    'lat': '55.82640363492185',
#    'long': '-4.246641817951074'}},
#  {'siteId': 'GC1631_R',
#   'from': {'description': 'Expressway Off-Ramp eastbound',
#    'lat': '55.86875616935264',
#    'long': '-4.312416185365758'},
#   'to': {'description': 'Expressway Off-Ramp eastbound',
#    'lat': '55.86929848850435',
#    'long': '-4.3108180231697855'}},
#  {'siteId': 'GJ0351_B',
#   'from': {'description': 'Menock Road westbound',
#    'lat': '55.81909085486535',
#    'long': '-4.248933992022725'},
#   'to': {'description': 'Menock Road westbound',
#    'lat': '55.81929977405216',
#    'long': '-4.250286990737608'}},
#  {'siteId': 'GJ0351_A',
#   'from': {'description': 'Menock Road eastbound',
#    'lat': '55.81924802421207',
#    'long': '-4.25164090617372'},
#   'to': {'description': 'Menock Road eastbound',
#    'lat': '55.82640363492185',
#    'long': '-4.246641817951074'}},
#  {'siteId': 'GH4521_B',
#   'from': {'description': 'Fullarton Roundabout s/b circulatory',
#    'lat': '55.83561735383645',
#    'long': '-4.170995850302077'},
#   'to': {'description': 'Fullarton Roundabout s/b circulatory',
#    'lat': '55.83494562438461',
#    'long': '-4.171373617863877'}},
#  {'siteId': 'GK0251_V',
#   'from': {'description': 'Pollokshaws Road inbound to Albert Drive',
#    'lat': '55.838800480265775',
#    'long': '-4.267529161607213'},
#   'to': {'description': 'Pollokshaws Road inbound to Albert Drive',
#    'lat': '55.83834658561153',
#    'long': '-4.267774245631587'}},
#  {'siteId': 'GK0251_T',
#   'from': {'description': 'Pollokshaws Road outbound to Albert Drive',
#    'lat': '55.84228274564642',
#    'long': '-4.263403260149433'},
#   'to': {'description': 'Pollokshaws Road outbound to Albert Drive',
#    'lat': '55.84235897320175',
#    'long': '-4.263168095042885'}},
#  {'siteId': 'GK0251_R',
#   'from': {'description': 'Albert Drive R/T',
#    'lat': '55.84115074735943',
#    'long': '-4.266308360823459'},
#   'to': {'description': 'Albert Drive R/T',
#    'lat': '55.84071743316437',
#    'long': '-4.265436600315468'}},
#  {'siteId': 'GG2751_D',
#   'from': {'description': 'South Chester Street',
#    'lat': '55.85075040392315',
#    'long': '-4.169555246772373'},
#   'to': {'description': 'South Chester Street',
#    'lat': '55.85177087994107',
#    'long': '-4.169276620816412'}},
#  {'siteId': 'GG2751_B',
#   'from': {'description': 'Shettleston Road to Chester St',
#    'lat': '55.85157937320951',
#    'long': '-4.166374199723624'},
#   'to': {'description': 'Shettleston Road to Chester St',
#    'lat': '55.85153701060594',
#    'long': '-4.166228053507993'}},
#  {'siteId': 'GG2751_A',
#   'from': {'description': 'Shettleston Rd East to Chester St',
#    'lat': '55.85183299613021',
#    'long': '-4.171868295482324'},
#   'to': {'description': 'Shettleston Rd East to Chester St',
#    'lat': '55.85191037902376',
#    'long': '-4.172575586561228'}},
#  {'siteId': 'GG0021_H',
#   'from': {'description': 'Alexandra Parade R/T to Wishart Street',
#    'lat': '55.86560326028364',
#    'long': '-4.229054889727144'},
#   'to': {'description': 'Alexandra Parade R/T to Wishart Street',
#    'lat': '55.86566957783804',
#    'long': '-4.228866899377545'}},
#  {'siteId': 'GG0021_C',
#   'from': {'description': 'Wishart Street',
#    'lat': '55.86537274202822',
#    'long': '-4.229872766495637'},
#   'to': {'description': 'Wishart Street',
#    'lat': '55.86566957783804',
#    'long': '-4.228866899377545'}},
#  {'siteId': 'GG0021_B',
#   'from': {'description': 'Alexandra Parade westbound to Wishart Street',
#    'lat': '55.865421633821946',
#    'long': '-4.227669993143565'},
#   'to': {'description': 'Alexandra Parade westbound to Wishart Street',
#    'lat': '55.86566957783804',
#    'long': '-4.228866899377545'}},
#  {'siteId': 'GB1201_E',
#   'from': {'description': 'Cathcart Road northbound',
#    'lat': '55.84687582162568',
#    'long': '-4.255059820284952'},
#   'to': {'description': 'Cathcart Road northbound',
#    'lat': '55.848092816760634',
#    'long': '-4.254858740826407'}},
#  {'siteId': 'GG0021_A',
#   'from': {'description': 'Alexandra Parade eastbound to Wishart Street',
#    'lat': '55.86627401191743',
#    'long': '-4.234191837483145'},
#   'to': {'description': 'Alexandra Parade eastbound to Wishart Street',
#    'lat': '55.86610225828142',
#    'long': '-4.234741368662251'}},
#  {'siteId': 'GL1901_T',
#   'from': {'description': 'Hillington Road southbound right turn',
#    'lat': '55.8465731249378',
#    'long': '-4.359822404393915'},
#   'to': {'description': 'Hillington Road southbound right turn',
#    'lat': '55.84552155892677',
#    'long': '-4.359822556890798'}},
#  {'siteId': 'GL1901_S',
#   'from': {'description': 'PRW to Hillington Road',
#    'lat': '55.84579511370658',
#    'long': '-4.355398116477264'},
#   'to': {'description': 'PRW to Hillington Road',
#    'lat': '55.84596178260748',
#    'long': '-4.354673352933915'}},
#  {'siteId': 'GB1201_A',
#   'from': {'description': 'Cumberland Street',
#    'lat': '55.84836128637019',
#    'long': '-4.256391968423523'},
#   'to': {'description': 'Cumberland Street',
#    'lat': '55.848092816760634',
#    'long': '-4.254858740826407'}},
#  {'siteId': 'GL1901_P',
#   'from': {'description': 'Hillington Road southbound left turn',
#    'lat': '55.84657373725236',
#    'long': '-4.359790491046517'},
#   'to': {'description': 'Hillington Road southbound left turn',
#    'lat': '55.84552155892677',
#    'long': '-4.359822556890798'}},
#  {'siteId': 'GE0551_S',
#   'from': {'description': 'Balmore Road outbound',
#    'lat': '55.89565126752435',
#    'long': '-4.26383987505431'},
#   'to': {'description': 'Balmore Road outbound',
#    'lat': '55.89557340592638',
#    'long': '-4.263675388864068'}},
#  {'siteId': 'GE0551_R',
#   'from': {'description': 'Balmore Road inbound towards Skirsa St',
#    'lat': '55.89864459845293',
#    'long': '-4.266253765163888'},
#   'to': {'description': 'Balmore Road inbound towards Skirsa St',
#    'lat': '55.897546071428856',
#    'long': '-4.266365642948926'}},
#  ...]

# %%
sensors_pd = pd.DataFrame(data) #convert data into dataframe
sensors_pd.head()
# Out:
#      siteId                                               from  \
# 0  GH020A_B  {'description': 'Gallowgate west to Sword St',...
# 1  GJ3301_D  {'description': 'Carmunnock Rd southbound', 'l...
# 2  GH020A_A  {'description': 'Gallowgate east to Sword St',...
# 3  GJ3301_C  {'description': 'Carmunnock Rd northbound to K...
# 4  GJ3301_B  {'description': 'Kings Park Ave westbound to C...
#
#                                                   to
# 0  {'description': 'Gallowgate west to Sword St',...
# 1  {'description': 'Carmunnock Rd southbound', 'l...
# 2  {'description': 'Gallowgate east to Sword St',...
# 3  {'description': 'Carmunnock Rd northbound to K...
# 4  {'description': 'Kings Park Ave westbound to C...

# %%
#normalising 'from' column of dataframe to split description and longitude and latitude
#Instructions from: https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html
normalised_from = pd.json_normalize(sensors_pd['from'])
normalised_from.head()
# Out:
#                                      description                 lat  \
# 0                    Gallowgate west to Sword St    55.8543754827825
# 1                       Carmunnock Rd southbound  55.821736212748405
# 2                    Gallowgate east to Sword St   55.85539015389372
# 3  Carmunnock Rd northbound to Kings Park Avenue   55.81925458152306
# 4      Kings Park Ave westbound to Carmunnock Rd  55.820288451422314
#
#                   long
# 0   -4.217259197086495
# 1  -4.2561270616272875
# 2   -4.225769520669405
# 3   -4.255696036412074
# 4   -4.250775113480551

# %%
#Remove any Na variables and subset to only requred data
clean_from_sensors_pd = normalised_from.dropna(subset=['description', 'lat', 'long',])
clean_from_sensors_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   description  1275 non-null   object
#  1   lat          1275 non-null   object
#  2   long         1275 non-null   object
# dtypes: object(3)
# memory usage: 30.0+ KB

# %%
gdf_from_sensors = gpd.GeoDataFrame(clean_from_sensors_pd, geometry=gpd.points_from_xy(clean_from_sensors_pd['long'], clean_from_sensors_pd['lat'])) #convert to gdf format

# %%
gdf_from_sensors.crs

# %%
gdf_from_sensors = gdf_from_sensors.set_crs("EPSG:4326") #change crs

# %%
gdf_from_sensors.explore() #map the from sensors

# %%
#Loading geopandas
import geopandas as gpd

# Read Shapefile
shapefile_path = "data/WorkplaceZones2011Scotland/WorkplaceZones2011Scotland.shp"
gdf_shapefile = gpd.read_file(shapefile_path)

# %%
gdf_shapefile.crs

# %%
gdf_wgs83 = gdf_shapefile.to_crs(epsg=4326) #convert to appropriate epsg

# %%
gdf_wgs83.explore()

# %%
glasgow_workingzones = gdf_wgs83[gdf_wgs83.LADCD=="S12000046"] #Use LADCD code for glasgow to create subset of regions
glasgow_workingzones.explore()

# %%
overlay_gdf  = gpd.sjoin(gdf_from_sensors, glasgow_workingzones, how="inner", op="within") #using sjoin to join gdfs using inner and within

# %%
overlay_gdf.explore()

# %%
grouped_WZCD = overlay_gdf.groupby('WZCD', dropna=True) # grouping sensors by working zone

# %%
sensors_per_workingzone = grouped_WZCD.size()#counting sensors in each working zone group

# %%
sensors_per_workingzone_df = sensors_per_workingzone.reset_index() #convert sensor count to dataframe

# %%
sensors_per_workingzone_df.columns = ['WZCD', 'SensorsCount'] #rename columns

# %%
sensors_per_workingzone_df['WZCD'] = sensors_per_workingzone_df['WZCD'].astype(str)
glasgow_workingzones['WZCD'] = glasgow_workingzones['WZCD'].astype(str)

# %%
WZCD_Sensor_count = pd.merge(sensors_per_workingzone_df, glasgow_workingzones, on="WZCD") #merge the sensor counts with the working zone map

# %%
WZCD_Sensor_count_GDF = gpd.GeoDataFrame(WZCD_Sensor_count, geometry='geometry') #convert the data frame to a geodataframe

# %%
import leafmap
WZCD_Sensor_count_GDF.explore(column='SensorsCount', cmap='RdYlGn') #Print the map using diverging color map to show high and low counts

# %%
# !ls -lh

# %% [markdown]
# ## Reading a WMS Service

# %%
m = leafmap.Map(
    center=(56.329031,-3.798943),
    zoom=7
)
wms_url = 'https://maps.gov.scot/server/services/NRS/Census2011/MapServer/WMSServer?'
# A WMS URL include multiple layers, so you need to provide the name you need to load in your map.
# See this: https://www.spatialdata.gov.scot/geonetwork/srv/eng/catalog.search#/metadata/ff882746-e913-4f78-862e-f6e3974fb80e


m.add_wms_layer(url=wms_url, layers='WorkplaceZones2011', name='Census2011', shown=True)
m

# %% [markdown]
# # Finishing the Lab
#
# Make sure you save all your code and upload the latest version of this notebook in your GitHub Repo. If you havent created a Repo to store all your Jupyter Notebooks related to the Labs, make sure you create a well and organized GitHub repo where you have the most curated and finished notebooks.
